# %%
import time
from math import sqrt
import matplotlib.pyplot as plt
import random
from env4 import Env
import os
import numpy as np
import torch
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader
from copy import deepcopy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class ExperienceDataset(Dataset):
    def __init__(self, data):
        super().__init__()
        self.data = data

    def __len__(self):
        return len(self.data[0])

    def __getitem__(self, ind):
        return tuple(map(lambda t: t[ind], self.data))

def create_shuffled_dataloader(data, batch_size):
    ds = ExperienceDataset(data)
    return DataLoader(ds, batch_size = batch_size, shuffle = True)

# %%
class PolicyNetwork(torch.nn.Module):
    def __init__(self,state_dims, n_actions):
        super(PolicyNetwork, self).__init__()
        self.actor = torch.nn.Sequential(
            torch.nn.Linear(6, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, n_actions),
            torch.nn.Softmax(dim=-1)
        )

    def forward(self, x):
        policy = self.actor(x)
        return policy
    

class ValueNetwork(torch.nn.Module):
    def __init__(self,state_dims):
        super(ValueNetwork, self).__init__()
        self.critic = torch.nn.Sequential(
            torch.nn.Linear(6, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        value = self.critic(x)
        return value
        
def weights_init(m):
    if isinstance(m,torch.nn.Linear):
        m.bias.data.fill_(0)
        torch.nn.init.kaiming_uniform_(m.weight)


def np_to_tensor(x):
    return torch.tensor(x).to(torch.float32)

    
policy_model = PolicyNetwork(state_dims=6, n_actions = 7)
value_model = ValueNetwork(state_dims=6)

# %%
print(policy_model,value_model)
summary(policy_model, input_size=(1, 6))
summary(value_model, input_size=(1, 6))
# Out:
# PolicyNetwork(
#   (actor): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=7, bias=True)
#     (5): Softmax(dim=-1)
#   )
# ) ValueNetwork(
#   (critic): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             448
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 32]           2,080
#               ReLU-4                [-1, 1, 32]               0
#             Linear-5                 [-1, 1, 7]             231
#            Softmax-6                 [-1, 1, 7]               0
# ================================================================
# Total params: 2,759
# Trainable params: 2,759
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             448
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 32]           2,080
#               ReLU-4                [-1, 1, 32]               0
#             Linear-5                 [-1, 1, 1]              33
# ================================================================
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------

# %%
class PPO:
    def __init__(self, state_dim=6, action_dim=7, policy_lr=0.0005, value_lr=0.001, 
                 gamma=0.99, lam=0.95, beta_s=0.01,epsilon_clip=0.2, value_clip=0.4, 
                 epochs=5,batch_size=50,save_path='Models'):
        
        self.policy_net = PolicyNetwork(state_dim, action_dim).to(device)
        self.value_net = ValueNetwork(state_dim).to(device)
        self.policy_net.apply(weights_init)
        self.value_net.apply(weights_init)

        self.policy_optimizer = torch.optim.Adam(self.policy_net.parameters(), lr=policy_lr)
        self.value_optimizer = torch.optim.Adam(self.value_net.parameters(), lr=value_lr)

        self.gamma = gamma
        self.lamda = lam
        self.epsilon_clip = epsilon_clip
        self.value_clip = value_clip
        self.beta_s = beta_s
        self.epochs = epochs
        self.action_dim = action_dim
        self.batch_size = batch_size

        self.env = Env()
        self.env.run()

        self.save_path = save_path
        self.env_name = "auto-docking-iss"

        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
        self.path = str(self.env_name)+'_PPO_'
        self.model_name = os.path.join(self.save_path, self.path)

        self.trajectory = {'states':[],'actions':[], 'rewards':[], 'action_logs':[],
                           'values':[],'done':[]}
        
        self.scores, self.episodes, self.average = [],[],[]
        self.value_loss_mean, self.policy_loss_mean = [], []

    def save(self,episode,score):
        torch.save({
            'actor': self.policy_net.state_dict(),
            'critic': self.value_net.state_dict()
        }, f'./'+ self.model_name + '_' + str(episode) + '_' + str(round(score,4)) + '.pt')

    def load(self,name):
        print(f'./{name}')
        try:
            data = torch.load(f'./{name}')
            self.policy_net.load_state_dict(data['actor'])
            self.value_net.load_state_dict(data['critic'])
        except Exception as e:
            print(e)

    # Función para visualizar la evolución del entrenamiento
    def plot_model(self, score, episode,num_episodes):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-10:]) / len(self.scores[-10:]))
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(1,figsize=(18, 9))
            plt.plot(self.episodes, self.scores, 'b')
            plt.plot(self.episodes, self.average, 'r')
            plt.ylabel('Score', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"scores.png")
            except OSError:
                pass

        return self.average[-1]
    
    def plot_loss(self,episode,num_episodes):        
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(2,figsize=(18, 9))
            plt.plot(self.episodes, self.policy_loss_mean, 'b')
            plt.plot(self.episodes, self.value_loss_mean, 'r')
            plt.ylabel('Loss', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"loss.png")
            except OSError:
                pass
    

    #Almacenamiento de todas las variables que definen una transición para PPO
    def collect_trayectory(self,state,action,action_logs,reward,done,value):
        self.trajectory['states'].append(state)
        self.trajectory['actions'].append(action)
        self.trajectory['rewards'].append(reward)
        self.trajectory['values'].append(value)
        self.trajectory['action_logs'].append(action_logs)
        self.trajectory['done'].append(done)
    
    def clear_trayectory(self):
        for key in self.trajectory.keys():
            self.trajectory[key].clear()
    
    def select_action(self,state):
        action_probs = self.policy_net(state).squeeze().detach()
        dist = torch.distributions.Categorical(action_probs)
        action = dist.sample()
        action_log_probs = dist.log_prob(action)
        
        return action.item(),action_log_probs,dist.entropy().item()

    
    def generalized_advantage_estimation(self,next_state):
        advantages = np.zeros_like(self.trajectory['rewards'])
        last_gae_lambda = 0
        self.trajectory['values'].append(self.value_net(next_state).squeeze().detach())

        for t in reversed(range(len(self.trajectory['rewards']))):
            delta = self.trajectory['rewards'][t]+ self.gamma * self.trajectory['values'][t + 1].item() - self.trajectory['values'][t].item()
            advantages[t] = last_gae_lambda = delta + self.gamma * self.lamda * last_gae_lambda
        
        return np_to_tensor(advantages)


    def learn_from_episode_trajectory(self,next_state):
        self.policy_net.train()
        self.value_net.train()

        states = deepcopy(self.trajectory['states'])
        actions = deepcopy(self.trajectory['actions'])
        # rewards = deepcopy(self.trajectory['rewards'])
        values = deepcopy(self.trajectory['values'])
        action_logs = deepcopy(self.trajectory['action_logs'])
        # done = deepcopy(self.trajectory['done'])

        advantages = self.generalized_advantage_estimation(next_state).to(device)

        # prepare dataloader for policy phase training
        dl = create_shuffled_dataloader([states, actions, action_logs, advantages, values], self.batch_size)

        policy_loss_array = []
        value_loss_array = []

        for i in range(self.epochs):
            for states, actions, action_log, advantages, values in dl:
                #Update policy_net
                new_action_probs = self.policy_net(states).squeeze()
                dist = torch.distributions.Categorical(new_action_probs)

                # print("")
                # print(actions)
                # print(new_action_probs)
                new_action_logs = dist.log_prob(actions)
                entropy = dist.entropy()

                # compute PPO-Clip
                ratios = torch.exp(new_action_logs - action_log)
                surr1 = ratios * advantages
                surr2 = ratios.clamp(1 - self.epsilon_clip, 1 + self.epsilon_clip) * advantages
                policy_loss = -torch.mean(torch.min(surr1, surr2) - self.beta_s * entropy)
                policy_loss_array.append(policy_loss.detach().numpy())

                self.policy_optimizer.zero_grad() # Clean gradients
                policy_loss.mean().backward() # Compute gradients
                self.policy_optimizer.step() #Update weights

                #Update value_net
                new_values = self.value_net(states).squeeze()
                value_clipped = values + (new_values - values).clamp(-self.value_clip, self.value_clip)
                value_loss_1 = (value_clipped.flatten() - advantages) ** 2
                value_loss_2 = (values.flatten() - advantages) ** 2
                value_loss = torch.mean(torch.max(value_loss_1, value_loss_2))
                value_loss_array.append(value_loss.detach().numpy())

                self.value_optimizer.zero_grad() # Clean gradients
                value_loss.backward() # Compute gradients 

        self.value_loss_mean.append(sum(value_loss_array)/self.epochs)
        self.policy_loss_mean.append(sum(policy_loss_array)/self.epochs)

        print(f"\n Mean Policy loss: {self.value_loss_mean[-1]:.4f}. Mean Value loss: {self.policy_loss_mean[-1]:.4f}")
        
        self.policy_net.eval()
        self.value_net.eval()


    # Función para resetear el entorno tras acabar trayectoria
    def reset(self):
        state = self.env.reset()
        return np_to_tensor(self.process_state(state))
    
     # Función para interacción agente-entorno
    def step(self, action):
        next_state, reward, done = self.env.step(action)
        next_state = self.process_state(next_state)
        return np_to_tensor(next_state), reward, done

    def process_state(self,state):
        state_processed = np.array(state)
        state_processed[:3] = state_processed[:3] / 40 # Position array
        return state_processed
    
    def train(self,num_episodes=200,max_steps=200):
        average = 0
        self.policy_net.eval()
        self.value_net.eval()

        max_score_average = -5000

        for episode in range(1,num_episodes+1):
            self.clear_trayectory()

            state = self.reset()
            score = 0

            SAVING = ""

            for step in range(1,max_steps+1):
                
                action_probs = self.policy_net(state).squeeze().detach()
                dist = torch.distributions.Categorical(action_probs)
                action = dist.sample()
                action_log = dist.log_prob(action)

                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action.item())    
                self.collect_trayectory(state,action,action_log,reward,done,value)

                state = next_state

                score += reward

                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Reward/Value: {round(reward,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)

                if done:
                    break
                
                time.sleep(1.0)

            self.learn_from_episode_trajectory(next_state)
            self.clear_trayectory()

            average = self.plot_model(score, episode,num_episodes)
            self.plot_loss(episode,num_episodes)
            
            if average >= max_score_average and episode > 5:
                max_score_average = average
                self.save(episode,average)
                SAVING = "SAVING"
            elif episode % 10 == 0:
                self.save(episode,average)
                SAVING = "SAVING"
            else:
                SAVING = ""
            
            print(f"Episode: {episode}/{num_episodes}, score/average: {score:.4f}/{average:.4f} {SAVING}\n")


        # close environemnt when finish training
        self.save(episode,average)

    def test(self,max_steps):
        self.policy_net.eval()
        self.value_net.eval()

        self.clear_trayectory()
        state = self.reset()
        score = 0

        start = time.time()
        end = time.time()
        step = 0

        while True:
            end = time.time()
            if end - start >= 1.0:
                step += 1
                action_probabilities = self.policy_net(state)
                action = torch.argmax(action_probabilities, dim=-1).item()#np.argmax(self.policy_net(state).squeeze().detach().numpy())
                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action)    

                state = next_state

                score += reward

                # print(action_probabilities)
                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Score/Value: {round(score,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)
                start = time.time()

            if self.env.done or step > max_steps:
                break

        state_end = self.env.get_state()
        
        print(f'\nNext state: {state_end}')

# %%
agent = PPO(save_path='Models7')
# Out:
# (9363) wsgi starting up on http://127.0.0.1:5000
# (9363) accepted ('127.0.0.1', 33598)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET / HTTP/1.1" 304 242 0.006050
# (9363) accepted ('127.0.0.1', 33610)
# (9363) accepted ('127.0.0.1', 33614)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /js/three/three.js HTTP/1.1" 304 196 0.000850
# (9363) accepted ('127.0.0.1', 33618)
# (9363) accepted ('127.0.0.1', 33628)
# (9363) accepted ('127.0.0.1', 33638)
# (9363) accepted ('127.0.0.1', 33646)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /css/layout.css HTTP/1.1" 304 198 0.000624
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /css/normalize.css HTTP/1.1" 304 201 0.000623
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /js/three/WebGL.js HTTP/1.1" 304 196 0.000571
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /js/three/GLTFLoader.js HTTP/1.1" 304 201 0.000509
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /js/three/CSS2DRenderer.js HTTP/1.1" 304 204 0.000502
# (9363) accepted ('127.0.0.1', 33660)
# (9363) accepted ('127.0.0.1', 33662)
# (9363) accepted ('127.0.0.1', 33672)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /js/gsap3/DrawSVGPlugin.js HTTP/1.1" 304 204 0.000569
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /js/gsap3/gsap.js HTTP/1.1" 304 195 0.000541
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /js/gsap3/ScrambleTextPlugin.js HTTP/1.1" 304 209 0.000509
# (9363) accepted ('127.0.0.1', 33684)
# (9363) accepted ('127.0.0.1', 33686)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/hud-ring.png HTTP/1.1" 304 200 0.000799
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/hud-darken.png HTTP/1.1" 304 202 0.000495
# (9363) accepted ('127.0.0.1', 33690)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/hud-ring-inner.png HTTP/1.1" 304 206 0.000500
# (9363) accepted ('127.0.0.1', 33704)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/shadow.png HTTP/1.1" 304 198 0.000471
# (9363) accepted ('127.0.0.1', 33720)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /js/threed.js HTTP/1.1" 304 197 0.000598
# (9363) accepted ('127.0.0.1', 33724)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/instructions/step1_6.jpg HTTP/1.1" 304 199 0.000799
# (9363) accepted ('127.0.0.1', 33730)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/instructions/step2.jpg HTTP/1.1" 304 197 0.000533
# (9363) accepted ('127.0.0.1', 33746)
# (9363) accepted ('127.0.0.1', 33762)
# (9363) accepted ('127.0.0.1', 33772)
# (9363) accepted ('127.0.0.1', 33780)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/instructions/step5.jpg HTTP/1.1" 304 197 0.000615
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/instructions/step3.jpg HTTP/1.1" 304 197 0.000561
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/instructions/step4.jpg HTTP/1.1" 304 197 0.000432
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/instructions/step7.jpg HTTP/1.1" 304 197 0.000498
# (9363) accepted ('127.0.0.1', 33788)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /socket.io/?EIO=4&transport=polling&t=P4rjY3k HTTP/1.1" 200 278 0.000478
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/hud/ForwardViewSprites.json HTTP/1.1" 304 211 0.001053
# (9363) accepted ('127.0.0.1', 33796)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /3d/iss.glb HTTP/1.1" 304 195 0.000741
# (9363) accepted ('127.0.0.1', 33810)
# (9363) accepted ('127.0.0.1', 33812)
# (9363) accepted ('127.0.0.1', 33814)
# (9363) accepted ('127.0.0.1', 33826)
# (9363) accepted ('127.0.0.1', 33836)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/earth.jpg HTTP/1.1" 304 197 0.000832
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/navball.png HTTP/1.1" 304 199 0.000701
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/texture_fire.jpg HTTP/1.1" 304 204 0.001022
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/texture_wormhole.jpg HTTP/1.1" 304 208 0.000534
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/texture_star.jpg HTTP/1.1" 304 204 0.000520
# (9363) accepted ('127.0.0.1', 33844)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/hud/ForwardViewSprites2.png HTTP/1.1" 304 211 0.000542
# (9363) accepted ('127.0.0.1', 33860)
# (9363) accepted ('127.0.0.1', 33872)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "POST /socket.io/?EIO=4&transport=polling&t=P4rjY85&sid=zOKxIUf98W3i70u3AAAA HTTP/1.1" 200 219 0.000587
# (9363) accepted ('127.0.0.1', 33888)
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /socket.io/?EIO=4&transport=polling&t=P4rjY85.0&sid=zOKxIUf98W3i70u3AAAA HTTP/1.1" 200 181 0.000080
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /socket.io/?EIO=4&transport=polling&t=P4rjYBo&sid=zOKxIUf98W3i70u3AAAA HTTP/1.1" 200 181 0.000207
# 127.0.0.1 - - [09/Aug/2024 07:56:54] "GET /img/favicon.ico HTTP/1.1" 304 199 0.000615
# 127.0.0.1 - - [09/Aug/2024 07:56:55] "GET /img/target-iss.png HTTP/1.1" 304 202 0.001121

# %%
agent.train(num_episodes=200,max_steps=200)
# Out:
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -0.45/-0.0075. Done: 0
#  Mean Policy loss: 98.6442. Mean Value loss: -5.7265
# Episode: 1/200, score/average: 19.3500/19.3500
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -0.6/-0.103. Done: 000
#  Mean Policy loss: 139.5966. Mean Value loss: 22.1721
# Episode: 2/200, score/average: -69.9000/-25.2750
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: 0.2/-0.0498. Done: 0 0
#  Mean Policy loss: 35.6158. Mean Value loss: 0.2334
# Episode: 3/200, score/average: -3.6000/-18.0500
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -0.3/-0.0669. Done: 00
#  Mean Policy loss: 25.9968. Mean Value loss: 0.5880
# Episode: 4/200, score/average: 2.3000/-12.9625
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.05/-0.0659. Done: 0
#  Mean Policy loss: 57.4047. Mean Value loss: -7.4361
# Episode: 5/200, score/average: 20.8500/-6.2000
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: 1.15/0.1191. Done: 00
#  Mean Policy loss: 113.7848. Mean Value loss: -18.0248
# Episode: 6/200, score/average: 53.8000/3.8000 SAVING
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -0.05/0.0389. Done: 00
#  Mean Policy loss: 215.2344. Mean Value loss: -21.1671
# Episode: 7/200, score/average: 69.2000/13.1429 SAVING
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: 0.35/-0.0208. Done: 00
#  Mean Policy loss: 57.1215. Mean Value loss: -3.9254
# Episode: 8/200, score/average: 22.8000/14.3500 SAVING
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: 0.35/0.047. Done: 00 0
#  Mean Policy loss: 16.2656. Mean Value loss: -2.9103
# Episode: 9/200, score/average: 12.6000/14.1556
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: 0.35/0.111. Done: 00 0
#  Mean Policy loss: 119.1002. Mean Value loss: -12.6005
# Episode: 10/200, score/average: 43.1000/17.0500 SAVING
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -0.2/-0.3184. Done: 00
#  Mean Policy loss: 23.8184. Mean Value loss: 0.7504
# Episode: 11/200, score/average: -2.6000/14.8550
#
# Reset
# Steps: 179/200. Action: 4. Reward/Value: 1.15/0.0442. Done: -1
#  Mean Policy loss: 71.7606. Mean Value loss: -15.3200
# Episode: 12/200, score/average: 46.5000/26.4950 SAVING
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -0.05/-0.0203. Done: 0
#  Mean Policy loss: 226.0853. Mean Value loss: -22.6088
# Episode: 13/200, score/average: 71.1500/33.9700 SAVING
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.45/-0.054. Done: 00
#  Mean Policy loss: 74.1175. Mean Value loss: -11.9877
# Episode: 14/200, score/average: 39.0500/37.6450 SAVING
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: 0.6/0.1272. Done: 0 00
#  Mean Policy loss: 23.1797. Mean Value loss: -7.7308
# Episode: 15/200, score/average: 24.2500/37.9850 SAVING
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.05/0.0842. Done: 00
#  Mean Policy loss: 74.3962. Mean Value loss: -12.7922
# Episode: 16/200, score/average: 41.7000/36.7750
#
# Reset
# Steps: 188/200. Action: 0. Reward/Value: 0.75/-0.0547. Done: -1
#  Mean Policy loss: 73.4389. Mean Value loss: -11.0195
# Episode: 17/200, score/average: 36.0000/33.4550
#
# Reset
# Steps: 198/200. Action: 1. Reward/Value: 0.75/-0.0195. Done: -1
#  Mean Policy loss: 45.6111. Mean Value loss: -11.2844
# Episode: 18/200, score/average: 35.9500/34.7700
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: 0.1/0.029. Done: 000 0
#  Mean Policy loss: 100.8004. Mean Value loss: -17.4276
# Episode: 19/200, score/average: 54.1500/38.9250 SAVING
#
# Reset
# Steps: 177/200. Action: 4. Reward/Value: 1.8/-0.0848. Done: -10
#  Mean Policy loss: 160.3259. Mean Value loss: -24.2876
# Episode: 20/200, score/average: 68.1500/41.4300 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -0.2/-0.1095. Done: 00
#  Mean Policy loss: 53.8741. Mean Value loss: -9.3327
# Episode: 21/200, score/average: 27.4500/44.4350 SAVING
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.2/-0.1835. Done: 00
#  Mean Policy loss: 73.7749. Mean Value loss: -14.0748
# Episode: 22/200, score/average: 43.5500/44.1400
#
# Reset
# Steps: 182/200. Action: 0. Reward/Value: 0.9/0.0713. Done: -100
#  Mean Policy loss: 112.2931. Mean Value loss: -17.2235
# Episode: 23/200, score/average: 51.0000/42.1250
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: 0.2/0.1752. Done: 0 00
#  Mean Policy loss: 41.9855. Mean Value loss: -6.9325
# Episode: 24/200, score/average: 24.6000/40.6800
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: 0.35/0.0885. Done: 0 0
#  Mean Policy loss: 113.9918. Mean Value loss: -17.1417
# Episode: 25/200, score/average: 52.4000/43.4950
#
# Reset
# Steps: 199/200. Action: 0. Reward/Value: 1.0/-0.0962. Done: -10
#  Mean Policy loss: 28.5037. Mean Value loss: -4.2677
# Episode: 26/200, score/average: 18.0000/41.1250
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -0.05/-0.0183. Done: 0
#  Mean Policy loss: 97.4996. Mean Value loss: -17.7036
# Episode: 27/200, score/average: 58.5000/43.3750
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -0.2/-0.1062. Done: 00
#  Mean Policy loss: 12.0409. Mean Value loss: -2.4561
# Episode: 28/200, score/average: 6.7500/40.4550
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -0.05/-0.0127. Done: 0
#  Mean Policy loss: 39.9265. Mean Value loss: -9.9896
# Episode: 29/200, score/average: 30.1000/38.0500
#
# Reset
# Steps: 147/200. Action: 1. Reward/Value: 1.0/-0.0672. Done: 100
#  Mean Policy loss: 113.3548. Mean Value loss: -17.1535
# Episode: 30/200, score/average: 57.1500/36.9500 SAVING
#
# Reset
# Steps: 198/200. Action: 4. Reward/Value: 0.2/0.1208. Done: -1 0
#  Mean Policy loss: 20.9020. Mean Value loss: -5.2849
# Episode: 31/200, score/average: 14.9500/35.7000
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -0.2/-0.086. Done: 000
#  Mean Policy loss: 84.2429. Mean Value loss: -10.3665
# Episode: 32/200, score/average: 42.9000/35.6350
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: 0.2/0.0315. Done: 0000
#  Mean Policy loss: 20.0581. Mean Value loss: -8.0803
# Episode: 33/200, score/average: 25.5500/33.0900
#
# Reset
# Steps: 183/200. Action: 5. Reward/Value: 0.6/-0.0724. Done: -10
#  Mean Policy loss: 39.1611. Mean Value loss: -9.0751
# Episode: 34/200, score/average: 30.3000/33.6600
#
# Reset
# Steps: 163/200. Action: 6. Reward/Value: 1.0/0.0208. Done: -100
#  Mean Policy loss: 88.5681. Mean Value loss: -14.8412
# Episode: 35/200, score/average: 39.7000/32.3900
#
# Reset
# Steps: 182/200. Action: 6. Reward/Value: -0.45/-0.1083. Done: -1
#  Mean Policy loss: 24.0070. Mean Value loss: -6.4478
# Episode: 36/200, score/average: 17.0500/32.2950
#
# Reset
# Steps: 190/200. Action: 1. Reward/Value: 1.4/0.1269. Done: -100
#  Mean Policy loss: 172.9919. Mean Value loss: -15.4837
# Episode: 37/200, score/average: 51.6500/31.6100
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: 0.35/0.0296. Done: 000
#  Mean Policy loss: 98.4665. Mean Value loss: -10.9998
# Episode: 38/200, score/average: 37.1000/34.6450
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: 0.2/-0.0632. Done: 000
#  Mean Policy loss: 92.7959. Mean Value loss: -12.9117
# Episode: 39/200, score/average: 37.7500/35.4100
#
# Reset
# Steps: 194/200. Action: 4. Reward/Value: 1.0/-0.2273. Done: -10
#  Mean Policy loss: 28.4226. Mean Value loss: -1.4824
# Episode: 40/200, score/average: 6.3500/30.3300 SAVING
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -0.05/-0.0276. Done: 0
#  Mean Policy loss: 128.0520. Mean Value loss: -18.4170
# Episode: 41/200, score/average: 54.2000/34.2550
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: 1.15/0.1106. Done: 0 0
#  Mean Policy loss: 66.6637. Mean Value loss: -14.4714
# Episode: 42/200, score/average: 44.3500/34.4000
#
# Reset
# Steps: 192/200. Action: 6. Reward/Value: 1.0/0.1111. Done: -100
#  Mean Policy loss: 66.5276. Mean Value loss: -9.1609
# Episode: 43/200, score/average: 36.4500/35.4900
#
# Reset
# Steps: 187/200. Action: 4. Reward/Value: 0.6/-0.0726. Done: -10
#  Mean Policy loss: 264.4099. Mean Value loss: -29.8605
# Episode: 44/200, score/average: 93.5000/41.8100
#
# Reset
# Steps: 188/200. Action: 6. Reward/Value: 1.0/-0.0378. Done: 100
#  Mean Policy loss: 423.9022. Mean Value loss: -37.8064
# Episode: 45/200, score/average: 107.6000/48.6000 SAVING
#
# Reset
# Steps: 187/200. Action: 6. Reward/Value: 1.15/0.0806. Done: -10
#  Mean Policy loss: 337.8297. Mean Value loss: -33.4649
# Episode: 46/200, score/average: 99.1000/56.8050 SAVING
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: 0.35/0.079. Done: 00 0
#  Mean Policy loss: 108.2788. Mean Value loss: -16.1897
# Episode: 47/200, score/average: 51.3000/56.7700
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: 0.2/0.065. Done: 00000
#  Mean Policy loss: 182.2986. Mean Value loss: -22.6544
# Episode: 48/200, score/average: 67.3000/59.7900 SAVING
#
# Reset
# Steps: 173/200. Action: 3. Reward/Value: 1.0/0.0866. Done: -100
#  Mean Policy loss: 65.5186. Mean Value loss: -12.7012
# Episode: 49/200, score/average: 32.4000/59.2550
#
# Reset
# Steps: 180/200. Action: 4. Reward/Value: 1.4/0.107. Done: -10 0
#  Mean Policy loss: 297.5729. Mean Value loss: -27.9768
# Episode: 50/200, score/average: 82.1000/66.8300 SAVING
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: 0.2/0.0668. Done: 00 0
#  Mean Policy loss: 78.6902. Mean Value loss: -12.4112
# Episode: 51/200, score/average: 41.5000/65.5600
#
# Reset
# Steps: 197/200. Action: 3. Reward/Value: 1.15/-0.0066. Done: -1
#  Mean Policy loss: 87.9878. Mean Value loss: -15.1798
# Episode: 52/200, score/average: 45.8000/65.7050
#
# Reset
# Steps: 199/200. Action: 5. Reward/Value: 1.4/0.119. Done: -100
#  Mean Policy loss: 66.7122. Mean Value loss: -12.4816
# Episode: 53/200, score/average: 43.0500/66.3650
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -0.05/-0.0739. Done: 0
#  Mean Policy loss: 90.9283. Mean Value loss: -15.2362
# Episode: 54/200, score/average: 46.4500/61.6600
#
# Reset
# Steps: 169/200. Action: 6. Reward/Value: 1.4/0.0921. Done: -1 0
#  Mean Policy loss: 71.6488. Mean Value loss: -12.2525
# Episode: 55/200, score/average: 33.8000/54.2800
#
# Reset
# Steps: 174/200. Action: 2. Reward/Value: 0.75/0.0139. Done: -10
#  Mean Policy loss: 103.8631. Mean Value loss: -15.3920
# Episode: 56/200, score/average: 46.6500/49.0350
#
# Reset
# Steps: 182/200. Action: 4. Reward/Value: -0.45/-0.1236. Done: -1
#  Mean Policy loss: 14.7296. Mean Value loss: -4.9122
# Episode: 57/200, score/average: 13.6500/45.2700
#
# Reset
# Steps: 180/200. Action: 2. Reward/Value: -0.45/-0.0618. Done: -1
#  Mean Policy loss: 101.2925. Mean Value loss: -18.4913
# Episode: 58/200, score/average: 55.7000/44.1100
#
# Reset
# Steps: 179/200. Action: 4. Reward/Value: -0.2/-0.0012. Done: -1
#  Mean Policy loss: 99.5113. Mean Value loss: -17.7281
# Episode: 59/200, score/average: 56.6000/46.5300
#
# Reset
# Steps: 175/200. Action: 6. Reward/Value: 0.75/-0.0463. Done: -1
#  Mean Policy loss: 159.8741. Mean Value loss: -23.5113
# Episode: 60/200, score/average: 69.0000/45.2200 SAVING
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -0.2/-0.0422. Done: 00
#  Mean Policy loss: 151.9211. Mean Value loss: -21.4603
# Episode: 61/200, score/average: 70.6000/48.1300
#
# Reset
# Steps: 188/200. Action: 5. Reward/Value: 0.75/-0.0597. Done: -1
#  Mean Policy loss: 152.5761. Mean Value loss: -22.2716
# Episode: 62/200, score/average: 75.9000/51.1400
#
# Reset
# Steps: 194/200. Action: 2. Reward/Value: 1.15/-0.0504. Done: 10
#  Mean Policy loss: 209.1151. Mean Value loss: -26.2886
# Episode: 63/200, score/average: 79.9000/54.8250
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: 1.0/0.0884. Done: 1000
#  Mean Policy loss: 287.0594. Mean Value loss: -29.3602
# Episode: 64/200, score/average: 97.9000/59.9700
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -0.05/0.0447. Done: 00
#  Mean Policy loss: 242.9512. Mean Value loss: -27.1870
# Episode: 65/200, score/average: 82.5500/64.8450
#
# Reset
# Steps: 159/200. Action: 1. Reward/Value: 0.6/-0.0379. Done: -10
#  Mean Policy loss: 169.9057. Mean Value loss: -18.3344
# Episode: 66/200, score/average: 47.0500/64.8850
#
# Reset
# Steps: 169/200. Action: 2. Reward/Value: 0.75/0.023. Done: -100
#  Mean Policy loss: 95.4096. Mean Value loss: -15.1727
# Episode: 67/200, score/average: 45.1500/68.0350 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: 0.9/0.0462. Done: 0000
#  Mean Policy loss: 203.5977. Mean Value loss: -25.7480
# Episode: 68/200, score/average: 82.7500/70.7400 SAVING
#
# Reset
# Steps: 178/200. Action: 0. Reward/Value: 2.2/0.119. Done: 100 0
#  Mean Policy loss: 124.2148. Mean Value loss: -19.8688
# Episode: 69/200, score/average: 52.5500/70.3350
#
# Reset
# Steps: 183/200. Action: 3. Reward/Value: 1.0/0.0128. Done: -100
#  Mean Policy loss: 72.9957. Mean Value loss: -12.5662
# Episode: 70/200, score/average: 40.2500/67.4600 SAVING
#
# Reset
# Steps: 196/200. Action: 2. Reward/Value: 0.2/0.0982. Done: 10 0
#  Mean Policy loss: 66.9405. Mean Value loss: -12.6513
# Episode: 71/200, score/average: 37.8500/64.1850
#
# Reset
# Steps: 192/200. Action: 1. Reward/Value: 0.75/-0.0122. Done: -1
#  Mean Policy loss: 80.0828. Mean Value loss: -14.5870
# Episode: 72/200, score/average: 44.3500/61.0300
#
# Reset
# Steps: 183/200. Action: 1. Reward/Value: 0.75/-0.0679. Done: -1
#  Mean Policy loss: 171.0218. Mean Value loss: -18.3663
# Episode: 73/200, score/average: 61.1000/59.1500
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: 0.35/0.1442. Done: 000
#  Mean Policy loss: 120.0260. Mean Value loss: -15.2940
# Episode: 74/200, score/average: 57.0000/55.0600
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -0.2/-0.1036. Done: 00
#  Mean Policy loss: 12.8473. Mean Value loss: -3.7505
# Episode: 75/200, score/average: 12.3000/48.0350
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -0.05/-0.067. Done: 00
#  Mean Policy loss: 126.7664. Mean Value loss: -16.0921
# Episode: 76/200, score/average: 52.2000/48.5500
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -0.05/-0.0581. Done: 0
#  Mean Policy loss: 62.4535. Mean Value loss: -11.5270
# Episode: 77/200, score/average: 36.5500/47.6900
#
# Reset
# Steps: 164/200. Action: 2. Reward/Value: 0.6/-0.1348. Done: -10
#  Mean Policy loss: 217.1607. Mean Value loss: -25.7611
# Episode: 78/200, score/average: 64.2000/45.8350
#
# Reset
# Steps: 194/200. Action: 1. Reward/Value: -0.6/-0.1268. Done: -1
#  Mean Policy loss: 67.3504. Mean Value loss: -13.7655
# Episode: 79/200, score/average: 43.3000/44.9100
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -0.05/-0.051. Done: 00
#  Mean Policy loss: 250.9053. Mean Value loss: -26.7876
# Episode: 80/200, score/average: 82.8500/49.1700 SAVING
#
# Reset
# Steps: 166/200. Action: 2. Reward/Value: 1.0/0.0345. Done: -100
#  Mean Policy loss: 37.7742. Mean Value loss: -10.4084
# Episode: 81/200, score/average: 28.4500/48.2300
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: 0.35/0.1048. Done: 000
#  Mean Policy loss: 17.6020. Mean Value loss: -3.1149
# Episode: 82/200, score/average: 7.9500/44.5900
#
# Reset
# Steps: 196/200. Action: 4. Reward/Value: 1.0/0.0401. Done: -10
#  Mean Policy loss: 205.6142. Mean Value loss: -21.7740
# Episode: 83/200, score/average: 69.5000/45.4300
#
# Reset
# Steps: 195/200. Action: 0. Reward/Value: 0.75/-0.0322. Done: -1
#  Mean Policy loss: 111.1525. Mean Value loss: -19.8198
# Episode: 84/200, score/average: 63.0000/46.0300
#
# Reset
# Steps: 180/200. Action: 6. Reward/Value: -0.05/0.0588. Done: 10
#  Mean Policy loss: 146.4651. Mean Value loss: -20.8363
# Episode: 85/200, score/average: 61.0000/50.9000
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -0.2/-0.011. Done: 00
#  Mean Policy loss: 267.2375. Mean Value loss: -21.6880
# Episode: 86/200, score/average: 66.7500/52.3550
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -0.05/-0.0299. Done: 0
#  Mean Policy loss: 280.7257. Mean Value loss: -29.9068
# Episode: 87/200, score/average: 96.6500/58.3650
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: 0.75/0.0036. Done: 000
#  Mean Policy loss: 258.2196. Mean Value loss: -26.9368
# Episode: 88/200, score/average: 90.3000/60.9750
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: 0.6/0.1696. Done: 00 0
#  Mean Policy loss: 106.5440. Mean Value loss: -17.5256
# Episode: 89/200, score/average: 53.6500/62.0100
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.2/-0.1043. Done: 00
#  Mean Policy loss: 123.9439. Mean Value loss: -20.5370
# Episode: 90/200, score/average: 62.5000/59.9750 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: 1.15/0.1106. Done: -1
#  Mean Policy loss: 157.9021. Mean Value loss: -23.3686
# Episode: 91/200, score/average: 71.1000/64.2400
#
# Reset
# Steps: 188/200. Action: 6. Reward/Value: 0.75/-0.0414. Done: -1
#  Mean Policy loss: 302.0941. Mean Value loss: -27.5929
# Episode: 92/200, score/average: 79.0000/71.3450 SAVING
#
# Reset
# Steps: 190/200. Action: 5. Reward/Value: 0.75/0.0737. Done: -10
#  Mean Policy loss: 109.4498. Mean Value loss: -16.3341
# Episode: 93/200, score/average: 48.2500/69.2200
#
# Reset
# Steps: 147/200. Action: 1. Reward/Value: 1.0/0.0367. Done: -100
#  Mean Policy loss: 87.9301. Mean Value loss: -13.2625
# Episode: 94/200, score/average: 46.9500/67.6150
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: 0.2/0.0304. Done: 0000
#  Mean Policy loss: 120.1430. Mean Value loss: -19.1809
# Episode: 95/200, score/average: 57.1500/67.2300
#
# Reset
# Steps: 161/200. Action: 3. Reward/Value: -0.2/0.1122. Done: -1
#  Mean Policy loss: 144.4311. Mean Value loss: -18.4719
# Episode: 96/200, score/average: 50.3000/65.5850
#
# Reset
# Steps: 147/200. Action: 2. Reward/Value: 1.0/0.0634. Done: -10
#  Mean Policy loss: 212.1724. Mean Value loss: -17.2703
# Episode: 97/200, score/average: 59.0500/61.8250
#
# Reset
# Steps: 198/200. Action: 6. Reward/Value: 0.75/0.0587. Done: -10
#  Mean Policy loss: 99.5496. Mean Value loss: -13.3684
# Episode: 98/200, score/average: 46.9500/57.4900
#
# Reset
# Steps: 155/200. Action: 3. Reward/Value: 0.75/0.0747. Done: -10
#  Mean Policy loss: 70.6648. Mean Value loss: -15.8480
# Episode: 99/200, score/average: 37.8000/55.9050
#
# Reset
# Steps: 168/200. Action: 2. Reward/Value: 0.6/0.0348. Done: -100
#  Mean Policy loss: 212.4361. Mean Value loss: -28.4401
# Episode: 100/200, score/average: 78.4500/57.5000 SAVING
#
# Reset
# Steps: 179/200. Action: 3. Reward/Value: -0.05/-0.0587. Done: 1
#  Mean Policy loss: 187.9435. Mean Value loss: -23.0502
# Episode: 101/200, score/average: 66.2000/57.0100
#
# Reset
# Steps: 162/200. Action: 2. Reward/Value: 1.4/0.1058. Done: 1000
#  Mean Policy loss: 76.1412. Mean Value loss: -15.7237
# Episode: 102/200, score/average: 38.8000/52.9900
#
# Reset
# Steps: 139/200. Action: 3. Reward/Value: 1.15/0.1463. Done: -10
#  Mean Policy loss: 107.5795. Mean Value loss: -12.3164
# Episode: 103/200, score/average: 37.7000/51.9350
#
# Reset
# Steps: 163/200. Action: 6. Reward/Value: 1.0/0.0034. Done: -1 0
#  Mean Policy loss: 470.6614. Mean Value loss: -30.2712
# Episode: 104/200, score/average: 92.2500/56.4650
#
# Reset
# Steps: 158/200. Action: 2. Reward/Value: -0.2/-0.0154. Done: 10
#  Mean Policy loss: 212.0622. Mean Value loss: -25.0904
# Episode: 105/200, score/average: 65.1000/57.2600
#
# Reset
# Steps: 183/200. Action: 5. Reward/Value: 1.0/0.0254. Done: -1 0
#  Mean Policy loss: 57.0660. Mean Value loss: -12.6048
# Episode: 106/200, score/average: 32.4500/55.4750
#
# Reset
# Steps: 152/200. Action: 3. Reward/Value: 1.15/0.1023. Done: -10
#  Mean Policy loss: 173.8846. Mean Value loss: -24.7927
# Episode: 107/200, score/average: 60.3500/55.6050
#
# Reset
# Steps: 152/200. Action: 4. Reward/Value: 1.0/0.0921. Done: -100
#  Mean Policy loss: 330.8799. Mean Value loss: -34.6717
# Episode: 108/200, score/average: 84.2500/59.3350
#
# Reset
# Steps: 163/200. Action: 1. Reward/Value: 0.6/-0.1003. Done: -10
#  Mean Policy loss: 98.2617. Mean Value loss: -18.1471
# Episode: 109/200, score/average: 46.9500/60.2500
#
# Reset
# Steps: 168/200. Action: 1. Reward/Value: 1.4/0.1695. Done: -100
#  Mean Policy loss: 149.3154. Mean Value loss: -20.8125
# Episode: 110/200, score/average: 53.6500/57.7700 SAVING
#
# Reset
# Steps: 165/200. Action: 5. Reward/Value: 0.2/0.0325. Done: 100
#  Mean Policy loss: 170.8071. Mean Value loss: -25.0366
# Episode: 111/200, score/average: 67.8500/57.9350
#
# Reset
# Steps: 167/200. Action: 5. Reward/Value: 0.75/0.0721. Done: -10
#  Mean Policy loss: 285.4003. Mean Value loss: -28.8795
# Episode: 112/200, score/average: 76.1000/61.6650
#
# Reset
# Steps: 135/200. Action: 1. Reward/Value: 0.6/0.1641. Done: 10 0
#  Mean Policy loss: 53.3117. Mean Value loss: -11.4088
# Episode: 113/200, score/average: 35.0500/61.4000
#
# Reset
# Steps: 183/200. Action: 3. Reward/Value: 2.2/0.1915. Done: -1 0
#  Mean Policy loss: 321.1531. Mean Value loss: -26.8505
# Episode: 114/200, score/average: 81.0500/60.2800
#
# Reset
# Steps: 141/200. Action: 2. Reward/Value: 1.0/0.0059. Done: -100
#  Mean Policy loss: 128.1033. Mean Value loss: -17.5769
# Episode: 115/200, score/average: 59.1500/59.6850
#
# Reset
# Steps: 173/200. Action: 1. Reward/Value: 1.4/0.0455. Done: 10 0
#  Mean Policy loss: 160.4149. Mean Value loss: -24.7987
# Episode: 116/200, score/average: 67.2000/63.1600
#
# Reset
# Steps: 158/200. Action: 6. Reward/Value: 0.75/-0.0481. Done: -1
#  Mean Policy loss: 70.9272. Mean Value loss: -15.2566
# Episode: 117/200, score/average: 41.4500/61.2700
#
# Reset
# Steps: 139/200. Action: 2. Reward/Value: -0.2/-0.1971. Done: -1
#  Mean Policy loss: 424.6021. Mean Value loss: -32.3791
# Episode: 118/200, score/average: 105.8500/63.4300
#
# Reset
# Steps: 141/200. Action: 2. Reward/Value: 0.75/-0.0022. Done: -1
#  Mean Policy loss: 203.3583. Mean Value loss: -19.4262
# Episode: 119/200, score/average: 64.0500/65.1400
#
# Reset
# Steps: 157/200. Action: 2. Reward/Value: 1.0/0.1269. Done: -100
#  Mean Policy loss: 654.1513. Mean Value loss: -39.6230
# Episode: 120/200, score/average: 97.6500/69.5400 SAVING
#
# Reset
# Steps: 157/200. Action: 2. Reward/Value: 1.0/0.093. Done: -1000
#  Mean Policy loss: 143.7249. Mean Value loss: -21.0671
# Episode: 121/200, score/average: 53.6500/68.1200
#
# Reset
# Steps: 142/200. Action: 6. Reward/Value: 1.15/0.1285. Done: -10
#  Mean Policy loss: 205.0045. Mean Value loss: -22.1804
# Episode: 122/200, score/average: 66.4000/67.1500
#
# Reset
# Steps: 176/200. Action: 2. Reward/Value: 1.8/0.0735. Done: -1 0
#  Mean Policy loss: 321.8753. Mean Value loss: -29.6758
# Episode: 123/200, score/average: 79.2000/71.5650 SAVING
#
# Reset
# Steps: 149/200. Action: 2. Reward/Value: 1.0/0.1013. Done: -10
#  Mean Policy loss: 158.1380. Mean Value loss: -18.8430
# Episode: 124/200, score/average: 63.6000/69.8200
#
# Reset
# Steps: 140/200. Action: 1. Reward/Value: 0.6/-0.0895. Done: -10
#  Mean Policy loss: 207.4526. Mean Value loss: -22.0883
# Episode: 125/200, score/average: 62.7000/70.1750
#
# Reset
# Steps: 164/200. Action: 4. Reward/Value: 0.75/-0.0966. Done: -1
#  Mean Policy loss: 244.3885. Mean Value loss: -28.8577
# Episode: 126/200, score/average: 75.4000/70.9950
#
# Reset
# Steps: 150/200. Action: 5. Reward/Value: 0.2/-0.083. Done: 1 00
#  Mean Policy loss: 130.9132. Mean Value loss: -17.3260
# Episode: 127/200, score/average: 56.4500/72.4950 SAVING
#
# Reset
# Steps: 161/200. Action: 5. Reward/Value: -0.05/0.0625. Done: 1
#  Mean Policy loss: 214.6336. Mean Value loss: -27.3792
# Episode: 128/200, score/average: 75.0500/69.4150
#
# Reset
# Steps: 150/200. Action: 3. Reward/Value: 0.75/-0.0871. Done: -1
#  Mean Policy loss: 83.5296. Mean Value loss: -12.4230
# Episode: 129/200, score/average: 38.8000/66.8900
#
# Reset
# Steps: 138/200. Action: 5. Reward/Value: 1.15/0.055. Done: -1 0
#  Mean Policy loss: 122.1794. Mean Value loss: -16.1266
# Episode: 130/200, score/average: 46.7500/61.8000 SAVING
#
# Reset
# Steps: 147/200. Action: 2. Reward/Value: 1.0/0.0583. Done: -1
#  Mean Policy loss: 155.9757. Mean Value loss: -18.0398
# Episode: 131/200, score/average: 60.5000/62.4850
#
# Reset
# Steps: 163/200. Action: 1. Reward/Value: -0.05/0.0056. Done: 10
#  Mean Policy loss: 176.7249. Mean Value loss: -25.0846
# Episode: 132/200, score/average: 67.7000/62.6150
#
# Reset
# Steps: 136/200. Action: 0. Reward/Value: 0.9/0.0799. Done: -1 0
#  Mean Policy loss: 51.7716. Mean Value loss: -10.3912
# Episode: 133/200, score/average: 33.5000/58.0450
#
# Reset
# Steps: 155/200. Action: 4. Reward/Value: 1.15/0.0639. Done: 1 0
#  Mean Policy loss: 433.4780. Mean Value loss: -36.0310
# Episode: 134/200, score/average: 88.1500/60.5000
#
# Reset
# Steps: 140/200. Action: 3. Reward/Value: 1.15/0.1093. Done: -10
#  Mean Policy loss: 113.9078. Mean Value loss: -17.0418
# Episode: 135/200, score/average: 49.0500/59.1350
#
# Reset
# Steps: 134/200. Action: 6. Reward/Value: 1.4/0.1095. Done: 10 0
#  Mean Policy loss: 110.2913. Mean Value loss: -16.9998
# Episode: 136/200, score/average: 55.0500/57.1000
#
# Reset
# Steps: 152/200. Action: 1. Reward/Value: 1.15/0.1017. Done: -10
#  Mean Policy loss: 119.3090. Mean Value loss: -18.5913
# Episode: 137/200, score/average: 51.6500/56.6200
#
# Reset
# Steps: 135/200. Action: 6. Reward/Value: 0.2/0.0967. Done: 100
#  Mean Policy loss: 193.2786. Mean Value loss: -22.1050
# Episode: 138/200, score/average: 62.5500/55.3700
#
# Reset
# Steps: 172/200. Action: 4. Reward/Value: 1.15/0.0987. Done: -10
#  Mean Policy loss: 168.1908. Mean Value loss: -22.8482
# Episode: 139/200, score/average: 65.8000/58.0700
#
# Reset
# Steps: 151/200. Action: 5. Reward/Value: 1.0/0.1369. Done: -10
#  Mean Policy loss: 242.6925. Mean Value loss: -28.1539
# Episode: 140/200, score/average: 71.0500/60.5000 SAVING
#
# Reset
# Steps: 146/200. Action: 6. Reward/Value: 0.75/-0.0458. Done: -1
#  Mean Policy loss: 183.8714. Mean Value loss: -22.3073
# Episode: 141/200, score/average: 76.5500/62.1050
#
# Reset
# Steps: 144/200. Action: 2. Reward/Value: 2.2/0.0465. Done: 10
#  Mean Policy loss: 206.9140. Mean Value loss: -21.0668
# Episode: 142/200, score/average: 60.0500/61.3400
#
# Reset
# Steps: 149/200. Action: 2. Reward/Value: 0.75/-0.0467. Done: -1
#  Mean Policy loss: 109.8746. Mean Value loss: -14.8707
# Episode: 143/200, score/average: 48.7500/62.8650
#
# Reset
# Steps: 158/200. Action: 1. Reward/Value: 0.2/0.0314. Done: 10 0
#  Mean Policy loss: 249.2019. Mean Value loss: -27.5132
# Episode: 144/200, score/average: 65.1500/60.5650
#
# Reset
# Steps: 156/200. Action: 6. Reward/Value: 1.15/0.1278. Done: -10
#  Mean Policy loss: 223.9300. Mean Value loss: -27.0338
# Episode: 145/200, score/average: 65.6500/62.2250
#
# Reset
# Steps: 172/200. Action: 2. Reward/Value: -0.05/-0.0779. Done: 1
#  Mean Policy loss: 553.2521. Mean Value loss: -43.8274
# Episode: 146/200, score/average: 117.6000/68.4800
#
# Reset
# Steps: 129/200. Action: 6. Reward/Value: 1.0/0.0155. Done: 100
#  Mean Policy loss: 229.7838. Mean Value loss: -23.5740
# Episode: 147/200, score/average: 64.4000/69.7550
#
# Reset
# Steps: 172/200. Action: 2. Reward/Value: 0.9/0.0299. Done: -100
#  Mean Policy loss: 390.9411. Mean Value loss: -34.9491
# Episode: 148/200, score/average: 95.9500/73.0950 SAVING
#
# Reset
# Steps: 136/200. Action: 2. Reward/Value: 2.2/0.0244. Done: -1
#  Mean Policy loss: 156.0401. Mean Value loss: -21.4750
# Episode: 149/200, score/average: 61.0000/72.6150
#
# Reset
# Steps: 139/200. Action: 2. Reward/Value: 1.8/0.0443. Done: -100
#  Mean Policy loss: 197.1762. Mean Value loss: -22.8723
# Episode: 150/200, score/average: 66.5500/72.1650 SAVING
#
# Reset
# Steps: 154/200. Action: 3. Reward/Value: 1.4/0.1559. Done: 1000
#  Mean Policy loss: 58.8329. Mean Value loss: -14.3588
# Episode: 151/200, score/average: 36.4500/68.1550
#
# Reset
# Steps: 155/200. Action: 2. Reward/Value: 0.6/0.155. Done: 100 0
#  Mean Policy loss: 101.8369. Mean Value loss: -18.9500
# Episode: 152/200, score/average: 47.6500/66.9150
#
# Reset
# Steps: 176/200. Action: 1. Reward/Value: 1.0/-0.011. Done: -1 0
#  Mean Policy loss: 433.0279. Mean Value loss: -39.3444
# Episode: 153/200, score/average: 105.2500/72.5650
#
# Reset
# Steps: 185/200. Action: 3. Reward/Value: 0.75/-0.1295. Done: -1
#  Mean Policy loss: 183.4515. Mean Value loss: -25.6420
# Episode: 154/200, score/average: 77.1500/73.7650 SAVING
#
# Reset
# Steps: 137/200. Action: 5. Reward/Value: 1.15/0.0976. Done: -10
#  Mean Policy loss: 158.0606. Mean Value loss: -18.9639
# Episode: 155/200, score/average: 55.1000/72.7100
#
# Reset
# Steps: 173/200. Action: 1. Reward/Value: 0.6/0.1148. Done: 10 0
#  Mean Policy loss: 182.7785. Mean Value loss: -19.6074
# Episode: 156/200, score/average: 49.6500/65.9150
#
# Reset
# Steps: 135/200. Action: 6. Reward/Value: 1.8/0.0771. Done: -10
#  Mean Policy loss: 238.3482. Mean Value loss: -23.9152
# Episode: 157/200, score/average: 69.8000/66.4550
#
# Reset
# Steps: 175/200. Action: 2. Reward/Value: 1.0/0.0358. Done: -1 0
#  Mean Policy loss: 220.3774. Mean Value loss: -23.2237
# Episode: 158/200, score/average: 64.8500/63.3450
#
# Reset
# Steps: 173/200. Action: 2. Reward/Value: 0.75/-0.0335. Done: -1
#  Mean Policy loss: 209.2005. Mean Value loss: -23.5361
# Episode: 159/200, score/average: 60.6500/63.3100
#
# Reset
# Steps: 141/200. Action: 3. Reward/Value: 0.2/0.0225. Done: 10 0
#  Mean Policy loss: 195.2557. Mean Value loss: -21.9860
# Episode: 160/200, score/average: 69.3500/63.5900 SAVING
#
# Reset
# Steps: 155/200. Action: 1. Reward/Value: 2.2/0.0572. Done: -10
#  Mean Policy loss: 112.4298. Mean Value loss: -20.1809
# Episode: 161/200, score/average: 52.1000/65.1550
#
# Reset
# Steps: 138/200. Action: 2. Reward/Value: 3.0/0.0531. Done: 10 0
#  Mean Policy loss: 133.1162. Mean Value loss: -17.6774
# Episode: 162/200, score/average: 49.7500/65.3650
#
# Reset
# Steps: 149/200. Action: 3. Reward/Value: 0.6/-0.0783. Done: -1
#  Mean Policy loss: 262.1633. Mean Value loss: -22.0417
# Episode: 163/200, score/average: 68.1500/61.6550
#
# Reset
# Steps: 143/200. Action: 4. Reward/Value: 1.0/0.1091. Done: -100
#  Mean Policy loss: 51.2216. Mean Value loss: -10.8790
# Episode: 164/200, score/average: 32.5500/57.1950
#
# Reset
# Steps: 162/200. Action: 4. Reward/Value: 1.8/-0.0434. Done: -10
#  Mean Policy loss: 91.4802. Mean Value loss: -16.8940
# Episode: 165/200, score/average: 42.3500/55.9200
#
# Reset
# Steps: 145/200. Action: 1. Reward/Value: 0.2/0.1494. Done: -10
#  Mean Policy loss: 95.2590. Mean Value loss: -11.8779
# Episode: 166/200, score/average: 40.4500/55.0000
#
# Reset
# Steps: 163/200. Action: 4. Reward/Value: -0.6/-0.0689. Done: -1
#  Mean Policy loss: 288.4037. Mean Value loss: -31.9945
# Episode: 167/200, score/average: 91.7500/57.1950
#
# Reset
# Steps: 166/200. Action: 1. Reward/Value: 1.4/0.1276. Done: -100
#  Mean Policy loss: 25.9989. Mean Value loss: -7.4738
# Episode: 168/200, score/average: 20.0000/52.7100
#
# Reset
# Steps: 172/200. Action: 1. Reward/Value: 0.6/-0.0645. Done: -10
#  Mean Policy loss: 118.6685. Mean Value loss: -17.9016
# Episode: 169/200, score/average: 46.9500/51.3400
#
# Reset
# Steps: 157/200. Action: 1. Reward/Value: 0.75/-0.0434. Done: -1
#  Mean Policy loss: 153.0538. Mean Value loss: -21.2732
# Episode: 170/200, score/average: 50.3500/49.4400 SAVING
#
# Reset
# Steps: 169/200. Action: 2. Reward/Value: -0.05/0.1328. Done: -1
#  Mean Policy loss: 141.6854. Mean Value loss: -20.4220
# Episode: 171/200, score/average: 52.0500/49.4350
#
# Reset
# Steps: 155/200. Action: 4. Reward/Value: 1.0/0.0562. Done: 100
#  Mean Policy loss: 220.8567. Mean Value loss: -27.1032
# Episode: 172/200, score/average: 65.7500/51.0350
#
# Reset
# Steps: 150/200. Action: 4. Reward/Value: 1.0/0.1177. Done: -100
#  Mean Policy loss: 83.4855. Mean Value loss: -14.6592
# Episode: 173/200, score/average: 46.0000/48.8200
#
# Reset
# Steps: 147/200. Action: 5. Reward/Value: 0.2/0.005. Done: 1: 0
#  Mean Policy loss: 155.5777. Mean Value loss: -18.6454
# Episode: 174/200, score/average: 54.7500/51.0400
#
# Reset
# Steps: 159/200. Action: 2. Reward/Value: -0.2/0.0179. Done: -10
#  Mean Policy loss: 77.0016. Mean Value loss: -15.7658
# Episode: 175/200, score/average: 37.0500/50.5100
#
# Reset
# Steps: 128/200. Action: 3. Reward/Value: 0.2/0.0283. Done: 10 0
#  Mean Policy loss: 239.3030. Mean Value loss: -23.2395
# Episode: 176/200, score/average: 63.5000/52.8150
#
# Reset
# Steps: 141/200. Action: 2. Reward/Value: 1.0/0.0241. Done: -1 0
#  Mean Policy loss: 71.3649. Mean Value loss: -12.5731
# Episode: 177/200, score/average: 37.8500/47.4250
#
# Reset
# Steps: 158/200. Action: 3. Reward/Value: 1.0/0.0898. Done: -10
#  Mean Policy loss: 136.4039. Mean Value loss: -20.7609
# Episode: 178/200, score/average: 54.5500/50.8800
#
# Reset
# Steps: 132/200. Action: 1. Reward/Value: 0.6/0.1699. Done: 1000
#  Mean Policy loss: 92.4677. Mean Value loss: -15.4115
# Episode: 179/200, score/average: 42.4500/50.4300
#
# Reset
# Steps: 155/200. Action: 1. Reward/Value: 1.95/0.0643. Done: -10
#  Mean Policy loss: 312.7537. Mean Value loss: -31.8383
# Episode: 180/200, score/average: 91.4500/54.5400 SAVING
#
# Reset
# Steps: 143/200. Action: 3. Reward/Value: 1.4/0.156. Done: 100 0
#  Mean Policy loss: 47.8592. Mean Value loss: -11.1457
# Episode: 181/200, score/average: 33.3000/52.6650
#
# Reset
# Steps: 160/200. Action: 1. Reward/Value: 1.95/0.1211. Done: 1
#  Mean Policy loss: 198.2592. Mean Value loss: -26.0930
# Episode: 182/200, score/average: 64.4500/52.5350
#
# Reset
# Steps: 139/200. Action: 1. Reward/Value: 0.9/0.0186. Done: -100
#  Mean Policy loss: 220.9421. Mean Value loss: -23.1256
# Episode: 183/200, score/average: 66.7000/54.6050
#
# Reset
# Steps: 135/200. Action: 0. Reward/Value: 1.15/0.1144. Done: -10
#  Mean Policy loss: 87.6266. Mean Value loss: -14.4438
# Episode: 184/200, score/average: 43.4500/53.4750
#
# Reset
# Steps: 134/200. Action: 1. Reward/Value: 0.2/0.0116. Done: 1000
#  Mean Policy loss: 98.7418. Mean Value loss: -16.0040
# Episode: 185/200, score/average: 44.6500/54.2350
#
# Reset
# Steps: 153/200. Action: 3. Reward/Value: 1.95/-0.0209. Done: -1
#  Mean Policy loss: 297.4142. Mean Value loss: -30.0506
# Episode: 186/200, score/average: 66.9000/54.5750
#
# Reset
# Steps: 165/200. Action: 6. Reward/Value: 1.4/0.1187. Done: 1000
#  Mean Policy loss: 153.8889. Mean Value loss: -22.0100
# Episode: 187/200, score/average: 56.5000/56.4400
#
# Reset
# Steps: 170/200. Action: 3. Reward/Value: 0.9/0.0503. Done: -100
#  Mean Policy loss: 28.6347. Mean Value loss: -9.4148
# Episode: 188/200, score/average: 25.8500/53.5700
#
# Reset
# Steps: 144/200. Action: 1. Reward/Value: 1.95/0.0459. Done: -1
#  Mean Policy loss: 103.1848. Mean Value loss: -15.5908
# Episode: 189/200, score/average: 47.5500/54.0800
#
# Reset
# Steps: 167/200. Action: 2. Reward/Value: 1.95/0.1194. Done: -1
#  Mean Policy loss: 102.7076. Mean Value loss: -13.6788
# Episode: 190/200, score/average: 33.2000/48.2550 SAVING
#
# Reset
# Steps: 165/200. Action: 2. Reward/Value: 0.75/-0.0465. Done: -1
#  Mean Policy loss: 110.7618. Mean Value loss: -18.4263
# Episode: 191/200, score/average: 45.9000/49.5150
#
# Reset
# Steps: 147/200. Action: 1. Reward/Value: -0.6/-0.0841. Done: -1
#  Mean Policy loss: 54.4781. Mean Value loss: -9.8775
# Episode: 192/200, score/average: 29.8000/46.0500
#
# Reset
# Steps: 160/200. Action: 1. Reward/Value: 1.15/0.1038. Done: -10
#  Mean Policy loss: 30.3890. Mean Value loss: -9.8980
# Episode: 193/200, score/average: 25.7000/41.9500
#
# Reset
# Steps: 148/200. Action: 6. Reward/Value: -0.6/-0.0523. Done: -1
#  Mean Policy loss: 12.9556. Mean Value loss: -3.4054
# Episode: 194/200, score/average: 11.0500/38.7100
#
# Reset
# Steps: 159/200. Action: 2. Reward/Value: 1.15/0.1006. Done: -10
#  Mean Policy loss: 23.3200. Mean Value loss: -8.3654
# Episode: 195/200, score/average: 21.7500/36.4200
#
# Reset
# Steps: 142/200. Action: 1. Reward/Value: 0.9/0.0817. Done: -1 0
#  Mean Policy loss: 36.1744. Mean Value loss: -9.3948
# Episode: 196/200, score/average: 28.0500/32.5350
#
# Reset
# Steps: 146/200. Action: 2. Reward/Value: -0.45/-0.1172. Done: -1
#  Mean Policy loss: 55.5973. Mean Value loss: -11.4131
# Episode: 197/200, score/average: 35.5500/30.4400
#
# Reset
# Steps: 167/200. Action: 2. Reward/Value: -0.3/0.0571. Done: -1
#  Mean Policy loss: 107.2888. Mean Value loss: -15.1572
# Episode: 198/200, score/average: 53.1000/33.1650
#
# Reset
# Steps: 171/200. Action: 1. Reward/Value: 1.4/0.1426. Done: -10
#  Mean Policy loss: 96.3230. Mean Value loss: -16.1363
# Episode: 199/200, score/average: 43.5500/32.7650
#
# Reset
# Steps: 158/200. Action: 1. Reward/Value: 0.2/-0.0592. Done: -10
#  Mean Policy loss: 39.8388. Mean Value loss: -11.7564
# Episode: 200/200, score/average: 28.8500/32.3300 SAVING
# 127.0.0.1 - - [08/Aug/2024 22:44:55] "GET /socket.io/?EIO=4&transport=websocket&sid=CqX7Uhqm7mV3HC4zAAAA HTTP/1.1" 200 0 43368.972407

# %%
agent.load("Models7/auto-docking-iss_PPO__154_73.765.pt")
# Out:
# ./Models7/auto-docking-iss_PPO__154_73.765.pt

# %%
agent.test(500)
# Out:
# Reset
# Steps: 21/500. Action: 1. Score/Value: 1.85/0.1403. Done: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 agent.test(500)
#
# Cell In[5], line 287, in PPO.test(self, max_steps)
#     284         print(f'\rSteps: {step}/{max_steps}. Action: {action}. Score/Value: {round(score,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)
#     285         start = time.time()
# --> 287     if self.env.done:
#     288         break
#     290 state_end = self.env.get_state()
#
# KeyboardInterrupt:
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /socket.io/?EIO=4&transport=websocket&sid=zOKxIUf98W3i70u3AAAA HTTP/1.1" 200 0 1028.438748
# (9363) accepted ('127.0.0.1', 53012)
# (9363) accepted ('127.0.0.1', 53016)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET / HTTP/1.1" 304 242 0.001190
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /css/normalize.css HTTP/1.1" 304 201 0.001020
# (9363) accepted ('127.0.0.1', 53020)
# (9363) accepted ('127.0.0.1', 53030)
# (9363) accepted ('127.0.0.1', 53044)
# (9363) accepted ('127.0.0.1', 53060)
# (9363) accepted ('127.0.0.1', 53066)
# (9363) accepted ('127.0.0.1', 53082)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /css/layout.css HTTP/1.1" 304 198 0.000653
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /js/three/three.js HTTP/1.1" 304 196 0.000588
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /js/three/WebGL.js HTTP/1.1" 304 196 0.000450
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /js/three/GLTFLoader.js HTTP/1.1" 304 201 0.000670
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /js/three/CSS2DRenderer.js HTTP/1.1" 304 204 0.000366
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /js/gsap3/gsap.js HTTP/1.1" 304 195 0.000325
# (9363) accepted ('127.0.0.1', 53084)
# (9363) accepted ('127.0.0.1', 53096)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /js/gsap3/DrawSVGPlugin.js HTTP/1.1" 304 204 0.000336
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /js/gsap3/ScrambleTextPlugin.js HTTP/1.1" 304 209 0.000334
# (9363) accepted ('127.0.0.1', 53108)
# (9363) accepted ('127.0.0.1', 53110)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/hud-darken.png HTTP/1.1" 304 202 0.000623
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/hud-ring.png HTTP/1.1" 304 200 0.000628
# (9363) accepted ('127.0.0.1', 53112)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/hud-ring-inner.png HTTP/1.1" 304 206 0.000515
# (9363) accepted ('127.0.0.1', 53122)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/shadow.png HTTP/1.1" 304 198 0.000422
# (9363) accepted ('127.0.0.1', 53134)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /js/threed.js HTTP/1.1" 304 197 0.000508
# (9363) accepted ('127.0.0.1', 53148)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/instructions/step1_6.jpg HTTP/1.1" 304 199 0.000551
# (9363) accepted ('127.0.0.1', 53160)
# (9363) accepted ('127.0.0.1', 53164)
# (9363) accepted ('127.0.0.1', 53176)
# (9363) accepted ('127.0.0.1', 53192)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/instructions/step2.jpg HTTP/1.1" 304 197 0.000541
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/instructions/step3.jpg HTTP/1.1" 304 197 0.000615
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/instructions/step4.jpg HTTP/1.1" 304 197 0.000446
# (9363) accepted ('127.0.0.1', 53198)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/instructions/step7.jpg HTTP/1.1" 304 197 0.000365
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/instructions/step5.jpg HTTP/1.1" 304 197 0.000565
# (9363) accepted ('127.0.0.1', 53208)
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /socket.io/?EIO=4&transport=polling&t=P4rnTE_ HTTP/1.1" 200 278 0.000438
# 127.0.0.1 - - [09/Aug/2024 08:14:02] "GET /img/hud/ForwardViewSprites.json HTTP/1.1" 304 211 0.000762
# (9363) accepted ('127.0.0.1', 53222)
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /3d/iss.glb HTTP/1.1" 304 195 0.000889
# (9363) accepted ('127.0.0.1', 53238)
# (9363) accepted ('127.0.0.1', 53240)
# (9363) accepted ('127.0.0.1', 53244)
# (9363) accepted ('127.0.0.1', 53260)
# (9363) accepted ('127.0.0.1', 53268)
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /img/earth.jpg HTTP/1.1" 304 197 0.001361
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /img/navball.png HTTP/1.1" 304 199 0.000696
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /img/texture_fire.jpg HTTP/1.1" 304 204 0.000619
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /img/texture_wormhole.jpg HTTP/1.1" 304 208 0.000515
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /img/texture_star.jpg HTTP/1.1" 304 204 0.000535
# (9363) accepted ('127.0.0.1', 53282)
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /img/hud/ForwardViewSprites2.png HTTP/1.1" 304 211 0.000784
# (9363) accepted ('127.0.0.1', 53296)
# (9363) accepted ('127.0.0.1', 53308)
# (9363) accepted ('127.0.0.1', 53322)
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "POST /socket.io/?EIO=4&transport=polling&t=P4rnTJR&sid=w0VzcTP_URgMryDdAAAC HTTP/1.1" 200 219 0.000344
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /socket.io/?EIO=4&transport=polling&t=P4rnTJS&sid=w0VzcTP_URgMryDdAAAC HTTP/1.1" 200 181 0.000111
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /socket.io/?EIO=4&transport=polling&t=P4rnTNQ&sid=w0VzcTP_URgMryDdAAAC HTTP/1.1" 200 181 0.000149
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /socket.io/?EIO=4&transport=polling&t=P4rnTNx&sid=w0VzcTP_URgMryDdAAAC HTTP/1.1" 200 181 0.000228
# 127.0.0.1 - - [09/Aug/2024 08:14:03] "GET /img/favicon.ico HTTP/1.1" 304 199 0.001584
# 127.0.0.1 - - [09/Aug/2024 08:14:04] "GET /img/target-iss.png HTTP/1.1" 304 202 0.001092

# %%
import os
import pyautogui

# Simular pulsación de Ctrl+S
pyautogui.hotkey('ctrl', 's')

os.system('sudo shutdown')
# os.system('sudo shutdown -c')

# %%
import time
from math import sqrt
import matplotlib.pyplot as plt
import random
from env6 import Env
import os
import numpy as np
import torch
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader
from copy import deepcopy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class ExperienceDataset(Dataset):
    def __init__(self, data):
        super().__init__()
        self.data = data

    def __len__(self):
        return len(self.data[0])

    def __getitem__(self, ind):
        return tuple(map(lambda t: t[ind], self.data))

def create_shuffled_dataloader(data, batch_size):
    ds = ExperienceDataset(data)
    return DataLoader(ds, batch_size = batch_size, shuffle = True)

# %%
class PolicyNetwork(torch.nn.Module):
    def __init__(self,state_dims, n_actions):
        super(PolicyNetwork, self).__init__()
        self.actor = torch.nn.Sequential(
            torch.nn.Linear(6, 130),
            torch.nn.Tanh(),
            torch.nn.Linear(130, 88),
            torch.nn.Tanh(),
            torch.nn.Linear(88, 60),
            torch.nn.Tanh(),
            torch.nn.Linear(60, n_actions),
            torch.nn.Softmax(dim=-1)
        )

    def forward(self, x):
        policy = self.actor(x)
        return policy
    

class ValueNetwork(torch.nn.Module):
    def __init__(self,state_dims):
        super(ValueNetwork, self).__init__()
        self.critic = torch.nn.Sequential(
            torch.nn.Linear(6, 130),
            torch.nn.Tanh(),
            torch.nn.Linear(130, 25),
            torch.nn.Tanh(),
            torch.nn.Linear(25, 5),
            torch.nn.Tanh(),
            torch.nn.Linear(5, 1)
        )

    def forward(self, x):
        value = self.critic(x)
        return value
        
def weights_init(m):
    if isinstance(m,torch.nn.Linear):
        m.bias.data.fill_(0)
        torch.nn.init.kaiming_uniform_(m.weight)

def np_to_tensor(x):
    return torch.tensor(x).to(torch.float32)

    
policy_model = PolicyNetwork(state_dims=6, n_actions = 6)
value_model = ValueNetwork(state_dims=6)

# %%
print(policy_model,value_model)
summary(policy_model, input_size=(1, 6))
summary(value_model, input_size=(1, 6))
# Out:
# PolicyNetwork(
#   (actor): Sequential(
#     (0): Linear(in_features=6, out_features=130, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=130, out_features=88, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=88, out_features=60, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=60, out_features=6, bias=True)
#     (7): Softmax(dim=-1)
#   )
# ) ValueNetwork(
#   (critic): Sequential(
#     (0): Linear(in_features=6, out_features=130, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=130, out_features=25, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=25, out_features=5, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=5, out_features=1, bias=True)
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 130]             910
#               Tanh-2               [-1, 1, 130]               0
#             Linear-3                [-1, 1, 88]          11,528
#               Tanh-4                [-1, 1, 88]               0
#             Linear-5                [-1, 1, 60]           5,340
#               Tanh-6                [-1, 1, 60]               0
#             Linear-7                 [-1, 1, 6]             366
#            Softmax-8                 [-1, 1, 6]               0
# ================================================================
# Total params: 18,144
# Trainable params: 18,144
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.07
# Estimated Total Size (MB): 0.07
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 130]             910
#               Tanh-2               [-1, 1, 130]               0
#             Linear-3                [-1, 1, 25]           3,275
#               Tanh-4                [-1, 1, 25]               0
#             Linear-5                 [-1, 1, 5]             130
#               Tanh-6                 [-1, 1, 5]               0
#             Linear-7                 [-1, 1, 1]               6
# ================================================================
# Total params: 4,321
# Trainable params: 4,321
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.02
# ----------------------------------------------------------------

# %%
class PPO:
    def __init__(self, state_dim=6, action_dim=6, policy_lr=0.0005, value_lr=0.001, 
                 gamma=0.99, lam=0.95, beta_s=0.01,epsilon_clip=0.2, value_clip=0.4, 
                 epochs=5,batch_size=50,save_path='Models'):
        
        self.policy_net = PolicyNetwork(state_dim, action_dim).to(device)
        self.value_net = ValueNetwork(state_dim).to(device)
        self.policy_net.apply(weights_init)
        self.value_net.apply(weights_init)

        self.policy_optimizer = torch.optim.Adam(self.policy_net.parameters(), lr=policy_lr)
        self.value_optimizer = torch.optim.Adam(self.value_net.parameters(), lr=value_lr)

        self.gamma = gamma
        self.lamda = lam
        self.epsilon_clip = epsilon_clip
        self.value_clip = value_clip
        self.beta_s = beta_s
        self.epochs = epochs
        self.action_dim = action_dim
        self.batch_size = batch_size

        self.env = Env(port=5555)
        self.env.run()

        self.save_path = save_path
        self.env_name = "auto-docking-iss"

        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
        self.path = str(self.env_name)+'_PPO_'
        self.model_name = os.path.join(self.save_path, self.path)

        self.trajectory = {'states':[],'actions':[], 'rewards':[], 'action_logs':[],
                           'values':[],'done':[]}
        
        self.scores, self.episodes, self.average = [],[],[]
        self.value_loss_mean, self.policy_loss_mean = [], []

    def save(self,episode,score):
        torch.save({
            'actor': self.policy_net.state_dict(),
            'critic': self.value_net.state_dict()
        }, f'./'+ self.model_name + '_' + str(episode) + '_' + str(round(score,4)) + '.pt')

    def load(self,name):
        print(f'./{name}')
        try:
            data = torch.load(f'./{name}')
            self.policy_net.load_state_dict(data['actor'])
            self.value_net.load_state_dict(data['critic'])
        except Exception as e:
            print(e)

    # Función para visualizar la evolución del entrenamiento
    def plot_model(self, score, episode,num_episodes):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-10:]) / len(self.scores[-10:]))
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(1,figsize=(18, 9))
            plt.plot(self.episodes, self.scores, 'b')
            plt.plot(self.episodes, self.average, 'r')
            plt.ylabel('Score', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"scores.png")
            except OSError:
                pass

        return self.average[-1]
    
    def plot_loss(self,episode,num_episodes):        
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(2,figsize=(18, 9))
            plt.plot(self.episodes, self.policy_loss_mean, 'b')
            plt.plot(self.episodes, self.value_loss_mean, 'r')
            plt.ylabel('Loss', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"loss.png")
            except OSError:
                pass
    

    #Almacenamiento de todas las variables que definen una transición para PPO
    def collect_trayectory(self,state,action,action_logs,reward,done,value):
        self.trajectory['states'].append(state)
        self.trajectory['actions'].append(action)
        self.trajectory['rewards'].append(reward)
        self.trajectory['values'].append(value)
        self.trajectory['action_logs'].append(action_logs)
        self.trajectory['done'].append(done)
    
    def clear_trayectory(self):
        for key in self.trajectory.keys():
            self.trajectory[key].clear()
    
    def select_action(self,state):
        action_probs = self.policy_net(state).squeeze().detach()
        dist = torch.distributions.Categorical(action_probs)
        action = dist.sample()
        action_log_probs = dist.log_prob(action)
        
        return action.item(),action_log_probs,dist.entropy().item()

    
    def generalized_advantage_estimation(self,next_state):
        advantages = np.zeros_like(self.trajectory['rewards'])
        last_gae_lambda = 0
        self.trajectory['values'].append(self.value_net(next_state).squeeze().detach())

        for t in reversed(range(len(self.trajectory['rewards']))):
            delta = self.trajectory['rewards'][t]+ self.gamma * self.trajectory['values'][t + 1].item() - self.trajectory['values'][t].item()
            advantages[t] = last_gae_lambda = delta + self.gamma * self.lamda * last_gae_lambda
        
        return np_to_tensor(advantages)


    def learn_from_episode_trajectory(self,next_state):
        self.policy_net.train()
        self.value_net.train()

        states = deepcopy(self.trajectory['states'])
        actions = deepcopy(self.trajectory['actions'])
        # rewards = deepcopy(self.trajectory['rewards'])
        values = deepcopy(self.trajectory['values'])
        action_logs = deepcopy(self.trajectory['action_logs'])
        # done = deepcopy(self.trajectory['done'])

        advantages = self.generalized_advantage_estimation(next_state).to(device)

        # prepare dataloader for policy phase training
        dl = create_shuffled_dataloader([states, actions, action_logs, advantages, values], self.batch_size)

        policy_loss_array = []
        value_loss_array = []

        for i in range(self.epochs):
            for states, actions, action_log, advantages, values in dl:
                #Update policy_net
                new_action_probs = self.policy_net(states).squeeze()
                dist = torch.distributions.Categorical(new_action_probs)

                # print("")
                # print(actions)
                # print(new_action_probs)
                new_action_logs = dist.log_prob(actions)
                entropy = dist.entropy()

                # compute PPO-Clip
                ratios = torch.exp(new_action_logs - action_log)
                surr1 = ratios * advantages
                surr2 = ratios.clamp(1 - self.epsilon_clip, 1 + self.epsilon_clip) * advantages
                policy_loss = -torch.mean(torch.min(surr1, surr2) - self.beta_s * entropy)
                policy_loss_array.append(policy_loss.detach().numpy())

                self.policy_optimizer.zero_grad() # Clean gradients
                policy_loss.mean().backward() # Compute gradients
                self.policy_optimizer.step() #Update weights

                #Update value_net
                new_values = self.value_net(states).squeeze()
                value_clipped = values + (new_values - values).clamp(-self.value_clip, self.value_clip)
                value_loss_1 = (value_clipped.flatten() - advantages) ** 2
                value_loss_2 = (values.flatten() - advantages) ** 2
                value_loss = torch.mean(torch.max(value_loss_1, value_loss_2))
                value_loss_array.append(value_loss.detach().numpy())

                self.value_optimizer.zero_grad() # Clean gradients
                value_loss.backward() # Compute gradients 

        self.value_loss_mean.append(sum(value_loss_array)/self.epochs)
        self.policy_loss_mean.append(sum(policy_loss_array)/self.epochs)

        print(f"\n Mean Policy loss: {self.value_loss_mean[-1]:.4f}. Mean Value loss: {self.policy_loss_mean[-1]:.4f}")
        
        self.policy_net.eval()
        self.value_net.eval()


    # Función para resetear el entorno tras acabar trayectoria
    def reset(self):
        state = self.env.reset()
        return np_to_tensor(self.process_state(state))
    
     # Función para interacción agente-entorno
    def step(self, action):
        next_state, reward, done = self.env.step(action)
        next_state = self.process_state(next_state)
        return np_to_tensor(next_state), reward, done

    def process_state(self,state):
        state_processed = np.array(state)
        state_processed[0] = state_processed[0] / 30 # Position array
        state_processed[1] = state_processed[1] / 3 # Position array
        state_processed[2] = state_processed[2] / 3 # Position array
        return state_processed
    
    def train(self,num_episodes=200,max_steps=200):
        average = 0
        self.policy_net.eval()
        self.value_net.eval()

        max_score_average = -5000

        for episode in range(1,num_episodes+1):
            self.clear_trayectory()

            state = self.reset()
            score = 0

            SAVING = ""

            for step in range(1,max_steps+1):
                
                action_probs = self.policy_net(state).squeeze().detach()
                dist = torch.distributions.Categorical(action_probs)
                action = dist.sample()
                action_log = dist.log_prob(action)

                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action.item())    
                self.collect_trayectory(state,action,action_log,reward,done,value)

                state = next_state

                score += reward

                # print(state)
                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Reward/Value: {round(reward,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)

                if done:
                    break
                
                time.sleep(1.0)

            self.learn_from_episode_trajectory(next_state)
            self.clear_trayectory()

            average = self.plot_model(score, episode,num_episodes)
            self.plot_loss(episode,num_episodes)
            
            if average >= max_score_average and episode > 5:
                max_score_average = average
                self.save(episode,average)
                SAVING = "SAVING"
            elif episode % 10 == 0:
                self.save(episode,average)
                SAVING = "SAVING"
            else:
                SAVING = ""
            
            print(f"Episode: {episode}/{num_episodes}, score/average: {score:.4f}/{average:.4f} {SAVING}\n")


        # close environemnt when finish training
        self.save(episode,average)

    def test(self,max_steps):
        self.policy_net.eval()
        self.value_net.eval()

        self.clear_trayectory()
        state = self.reset()
        score = 0

        start = time.time()
        end = time.time()
        step = 0

        while True:
            end = time.time()
            if end - start >= 1.0:
                step += 1
                action_probabilities = self.policy_net(state)
                action = torch.argmax(action_probabilities, dim=-1).item()#np.argmax(self.policy_net(state).squeeze().detach().numpy())
                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action)    

                state = next_state

                score += reward

                # print(action_probabilities)
                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Score/Value: {round(score,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)
                start = time.time()

            if self.env.done or step > max_steps:
                break

        state_end = self.env.get_state()
        
        print(f'\nNext state: {state_end}')

# %%
agent = PPO(save_path='Models9')
# Out:
# (22849) wsgi starting up on http://127.0.0.1:5555
# (22849) accepted ('127.0.0.1', 56210)
# (22849) accepted ('127.0.0.1', 56216)
# 127.0.0.1 - - [09/Aug/2024 13:11:30] "GET / HTTP/1.1" 304 243 0.004646
# 127.0.0.1 - - [09/Aug/2024 13:11:31] "GET /css/normalize.css HTTP/1.1" 304 201 0.000868
# (22849) accepted ('127.0.0.1', 56222)
# (22849) accepted ('127.0.0.1', 56232)
# (22849) accepted ('127.0.0.1', 56248)
# (22849) accepted ('127.0.0.1', 56258)
# (22849) accepted ('127.0.0.1', 56270)
# (22849) accepted ('127.0.0.1', 56280)
# 127.0.0.1 - - [09/Aug/2024 13:11:31] "GET /css/layout.css HTTP/1.1" 304 198 0.000474
#
# Reset
# Steps: 41/250. Action: 2. Reward/Value: -200.56/-0.6629. Done: -1
#  Mean Policy loss: 9781.2373. Mean Value loss: 89.1817
# Episode: 3/400, score/average: -248.6786/-275.0569
#
# Reset
# Steps: 100/250. Action: 4. Reward/Value: -202.33/-0.3388. Done: -1
#  Mean Policy loss: 9888.6699. Mean Value loss: 110.0429
# Episode: 4/400, score/average: -349.1630/-293.5834
#
# Reset
# Steps: 41/250. Action: 5. Reward/Value: -202.36/-1.256. Done: -1
#  Mean Policy loss: 11599.2588. Mean Value loss: 97.6639
# Episode: 5/400, score/average: -288.3063/-292.5280
#
# Reset
# Steps: 73/250. Action: 0. Reward/Value: -201.76/-0.3533. Done: -1
#  Mean Policy loss: 12661.8564. Mean Value loss: 126.2904
# Episode: 6/400, score/average: -296.4088/-293.1748 SAVING
#
# Reset
# Steps: 21/250. Action: 0. Reward/Value: -202.33/-0.8531. Done: -1
#  Mean Policy loss: 18247.4414. Mean Value loss: 121.8069
# Episode: 7/400, score/average: -240.8401/-285.6984 SAVING
#
# Reset
# Steps: 44/250. Action: 4. Reward/Value: -201.79/-1.3634. Done: -1
#  Mean Policy loss: 9538.8828. Mean Value loss: 83.8864
# Episode: 8/400, score/average: -262.8959/-282.8481 SAVING
#
# Reset
# Steps: 40/250. Action: 2. Reward/Value: -202.2/-0.5144. Done: -1
#  Mean Policy loss: 11108.0352. Mean Value loss: 92.0091
# Episode: 9/400, score/average: -268.7218/-281.2785 SAVING
#
# Reset
# Steps: 84/250. Action: 0. Reward/Value: -202.19/-1.2798. Done: -1
#  Mean Policy loss: 11118.8203. Mean Value loss: 113.3361
# Episode: 10/400, score/average: -302.7071/-283.4214 SAVING
#
# Reset
# Steps: 76/250. Action: 1. Reward/Value: -201.56/-0.7209. Done: -1
#  Mean Policy loss: 10806.4707. Mean Value loss: 114.2650
# Episode: 11/400, score/average: -279.2327/-279.9598 SAVING
#
# Reset
# Steps: 50/250. Action: 4. Reward/Value: -201.53/-0.6893. Done: -1
#  Mean Policy loss: 8412.9014. Mean Value loss: 77.8460
# Episode: 12/400, score/average: -259.0922/-279.6046 SAVING
#
# Reset
# Steps: 109/250. Action: 5. Reward/Value: -202.06/-1.5567. Done: -1
#  Mean Policy loss: 11870.3184. Mean Value loss: 147.0881
# Episode: 13/400, score/average: -355.3862/-290.2754
#
# Reset
# Steps: 80/250. Action: 5. Reward/Value: -202.19/-0.9781. Done: -1
#  Mean Policy loss: 11602.8154. Mean Value loss: 114.5320
# Episode: 14/400, score/average: -291.4108/-284.5002
#
# Reset
# Steps: 93/250. Action: 0. Reward/Value: -201.09/-0.9055. Done: -1
#  Mean Policy loss: 8585.9688. Mean Value loss: 92.3059
# Episode: 15/400, score/average: -277.5603/-283.4256
#
# Reset
# Steps: 73/250. Action: 1. Reward/Value: -201.34/-1.3446. Done: -1
#  Mean Policy loss: 11447.2080. Mean Value loss: 118.6102
# Episode: 16/400, score/average: -289.0631/-282.6910
#
# Reset
# Steps: 43/250. Action: 5. Reward/Value: -201.83/-0.5694. Done: -1
# Episode: 90/400, score/average: -247.8446/-298.9108 SAVING
#
# Reset
# Steps: 112/250. Action: 4. Reward/Value: -201.94/-0.4883. Done: -1
#  Mean Policy loss: 13112.0752. Mean Value loss: 146.6100
# Episode: 91/400, score/average: -323.7907/-298.8221
#
# Reset
# Steps: 98/250. Action: 5. Reward/Value: -202.06/-0.8311. Done: -1
#  Mean Policy loss: 9768.2021. Mean Value loss: 107.6982
# Episode: 92/400, score/average: -334.8083/-302.4383
#
# Reset
# Steps: 50/250. Action: 4. Reward/Value: -202.03/-0.8084. Done: -1
#  Mean Policy loss: 8793.8398. Mean Value loss: 79.1925
# Episode: 93/400, score/average: -267.0463/-300.7630
#
# Reset
# Steps: 125/250. Action: 5. Reward/Value: -201.95/-0.8862. Done: -1
#  Mean Policy loss: 11382.7012. Mean Value loss: 136.6458
# Episode: 94/400, score/average: -360.9956/-309.5322
#
# Reset
# Steps: 57/250. Action: 5. Reward/Value: -202.57/-0.6598. Done: -1
#  Mean Policy loss: 16671.9473. Mean Value loss: 153.7293
# Episode: 95/400, score/average: -299.7980/-312.0050
#
# Reset
# Steps: 64/250. Action: 0. Reward/Value: -201.99/-1.158. Done: -1
#  Mean Policy loss: 13271.9482. Mean Value loss: 127.8400
# Episode: 96/400, score/average: -277.3100/-312.6259
#
# Reset
# Steps: 81/250. Action: 4. Reward/Value: -201.94/-1.3556. Done: -1
#  Mean Policy loss: 10198.2549. Mean Value loss: 108.1478
# Episode: 97/400, score/average: -281.0680/-300.8248
#
# Reset
# Steps: 123/250. Action: 5. Reward/Value: -201.45/-1.7712. Done: -1
#  Mean Policy loss: 10852.9082. Mean Value loss: 133.3887
# Episode: 98/400, score/average: -352.3387/-304.3185
#
# Reset
# Steps: 107/250. Action: 0. Reward/Value: -202.05/-1.2726. Done: -1
#  Mean Policy loss: 11024.6191. Mean Value loss: 129.2127
# Episode: 99/400, score/average: -311.5674/-305.6568
#
# Reset
# Steps: 48/250. Action: 4. Reward/Value: -201.7/-1.1839. Done: -1
#  Mean Policy loss: 8406.8564. Mean Value loss: 78.1674
# Episode: 100/400, score/average: -249.9634/-305.8686 SAVING
#
# Reset
# Steps: 44/250. Action: 4. Reward/Value: -201.94/-1.1148. Done: -1
#  Mean Policy loss: 9902.3086. Mean Value loss: 87.0854
# Episode: 101/400, score/average: -269.1534/-300.4049
#
# Reset
# Steps: 112/250. Action: 0. Reward/Value: -201.85/-1.0314. Done: -1
#  Mean Policy loss: 12405.8887. Mean Value loss: 132.7407
# Episode: 102/400, score/average: -315.5336/-298.4774
#
# Reset
# Steps: 95/250. Action: 0. Reward/Value: -201.96/-1.4034. Done: -1
#  Mean Policy loss: 9816.4932. Mean Value loss: 104.8250
# Episode: 103/400, score/average: -317.4328/-303.5161
#
# Reset
# Steps: 40/250. Action: 5. Reward/Value: -202.35/-0.9336. Done: -1
#  Mean Policy loss: 11501.8027. Mean Value loss: 96.3094
# Episode: 104/400, score/average: -275.8031/-294.9968
#
# Reset
# Steps: 66/250. Action: 5. Reward/Value: -201.71/-1.2622. Done: -1
#  Mean Policy loss: 13170.8623. Mean Value loss: 134.9432
# Episode: 164/400, score/average: -306.6996/-321.1346
#
# Reset
# Steps: 60/250. Action: 4. Reward/Value: -202.16/-1.4301. Done: -1
#  Mean Policy loss: 15508.6611. Mean Value loss: 152.7368
# Episode: 165/400, score/average: -304.8967/-316.0975
#
# Reset
# Steps: 106/250. Action: 5. Reward/Value: -201.26/-1.9213. Done: -1
#  Mean Policy loss: 10508.7197. Mean Value loss: 119.3210
# Episode: 166/400, score/average: -279.7443/-315.5170
#
# Reset
# Steps: 109/250. Action: 0. Reward/Value: -202.17/-1.0863. Done: -1
#  Mean Policy loss: 13899.3750. Mean Value loss: 156.5239
# Episode: 167/400, score/average: -349.8379/-326.1752
#
# Reset
# Steps: 99/250. Action: 0. Reward/Value: -201.65/-1.7672. Done: -1
#  Mean Policy loss: 9922.9453. Mean Value loss: 117.5535
# Episode: 168/400, score/average: -373.8136/-325.2627
#
# Reset
# Steps: 104/250. Action: 0. Reward/Value: -202.01/-1.9133. Done: -1
#  Mean Policy loss: 13674.1738. Mean Value loss: 165.8764
# Episode: 169/400, score/average: -365.1793/-322.2898
#
# Reset
# Steps: 106/250. Action: 4. Reward/Value: -201.76/-1.6042. Done: -1
#  Mean Policy loss: 11733.4541. Mean Value loss: 145.3516
# Episode: 170/400, score/average: -343.9879/-327.1085 SAVING
#
# Reset
# Steps: 114/250. Action: 5. Reward/Value: -201.47/-1.8859. Done: -1
#  Mean Policy loss: 12268.0791. Mean Value loss: 142.7296
# Episode: 171/400, score/average: -338.7375/-330.3186
#
# Reset
# Steps: 120/250. Action: 0. Reward/Value: -201.62/-1.6795. Done: -1
#  Mean Policy loss: 11933.6387. Mean Value loss: 139.8515
# Episode: 172/400, score/average: -344.0853/-337.9640
#
# Reset
# Steps: 116/250. Action: 4. Reward/Value: -201.98/-1.6897. Done: -1
#  Mean Policy loss: 11967.3105. Mean Value loss: 139.9644
# Episode: 173/400, score/average: -347.3807/-335.4363
#
# Reset
# Steps: 72/250. Action: 5. Reward/Value: -202.75/-1.0312. Done: -1
#  Mean Policy loss: 13345.0234. Mean Value loss: 132.1448
# Episode: 174/400, score/average: -301.5100/-334.9173
#
# Reset
# Steps: 65/250. Action: 5. Reward/Value: -202.2/-1.2252. Done: -1
#  Mean Policy loss: 14431.3828. Mean Value loss: 141.1938
# Episode: 175/400, score/average: -291.5344/-333.5811
#
# Reset
# Steps: 114/250. Action: 5. Reward/Value: -202.19/-1.6357. Done: -1
#  Mean Policy loss: 10902.5312. Mean Value loss: 117.1479
# Episode: 176/400, score/average: -281.3655/-333.7432
#
# Reset
# Steps: 78/250. Action: 5. Reward/Value: -202.17/-1.349. Done: -1
#  Mean Policy loss: 12270.9082. Mean Value loss: 126.9355
# Episode: 177/400, score/average: -323.7931/-331.1387
#
# Reset
# Steps: 90/250. Action: 0. Reward/Value: -202.55/-1.2331. Done: -1
#  Mean Policy loss: 11035.2568. Mean Value loss: 117.9713
# Episode: 178/400, score/average: -346.6419/-328.4216
#
# Reset
#
# Reset
# Steps: 122/250. Action: 5. Reward/Value: -202.29/-0.6254. Done: -1
#  Mean Policy loss: 10866.4150. Mean Value loss: 124.9682
# Episode: 194/400, score/average: -335.9329/-333.3413
#
# Reset
# Steps: 64/250. Action: 0. Reward/Value: -202.41/-1.1248. Done: -1
#  Mean Policy loss: 16431.6660. Mean Value loss: 156.8431
# Episode: 195/400, score/average: -321.5909/-329.6833
#
# Reset
# Steps: 103/250. Action: 0. Reward/Value: -201.85/-1.6458. Done: -1
#  Mean Policy loss: 14290.3096. Mean Value loss: 143.7738
# Episode: 196/400, score/average: -277.8519/-325.2577
#
# Reset
# Steps: 106/250. Action: 4. Reward/Value: -202.14/-1.5533. Done: -1
#  Mean Policy loss: 12858.3193. Mean Value loss: 156.6223
# Episode: 197/400, score/average: -377.9052/-329.5665
#
# Reset
# Steps: 86/250. Action: 5. Reward/Value: -202.62/-1.1532. Done: -1
#  Mean Policy loss: 11233.0195. Mean Value loss: 111.6491
# Episode: 198/400, score/average: -308.9683/-321.8328
#
# Reset
# Steps: 102/250. Action: 5. Reward/Value: -201.62/-1.6529. Done: -1
#  Mean Policy loss: 15642.0840. Mean Value loss: 165.2117
# Episode: 199/400, score/average: -302.8610/-318.9479
#
# Reset
# Steps: 118/250. Action: 0. Reward/Value: -200.83/-1.7846. Done: -1
#  Mean Policy loss: 11478.7676. Mean Value loss: 146.9252
# Episode: 200/400, score/average: -369.6240/-323.8121 SAVING
#
# Reset
# Steps: 56/250. Action: 4. Reward/Value: -202.6/-0.823. Done: -1
#  Mean Policy loss: 17808.9121. Mean Value loss: 155.9944
# Episode: 201/400, score/average: -268.5629/-318.6368
#
# Reset
# Steps: 123/250. Action: 5. Reward/Value: -201.84/-1.646. Done: -1
#  Mean Policy loss: 11726.8994. Mean Value loss: 139.3599
# Episode: 202/400, score/average: -348.3838/-324.6828
#
# Reset
# Steps: 92/250. Action: 4. Reward/Value: -202.19/-1.3061. Done: -1
#  Mean Policy loss: 10664.2539. Mean Value loss: 114.1994
# Episode: 203/400, score/average: -334.6099/-324.6291
#
# Reset
# Steps: 92/250. Action: 0. Reward/Value: -202.02/-1.5347. Done: -1
#  Mean Policy loss: 9501.6094. Mean Value loss: 103.1008
# Episode: 204/400, score/average: -302.2623/-321.2620
#
# Reset
# Steps: 115/250. Action: 0. Reward/Value: -201.56/-1.6814. Done: -1
#  Mean Policy loss: 11684.9873. Mean Value loss: 131.3548
# Episode: 205/400, score/average: -323.6313/-321.4661
#
# Reset
# Steps: 124/250. Action: 4. Reward/Value: -201.61/-1.9145. Done: -1
#  Mean Policy loss: 11110.5420. Mean Value loss: 123.4343
# Episode: 206/400, score/average: -308.2755/-324.5084
#
# Reset
# Steps: 88/250. Action: 4. Reward/Value: -201.32/-1.782. Done: -1
#  Mean Policy loss: 10374.7637. Mean Value loss: 121.0276
# Episode: 207/400, score/average: -344.2149/-321.1394
#
# Reset
# Steps: 91/250. Action: 4. Reward/Value: -201.51/-1.851. Done: -1
#  Mean Policy loss: 8511.2422. Mean Value loss: 96.3396
# Episode: 208/400, score/average: -287.3654/-318.9791
#
# Reset
# Steps: 124/250. Action: 0. Reward/Value: -202.02/-1.5783. Done: -1
#  Mean Policy loss: 10614.3770. Mean Value loss: 133.2138
# Episode: 209/400, score/average: -360.1113/-324.7041
#
# Reset
# Steps: 130/250. Action: 0. Reward/Value: -201.27/-1.7803. Done: -1
#  Mean Policy loss: 9497.5566. Mean Value loss: 112.4433
# Episode: 210/400, score/average: -311.3461/-318.8763 SAVING
#
# Reset
# Steps: 111/250. Action: 4. Reward/Value: -202.68/-1.6717. Done: -1
#  Mean Policy loss: 14797.2988. Mean Value loss: 163.0902
# Episode: 211/400, score/average: -382.6950/-330.2896
#
# Reset
# Steps: 123/250. Action: 5. Reward/Value: -202.28/-1.4005. Done: -1
#  Mean Policy loss: 11651.7998. Mean Value loss: 139.5628
# Episode: 212/400, score/average: -357.7176/-331.2229
#
# Reset
# Steps: 115/250. Action: 4. Reward/Value: -201.5/-1.7088. Done: -1
#  Mean Policy loss: 10783.4072. Mean Value loss: 128.5103
# Episode: 213/400, score/average: -314.8445/-329.2464
#
# Reset
# Steps: 79/250. Action: 1. Reward/Value: -201.13/-1.2932. Done: -1
#  Mean Policy loss: 9492.5576. Mean Value loss: 100.6504
# Episode: 214/400, score/average: -261.0141/-325.1216
#
# Reset
# Steps: 102/250. Action: 4. Reward/Value: -201.33/-1.1227. Done: -1
#  Mean Policy loss: 10063.4336. Mean Value loss: 121.7137
# Episode: 215/400, score/average: -282.7972/-321.0382
#
# Reset
# Steps: 119/250. Action: 4. Reward/Value: -201.11/-1.8615. Done: -1
#  Mean Policy loss: 10506.9404. Mean Value loss: 123.9253
# Episode: 216/400, score/average: -314.4229/-321.6529
#
# Reset
# Steps: 84/250. Action: 5. Reward/Value: -202.22/-1.4861. Done: -1
#  Mean Policy loss: 10987.7559. Mean Value loss: 113.1563
# Episode: 217/400, score/average: -303.7202/-317.6034
#
# Reset
# Steps: 178/250. Action: 5. Reward/Value: -201.23/-1.8652. Done: -1
#  Mean Policy loss: 11042.3828. Mean Value loss: 156.9701
# Episode: 218/400, score/average: -426.6670/-331.5336
#
# Reset
# Steps: 106/250. Action: 4. Reward/Value: -202.48/-1.6376. Done: -1
#  Mean Policy loss: 15782.5811. Mean Value loss: 178.8658
# Episode: 219/400, score/average: -407.2172/-336.2442
#
# Reset
# Steps: 46/250. Action: 0. Reward/Value: -202.54/-1.3855. Done: -1
#  Mean Policy loss: 10025.0410. Mean Value loss: 88.8059
# Episode: 220/400, score/average: -273.9576/-332.5053 SAVING
#
# Reset
# Steps: 112/250. Action: 4. Reward/Value: -202.29/-1.5794. Done: -1
#  Mean Policy loss: 13669.9111. Mean Value loss: 162.2778
# Episode: 221/400, score/average: -385.5355/-332.7894
#
# Reset
# Steps: 104/250. Action: 5. Reward/Value: -202.51/-1.8154. Done: -1
#  Mean Policy loss: 16911.0273. Mean Value loss: 173.6571
# Episode: 222/400, score/average: -371.6072/-334.1783
#
# Reset
# Steps: 250/250. Action: 1. Reward/Value: -1.84/-1.5053. Done: 0
#  Mean Policy loss: 1918.2828. Mean Value loss: 102.0668
# Episode: 223/400, score/average: -324.4884/-335.1427
#
# Reset
# Steps: 117/250. Action: 5. Reward/Value: -202.07/-1.8793. Done: -1
#  Mean Policy loss: 13154.8984. Mean Value loss: 154.4390
# Episode: 224/400, score/average: -388.7239/-347.9137
#
# Reset
# Steps: 44/250. Action: 0. Reward/Value: -202.09/-1.3138. Done: -1
#  Mean Policy loss: 9588.6328. Mean Value loss: 85.9426
# Episode: 225/400, score/average: -257.6188/-345.3959
#
# Reset
# Steps: 184/250. Action: 0. Reward/Value: -201.06/-1.8105. Done: -1
#  Mean Policy loss: 9024.1357. Mean Value loss: 116.3428
# Episode: 226/400, score/average: -336.2908/-347.5827
#
# Reset
# Steps: 100/250. Action: 5. Reward/Value: -202.36/-1.531. Done: -1
#  Mean Policy loss: 9163.5586. Mean Value loss: 95.3006
# Episode: 227/400, score/average: -301.5426/-347.3649
#
# Reset
# Steps: 77/250. Action: 0. Reward/Value: -202.2/-1.3741. Done: -1
#  Mean Policy loss: 11627.7285. Mean Value loss: 113.9244
# Episode: 228/400, score/average: -270.5033/-331.7485
#
# Reset
# Steps: 118/250. Action: 1. Reward/Value: -202.68/-1.5182. Done: -1
#  Mean Policy loss: 13295.6582. Mean Value loss: 133.5877
# Episode: 229/400, score/average: -311.1746/-322.1443
#
# Reset
# Steps: 133/250. Action: 5. Reward/Value: -201.31/-1.6962. Done: -1
#  Mean Policy loss: 9767.4727. Mean Value loss: 115.4880
# Episode: 230/400, score/average: -315.9228/-326.3408 SAVING
#
# Reset
# Steps: 116/250. Action: 1. Reward/Value: -200.46/-1.8998. Done: -1
#  Mean Policy loss: 10592.8594. Mean Value loss: 131.4893
# Episode: 231/400, score/average: -324.6864/-320.2559
#
# Reset
# Steps: 105/250. Action: 5. Reward/Value: -202.06/-1.6202. Done: -1
#  Mean Policy loss: 11272.2891. Mean Value loss: 124.4360
# Episode: 232/400, score/average: -287.3075/-311.8259
#
# Reset
# Steps: 93/250. Action: 0. Reward/Value: -202.03/-1.8996. Done: -1
#  Mean Policy loss: 9544.3818. Mean Value loss: 99.3462
# Episode: 233/400, score/average: -295.8576/-308.9628
#
# Reset
# Steps: 151/250. Action: 4. Reward/Value: -200.09/-1.846. Done: -1
#  Mean Policy loss: 9352.6924. Mean Value loss: 147.6200
# Episode: 234/400, score/average: -382.8692/-308.3774
#
# Reset
# Steps: 93/250. Action: 0. Reward/Value: -202.0/-1.5375. Done: -1
#  Mean Policy loss: 9402.4375. Mean Value loss: 97.7586
# Episode: 235/400, score/average: -278.9663/-310.5121
#
# Reset
# Steps: 88/250. Action: 4. Reward/Value: -202.15/-1.7123. Done: -1
#  Mean Policy loss: 10584.9639. Mean Value loss: 114.2415
# Episode: 236/400, score/average: -326.4112/-309.5241
#
# Reset
# Steps: 57/250. Action: 4. Reward/Value: -201.6/-1.291. Done: -1
#  Mean Policy loss: 14296.1982. Mean Value loss: 135.3546
# Episode: 237/400, score/average: -276.3148/-307.0014
#
# Reset
# Steps: 72/250. Action: 4. Reward/Value: -201.96/-1.5461. Done: -1
#  Mean Policy loss: 12933.5693. Mean Value loss: 121.9676
# Episode: 238/400, score/average: -313.1510/-311.2661
#
# Reset
# Steps: 119/250. Action: 4. Reward/Value: -201.7/-1.9413. Done: -1
#  Mean Policy loss: 11174.9746. Mean Value loss: 138.7859
# Episode: 239/400, score/average: -350.7681/-315.2255
#
# Reset
# Steps: 128/250. Action: 1. Reward/Value: -201.27/-1.7896. Done: -1
#  Mean Policy loss: 9713.8262. Mean Value loss: 111.3720
# Episode: 240/400, score/average: -313.1066/-314.9439 SAVING
#
# Reset
# Steps: 126/250. Action: 0. Reward/Value: -201.68/-1.9822. Done: -1
#  Mean Policy loss: 10042.5283. Mean Value loss: 110.3674
# Episode: 241/400, score/average: -321.1540/-314.5906
#
# Reset
# Steps: 102/250. Action: 2. Reward/Value: -202.41/-1.7101. Done: -1
#  Mean Policy loss: 18231.0312. Mean Value loss: 226.0428
# Episode: 242/400, score/average: -378.0705/-323.6669
#
# Reset
# Steps: 42/250. Action: 3. Reward/Value: -201.94/-1.7848. Done: -1
#  Mean Policy loss: 9989.2637. Mean Value loss: 89.0816
# Episode: 243/400, score/average: -263.0972/-320.3909
#
# Reset
# Steps: 117/250. Action: 2. Reward/Value: -202.19/-1.754. Done: -1
#  Mean Policy loss: 13351.7637. Mean Value loss: 159.4896
# Episode: 244/400, score/average: -385.3135/-320.6353
#
# Reset
# Steps: 114/250. Action: 3. Reward/Value: -202.16/-1.8809. Done: -1
#  Mean Policy loss: 12643.6738. Mean Value loss: 147.0140
# Episode: 245/400, score/average: -367.3483/-329.4735
#
# Reset
# Steps: 95/250. Action: 3. Reward/Value: -201.85/-1.9581. Done: -1
#  Mean Policy loss: 10006.8389. Mean Value loss: 112.0049
# Episode: 246/400, score/average: -336.0844/-330.4408
#
# Reset
# Steps: 127/250. Action: 3. Reward/Value: -201.89/-1.8367. Done: -1
#  Mean Policy loss: 11211.8193. Mean Value loss: 142.1381
# Episode: 247/400, score/average: -385.2174/-341.3311
#
# Reset
# Steps: 56/250. Action: 4. Reward/Value: -202.05/-1.7495. Done: -1
#  Mean Policy loss: 17177.0234. Mean Value loss: 160.5596
# Episode: 248/400, score/average: -268.1494/-336.8309
#
# Reset
# Steps: 41/250. Action: 4. Reward/Value: -201.54/-1.3682. Done: -1
#  Mean Policy loss: 9765.0020. Mean Value loss: 86.9003
# Episode: 249/400, score/average: -250.4134/-326.7955
#
# Reset
# Steps: 85/250. Action: 3. Reward/Value: -201.69/-1.8275. Done: -1
#  Mean Policy loss: 10016.3193. Mean Value loss: 104.7328
# Episode: 250/400, score/average: -290.9207/-324.5769 SAVING
#
# Reset
# Steps: 111/250. Action: 3. Reward/Value: -201.55/-1.9251. Done: -1
#  Mean Policy loss: 12638.4844. Mean Value loss: 133.7241
# Episode: 251/400, score/average: -306.8494/-323.1464
#
# Reset
# Steps: 122/250. Action: 0. Reward/Value: -201.96/-1.8903. Done: -1
#  Mean Policy loss: 12070.3574. Mean Value loss: 137.7285
# Episode: 252/400, score/average: -363.2673/-321.6661
#
# Reset
# Steps: 111/250. Action: 0. Reward/Value: -202.34/-1.7213. Done: -1
#  Mean Policy loss: 13780.9375. Mean Value loss: 154.9294
# Episode: 253/400, score/average: -362.8929/-331.6457
#
# Reset
# Steps: 81/250. Action: 0. Reward/Value: -201.98/-1.8692. Done: -1
#  Mean Policy loss: 11750.3730. Mean Value loss: 119.8357
# Episode: 254/400, score/average: -314.6867/-324.5830
#
# Reset
# Steps: 96/250. Action: 5. Reward/Value: -201.8/-1.8834. Done: -1
#  Mean Policy loss: 10159.7520. Mean Value loss: 111.6037
# Episode: 255/400, score/average: -332.4901/-321.0972
#
# Reset
# Steps: 97/250. Action: 4. Reward/Value: -201.74/-1.8768. Done: -1
#  Mean Policy loss: 8908.6621. Mean Value loss: 98.1189
# Episode: 256/400, score/average: -302.1660/-317.7053
#
# Reset
# Steps: 113/250. Action: 3. Reward/Value: -201.84/-1.6784. Done: -1
#  Mean Policy loss: 12169.2158. Mean Value loss: 135.9341
# Episode: 257/400, score/average: -321.4657/-311.3302
#
# Reset
# Steps: 104/250. Action: 2. Reward/Value: -201.69/-1.7528. Done: -1
#  Mean Policy loss: 11868.7139. Mean Value loss: 139.8831
# Episode: 258/400, score/average: -294.7013/-313.9854
#
# Reset
# Steps: 126/250. Action: 2. Reward/Value: -201.77/-1.9007. Done: -1
#  Mean Policy loss: 11641.3232. Mean Value loss: 143.8855
# Episode: 259/400, score/average: -374.9544/-326.4395
#
# Reset
# Steps: 91/250. Action: 0. Reward/Value: -200.68/-1.6966. Done: -1
#  Mean Policy loss: 9407.6738. Mean Value loss: 103.5578
# Episode: 260/400, score/average: -301.4234/-327.4897 SAVING
#
# Reset
# Steps: 121/250. Action: 3. Reward/Value: -201.34/-1.8407. Done: -1
#  Mean Policy loss: 10381.1631. Mean Value loss: 124.3619
# Episode: 261/400, score/average: -317.1637/-328.5212
#
# Reset
# Steps: 137/250. Action: 0. Reward/Value: -201.32/-1.7621. Done: -1
#  Mean Policy loss: 9073.5020. Mean Value loss: 107.6230
# Episode: 262/400, score/average: -316.2918/-323.8236
#
# Reset
# Steps: 92/250. Action: 0. Reward/Value: -200.45/-1.8287. Done: -1
#  Mean Policy loss: 8913.1133. Mean Value loss: 101.5407
# Episode: 263/400, score/average: -305.3234/-318.0667
#
# Reset
# Steps: 90/250. Action: 2. Reward/Value: -201.76/-1.8141. Done: -1
#  Mean Policy loss: 9463.0098. Mean Value loss: 101.9479
# Episode: 264/400, score/average: -283.7360/-314.9716
#
# Reset
# Steps: 109/250. Action: 0. Reward/Value: -200.83/-1.6145. Done: -1
#  Mean Policy loss: 12140.7275. Mean Value loss: 136.6049
# Episode: 265/400, score/average: -296.3888/-311.3615
#
# Reset
# Steps: 127/250. Action: 3. Reward/Value: -201.57/-1.6475. Done: -1
#  Mean Policy loss: 9806.6689. Mean Value loss: 116.6468
# Episode: 266/400, score/average: -306.2553/-311.7704
#
# Reset
# Steps: 135/250. Action: 2. Reward/Value: -201.07/-1.7273. Done: -1
#  Mean Policy loss: 8899.0908. Mean Value loss: 100.8932
# Episode: 267/400, score/average: -291.2658/-308.7504
#
# Reset
# Steps: 122/250. Action: 5. Reward/Value: -201.22/-1.7699. Done: -1
#  Mean Policy loss: 10650.7988. Mean Value loss: 122.3542
# Episode: 268/400, score/average: -303.4977/-309.6300
#
# Reset
# Steps: 127/250. Action: 3. Reward/Value: -201.07/-1.8099. Done: -1
#  Mean Policy loss: 10089.0459. Mean Value loss: 123.4686
# Episode: 269/400, score/average: -328.1062/-304.9452
#
# Reset
# Steps: 134/250. Action: 4. Reward/Value: -201.38/-1.759. Done: -1
#  Mean Policy loss: 9733.8496. Mean Value loss: 115.7459
# Episode: 270/400, score/average: -326.5368/-307.4565 SAVING
#
# Reset
# Steps: 97/250. Action: 3. Reward/Value: -202.32/-1.429. Done: -1
#  Mean Policy loss: 10079.4473. Mean Value loss: 103.8664
# Episode: 271/400, score/average: -323.8870/-308.1289
#
# Reset
# Steps: 103/250. Action: 3. Reward/Value: -201.19/-1.7596. Done: -1
#  Mean Policy loss: 11476.6982. Mean Value loss: 136.8364
# Episode: 272/400, score/average: -308.0225/-307.3019
#
# Reset
# Steps: 100/250. Action: 5. Reward/Value: -200.77/-1.7783. Done: -1
#  Mean Policy loss: 8157.5469. Mean Value loss: 92.0077
# Episode: 273/400, score/average: -295.0000/-306.2696
#
# Reset
# Steps: 108/250. Action: 2. Reward/Value: -201.54/-1.7434. Done: -1
#  Mean Policy loss: 12941.5381. Mean Value loss: 139.4526
# Episode: 274/400, score/average: -317.2127/-309.6173
#
# Reset
# Steps: 105/250. Action: 5. Reward/Value: -202.46/-1.4428. Done: -1
#  Mean Policy loss: 13428.4707. Mean Value loss: 157.3053
# Episode: 275/400, score/average: -368.5110/-316.8295
#
# Reset
# Steps: 114/250. Action: 4. Reward/Value: -202.23/-1.5233. Done: -1
#  Mean Policy loss: 13986.3848. Mean Value loss: 157.4491
# Episode: 276/400, score/average: -377.4185/-323.9458
#
# Reset
# Steps: 118/250. Action: 4. Reward/Value: -201.66/-1.6968. Done: -1
#  Mean Policy loss: 12234.1182. Mean Value loss: 146.4377
# Episode: 277/400, score/average: -354.5894/-330.2782
#
# Reset
# Steps: 110/250. Action: 2. Reward/Value: -200.96/-1.778. Done: -1
#  Mean Policy loss: 9755.3828. Mean Value loss: 114.1415
# Episode: 278/400, score/average: -267.2497/-326.6534
#
# Reset
# Steps: 111/250. Action: 4. Reward/Value: -200.5/-1.867. Done: -1
#  Mean Policy loss: 11423.3281. Mean Value loss: 139.7633
# Episode: 279/400, score/average: -325.6983/-326.4126
#
# Reset
# Steps: 113/250. Action: 4. Reward/Value: -201.69/-1.6248. Done: -1
#  Mean Policy loss: 11812.0625. Mean Value loss: 136.2606
# Episode: 280/400, score/average: -337.0635/-327.4652 SAVING
#
# Reset
# Steps: 95/250. Action: 5. Reward/Value: -201.97/-1.6151. Done: -1
#  Mean Policy loss: 9303.7627. Mean Value loss: 98.2228
# Episode: 281/400, score/average: -295.6530/-324.6419
#
# Reset
# Steps: 160/250. Action: 4. Reward/Value: -202.06/-1.6339. Done: -1
#  Mean Policy loss: 12613.7588. Mean Value loss: 156.5363
# Episode: 282/400, score/average: -407.2277/-334.5624
#
# Reset
# Steps: 106/250. Action: 4. Reward/Value: -201.08/-1.7334. Done: -1
#  Mean Policy loss: 11651.4648. Mean Value loss: 135.4581
# Episode: 283/400, score/average: -298.3077/-334.8932
#
# Reset
# Steps: 120/250. Action: 0. Reward/Value: -202.08/-1.5851. Done: -1
#  Mean Policy loss: 11259.2793. Mean Value loss: 135.8150
# Episode: 284/400, score/average: -356.6693/-338.8388
#
# Reset
# Steps: 104/250. Action: 0. Reward/Value: -202.57/-1.2631. Done: -1
#  Mean Policy loss: 12552.3477. Mean Value loss: 137.9839
# Episode: 285/400, score/average: -334.0319/-335.3909
#
# Reset
# Steps: 127/250. Action: 0. Reward/Value: -201.69/-1.6797. Done: -1
#  Mean Policy loss: 11232.9980. Mean Value loss: 134.1817
# Episode: 286/400, score/average: -355.5304/-333.2021
#
# Reset
# Steps: 118/250. Action: 5. Reward/Value: -201.72/-1.9309. Done: -1
#  Mean Policy loss: 10462.6699. Mean Value loss: 123.3374
# Episode: 287/400, score/average: -313.1708/-329.0602
#
# Reset
# Steps: 122/250. Action: 0. Reward/Value: -201.5/-1.6523. Done: -1
#  Mean Policy loss: 11040.3135. Mean Value loss: 125.9412
# Episode: 288/400, score/average: -318.8822/-334.2235
#
# Reset
# Steps: 133/250. Action: 2. Reward/Value: -201.61/-1.8004. Done: -1
#  Mean Policy loss: 9299.6475. Mean Value loss: 107.4965
# Episode: 289/400, score/average: -299.2251/-331.5762
#
# Reset
# Steps: 95/250. Action: 3. Reward/Value: -201.12/-1.8112. Done: -1
#  Mean Policy loss: 8766.7246. Mean Value loss: 105.1184
# Episode: 290/400, score/average: -329.4618/-330.8160 SAVING
#
# Reset
# Steps: 8/250. Action: 2. Reward/Value: -1.42/-1.6792. Done: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 agent.train(num_episodes=400,max_steps=250)
#
# Cell In[5], line 236, in PPO.train(self, num_episodes, max_steps)
#     233     if done:
#     234         break
# --> 236     time.sleep(1.0)
#     238 self.learn_from_episode_trajectory(next_state)
#     239 self.clear_trayectory()
#
# KeyboardInterrupt:

# %%
agent.load("Models8/auto-docking-iss_PPO__148_-226.6446.pt")

# %%
agent.test(500)
# Out:
# Reset
# Steps: 49/500. Action: 3. Score/Value: -80.01/-1.5403. Done: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 agent.test(500)
#
# Cell In[5], line 290, in PPO.test(self, max_steps)
#     287         print(f'\rSteps: {step}/{max_steps}. Action: {action}. Score/Value: {round(score,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)
#     288         start = time.time()
# --> 290     if self.env.done or step > max_steps:
#     291         break
#     293 state_end = self.env.get_state()
#
# KeyboardInterrupt:
# 127.0.0.1 - - [09/Aug/2024 20:48:44] "GET /socket.io/?EIO=4&transport=websocket&sid=97TRwSTTmqJehiWHAAAA HTTP/1.1" 200 0 27429.823081

# %%
import os
import pyautogui

# Simular pulsación de Ctrl+S
pyautogui.hotkey('ctrl', 's')

os.system('sudo shutdown')
# os.system('sudo shutdown -c')

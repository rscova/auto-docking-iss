# %%
import time
from math import sqrt
import matplotlib.pyplot as plt
import random
from env3 import Env
import os
import numpy as np
import torch
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader
from copy import deepcopy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class ExperienceDataset(Dataset):
    def __init__(self, data):
        super().__init__()
        self.data = data

    def __len__(self):
        return len(self.data[0])

    def __getitem__(self, ind):
        return tuple(map(lambda t: t[ind], self.data))

def create_shuffled_dataloader(data, batch_size):
    ds = ExperienceDataset(data)
    return DataLoader(ds, batch_size = batch_size, shuffle = True)

# %%
class PolicyNetwork(torch.nn.Module):
    def __init__(self,state_dims, n_actions):
        super(PolicyNetwork, self).__init__()
        self.actor = torch.nn.Sequential(
            torch.nn.Linear(6, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, n_actions),
            torch.nn.Softmax(dim=-1)
        )

    def forward(self, x):
        policy = self.actor(x)
        return policy
    

class ValueNetwork(torch.nn.Module):
    def __init__(self,state_dims):
        super(ValueNetwork, self).__init__()
        self.critic = torch.nn.Sequential(
            torch.nn.Linear(6, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        value = self.critic(x)
        return value
        
def weights_init(m):
    if isinstance(m,torch.nn.Linear):
        m.bias.data.fill_(0)
        torch.nn.init.kaiming_uniform_(m.weight)


def np_to_tensor(x):
    return torch.tensor(x).to(torch.float32)

    
policy_model = PolicyNetwork(state_dims=6, n_actions = 6)
value_model = ValueNetwork(state_dims=6)

# %%
print(policy_model,value_model)
summary(policy_model, input_size=(1, 6))
summary(value_model, input_size=(1, 6))
# Out:
# PolicyNetwork(
#   (actor): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=6, bias=True)
#     (5): Softmax(dim=-1)
#   )
# ) ValueNetwork(
#   (critic): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             448
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 32]           2,080
#               ReLU-4                [-1, 1, 32]               0
#             Linear-5                 [-1, 1, 6]             198
#            Softmax-6                 [-1, 1, 6]               0
# ================================================================
# Total params: 2,726
# Trainable params: 2,726
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             448
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 32]           2,080
#               ReLU-4                [-1, 1, 32]               0
#             Linear-5                 [-1, 1, 1]              33
# ================================================================
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------

# %%
class PPO:
    def __init__(self, state_dim=6, action_dim=6, policy_lr=0.0005, value_lr=0.001, 
                 gamma=0.99, lam=0.95, beta_s=0.01,epsilon_clip=0.2, value_clip=0.4, 
                 epochs=10,batch_size=50,save_path='Models'):
        
        self.policy_net = PolicyNetwork(state_dim, action_dim).to(device)
        self.value_net = ValueNetwork(state_dim).to(device)
        self.policy_net.apply(weights_init)
        self.value_net.apply(weights_init)

        self.policy_optimizer = torch.optim.Adam(self.policy_net.parameters(), lr=policy_lr)
        self.value_optimizer = torch.optim.Adam(self.value_net.parameters(), lr=value_lr)

        self.gamma = gamma
        self.lamda = lam
        self.epsilon_clip = epsilon_clip
        self.value_clip = value_clip
        self.beta_s = beta_s
        self.epochs = epochs
        self.action_dim = action_dim
        self.batch_size = batch_size

        self.env = Env()
        self.env.run()

        self.save_path = save_path
        self.env_name = "auto-docking-iss"

        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
        self.path = str(self.env_name)+'_PPO_'
        self.model_name = os.path.join(self.save_path, self.path)

        self.trajectory = {'states':[],'actions':[], 'rewards':[], 'action_logs':[],
                           'values':[],'done':[]}
        
        self.scores, self.episodes, self.average = [],[],[]
        self.value_loss_mean, self.policy_loss_mean = [], []

    def save(self,episode,score):
        torch.save({
            'actor': self.policy_net.state_dict(),
            'critic': self.value_net.state_dict()
        }, f'./'+ self.model_name + '_' + str(episode) + '_' + str(round(score,4)) + '.pt')

    def load(self,name):
        print(f'./{name}')
        try:
            data = torch.load(f'./{name}')
            self.policy_net.load_state_dict(data['actor'])
            self.value_net.load_state_dict(data['critic'])
        except Exception as e:
            print(e)

    # Función para visualizar la evolución del entrenamiento
    def plot_model(self, score, episode,num_episodes):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-10:]) / len(self.scores[-10:]))
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(1,figsize=(18, 9))
            plt.plot(self.episodes, self.scores, 'b')
            plt.plot(self.episodes, self.average, 'r')
            plt.ylabel('Score', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"scores.png")
            except OSError:
                pass

        return self.average[-1]
    
    def plot_loss(self,episode,num_episodes):        
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(2,figsize=(18, 9))
            plt.plot(self.episodes, self.policy_loss_mean, 'b')
            plt.plot(self.episodes, self.value_loss_mean, 'r')
            plt.ylabel('Loss', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"loss.png")
            except OSError:
                pass
    

    #Almacenamiento de todas las variables que definen una transición para PPO
    def collect_trayectory(self,state,action,action_logs,reward,done,value):
        # action_onehot = np.zeros([self.action_dim])
        # action_onehot[action] = 1
        self.trajectory['states'].append(state)
        self.trajectory['actions'].append(action)
        self.trajectory['rewards'].append(reward)
        self.trajectory['values'].append(value)
        self.trajectory['action_logs'].append(action_logs)
        self.trajectory['done'].append(done)
    
    def clear_trayectory(self):
        for key in self.trajectory.keys():
            self.trajectory[key].clear()
    
    def select_action(self,state):
        action_probs = self.policy_net(state).squeeze().detach()
        dist = torch.distributions.Categorical(action_probs)
        action = dist.sample()
        action_log_probs = dist.log_prob(action)
        
        return action.item(),action_log_probs,dist.entropy().item()

    
    def generalized_advantage_estimation(self,next_state):
        advantages = np.zeros_like(self.trajectory['rewards'])
        last_gae_lambda = 0
        self.trajectory['values'].append(self.value_net(next_state).squeeze().detach())

        for t in reversed(range(len(self.trajectory['rewards']))):
            delta = self.trajectory['rewards'][t]+ self.gamma * self.trajectory['values'][t + 1].item() - self.trajectory['values'][t].item()
            advantages[t] = last_gae_lambda = delta + self.gamma * self.lamda * last_gae_lambda
        
        return np_to_tensor(advantages)


    def learn_from_episode_trajectory(self,next_state):
        self.policy_net.train()
        self.value_net.train()

        # to_torch_tensor = lambda t: torch.stack(t).to(device).detach()

        states = deepcopy(self.trajectory['states'])
        actions = deepcopy(self.trajectory['actions'])
        # rewards = deepcopy(self.trajectory['rewards'])
        values = deepcopy(self.trajectory['values'])
        action_logs = deepcopy(self.trajectory['action_logs'])
        # done = deepcopy(self.trajectory['done'])

        advantages = self.generalized_advantage_estimation(next_state).to(device)

        # prepare dataloader for policy phase training
        dl = create_shuffled_dataloader([states, actions, action_logs, advantages, values], self.batch_size)

        policy_loss_array = []
        value_loss_array = []

        for i in range(self.epochs):
            for states, actions, action_log, advantages, values in dl:
                #Update policy_net
                new_action_probs = self.policy_net(states).squeeze()
                dist = torch.distributions.Categorical(new_action_probs)

                # print("")
                # print(actions)
                # print(new_action_probs)
                new_action_logs = dist.log_prob(actions)
                entropy = dist.entropy()

                # compute PPO-Clip
                ratios = torch.exp(new_action_logs - action_log)
                surr1 = ratios * advantages
                surr2 = ratios.clamp(1 - self.epsilon_clip, 1 + self.epsilon_clip) * advantages
                policy_loss = -torch.mean(torch.min(surr1, surr2) - self.beta_s * entropy)
                policy_loss_array.append(policy_loss.detach().numpy())

                self.policy_optimizer.zero_grad() # Clean gradients
                policy_loss.mean().backward() # Compute gradients
                self.policy_optimizer.step() #Update weights

                #Update value_net
                new_values = self.value_net(states).squeeze()
                value_clipped = values + (new_values - values).clamp(-self.value_clip, self.value_clip)
                value_loss_1 = (value_clipped.flatten() - advantages) ** 2
                value_loss_2 = (values.flatten() - advantages) ** 2
                value_loss = torch.mean(torch.max(value_loss_1, value_loss_2))
                value_loss_array.append(value_loss.detach().numpy())

                self.value_optimizer.zero_grad() # Clean gradients
                value_loss.backward() # Compute gradients 

        self.value_loss_mean.append(sum(value_loss_array)/self.epochs)
        self.policy_loss_mean.append(sum(policy_loss_array)/self.epochs)

        print(f"\n Mean Policy loss: {self.value_loss_mean[-1]:.4f}. Mean Value loss: {self.policy_loss_mean[-1]:.4f}")
        
        self.policy_net.eval()
        self.value_net.eval()


    # Función para resetear el entorno tras acabar trayectoria
    def reset(self):
        state = self.env.reset()
        return np_to_tensor(self.process_state(state))
    
     # Función para interacción agente-entorno
    def step(self, action):
        next_state, reward, done = self.env.step(action)
        next_state = self.process_state(next_state)
        return np_to_tensor(next_state), reward, done

    def process_state(self,state):
        state_processed = np.array(state)
        state_processed[:3] = state_processed[:3] / 40 # Position array
        return state_processed
    
    def train(self,num_episodes=200,max_steps=200):
        average = 0
        self.policy_net.eval()
        self.value_net.eval()

        max_score_average = -5000

        for episode in range(1,num_episodes+1):
            self.clear_trayectory()

            state = self.reset()
            score = 0

            SAVING = ""

            for step in range(1,max_steps+1):
                
                action_probs = self.policy_net(state).squeeze().detach()
                dist = torch.distributions.Categorical(action_probs)
                action = dist.sample()
                action_log = dist.log_prob(action)

                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action.item())    
                self.collect_trayectory(state,action,action_log,reward,done,value)

                state = next_state

                score += reward

                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Reward/Value: {round(reward,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)

                if done:
                    break
                
                time.sleep(1)

            self.learn_from_episode_trajectory(next_state)
            self.clear_trayectory()

            average = self.plot_model(score, episode,num_episodes)
            self.plot_loss(episode,num_episodes)
            
            if average >= max_score_average and episode > 5:
                max_score_average = average
                self.save(episode,average)
                SAVING = "SAVING"
            elif episode % 10 == 0:
                self.save(episode,average)
                SAVING = "SAVING"
            else:
                SAVING = ""
            
            print(f"Episode: {episode}/{num_episodes}, score/average: {score:.4f}/{average:.4f} {SAVING}\n")


        # close environemnt when finish training
        self.save(episode,average)

    def test(self,max_steps):
        self.policy_net.eval()
        self.value_net.eval()

        self.clear_trayectory()
        state = self.reset()
        score = 0

        start = time.time()
        end = time.time()
        step = 0

        while True:
            end = time.time()
            if end - start >= 1.0:
                step += 1
                action_probabilities = self.policy_net(state)
                action = torch.argmax(action_probabilities, dim=-1).item()#np.argmax(self.policy_net(state).squeeze().detach().numpy())
                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action)    

                state = next_state

                score += reward

                # print(action_probabilities)
                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Score/Value: {round(score,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)
                start = time.time()

            if self.env.done:
                break

        state_end = self.env.get_state()
        
        print(f'\nNext state: {state_end}')

# %%
agent = PPO(save_path='Models6')
# Out:
# (4067) wsgi starting up on http://127.0.0.1:5000
# (4067) accepted ('127.0.0.1', 35232)
# (4067) accepted ('127.0.0.1', 35246)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET / HTTP/1.1" 304 242 0.004359
# (4067) accepted ('127.0.0.1', 35252)
# (4067) accepted ('127.0.0.1', 35264)
# (4067) accepted ('127.0.0.1', 35278)
# (4067) accepted ('127.0.0.1', 35290)
# (4067) accepted ('127.0.0.1', 35302)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /css/layout.css HTTP/1.1" 304 198 0.000714
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /js/three/three.js HTTP/1.1" 304 196 0.000414
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /js/three/WebGL.js HTTP/1.1" 304 196 0.000405
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /js/three/GLTFLoader.js HTTP/1.1" 304 201 0.000415
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /js/three/CSS2DRenderer.js HTTP/1.1" 304 204 0.000418
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /css/normalize.css HTTP/1.1" 304 201 0.000495
# (4067) accepted ('127.0.0.1', 35312)
# (4067) accepted ('127.0.0.1', 35318)
# (4067) accepted ('127.0.0.1', 35328)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /js/gsap3/gsap.js HTTP/1.1" 304 195 0.000463
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /js/gsap3/DrawSVGPlugin.js HTTP/1.1" 304 204 0.000504
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /js/gsap3/ScrambleTextPlugin.js HTTP/1.1" 304 209 0.000428
# (4067) accepted ('127.0.0.1', 35332)
# (4067) accepted ('127.0.0.1', 35342)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/hud-darken.png HTTP/1.1" 304 202 0.000894
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/hud-ring.png HTTP/1.1" 304 200 0.000764
# (4067) accepted ('127.0.0.1', 35350)
# (4067) accepted ('127.0.0.1', 35360)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/hud-ring-inner.png HTTP/1.1" 304 206 0.000610
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/shadow.png HTTP/1.1" 304 198 0.000436
# (4067) accepted ('127.0.0.1', 35364)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /js/threed.js HTTP/1.1" 304 197 0.000857
# (4067) accepted ('127.0.0.1', 35370)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/instructions/step1_6.jpg HTTP/1.1" 304 199 0.009390
# (4067) accepted ('127.0.0.1', 35384)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/instructions/step2.jpg HTTP/1.1" 304 197 0.001047
# (4067) accepted ('127.0.0.1', 35386)
# (4067) accepted ('127.0.0.1', 35388)
# (4067) accepted ('127.0.0.1', 35392)
# (4067) accepted ('127.0.0.1', 35398)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/instructions/step3.jpg HTTP/1.1" 304 197 0.000586
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/instructions/step4.jpg HTTP/1.1" 304 197 0.000403
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/instructions/step5.jpg HTTP/1.1" 304 197 0.000405
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/instructions/step7.jpg HTTP/1.1" 304 197 0.000402
# (4067) accepted ('127.0.0.1', 35412)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /socket.io/?EIO=4&transport=polling&t=P4mlCvY HTTP/1.1" 200 278 0.000463
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/hud/ForwardViewSprites.json HTTP/1.1" 304 211 0.001333
# (4067) accepted ('127.0.0.1', 35420)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /3d/iss.glb HTTP/1.1" 304 195 0.000608
# (4067) accepted ('127.0.0.1', 35426)
# (4067) accepted ('127.0.0.1', 35436)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/earth.jpg HTTP/1.1" 304 197 0.000710
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/texture_fire.jpg HTTP/1.1" 304 204 0.000733
# (4067) accepted ('127.0.0.1', 35438)
# (4067) accepted ('127.0.0.1', 35448)
# (4067) accepted ('127.0.0.1', 35450)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/navball.png HTTP/1.1" 304 199 0.001144
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/texture_star.jpg HTTP/1.1" 304 204 0.000699
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/texture_wormhole.jpg HTTP/1.1" 304 208 0.001497
# (4067) accepted ('127.0.0.1', 35452)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /img/hud/ForwardViewSprites2.png HTTP/1.1" 304 211 0.000948
# (4067) accepted ('127.0.0.1', 35466)
# (4067) accepted ('127.0.0.1', 35472)
# (4067) accepted ('127.0.0.1', 35482)
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "POST /socket.io/?EIO=4&transport=polling&t=P4mlC-K&sid=XZwbVmDnBqEbssmLAAAA HTTP/1.1" 200 219 0.000541
# 127.0.0.1 - - [08/Aug/2024 08:46:05] "GET /socket.io/?EIO=4&transport=polling&t=P4mlC-M&sid=XZwbVmDnBqEbssmLAAAA HTTP/1.1" 200 213 0.000157
# 127.0.0.1 - - [08/Aug/2024 08:46:06] "GET /socket.io/?EIO=4&transport=polling&t=P4mlD10&sid=XZwbVmDnBqEbssmLAAAA HTTP/1.1" 200 181 0.000209
# 127.0.0.1 - - [08/Aug/2024 08:46:06] "GET /socket.io/?EIO=4&transport=polling&t=P4mlD17&sid=XZwbVmDnBqEbssmLAAAA HTTP/1.1" 200 181 0.000147
# 127.0.0.1 - - [08/Aug/2024 08:46:06] "GET /img/favicon.ico HTTP/1.1" 304 199 0.000639

# %%
agent.load("Models5/auto-docking-iss_PPO__178_9.75.pt")

# %%
agent.train(num_episodes=200,max_steps=200)
# Out:
# Reset
# Steps: 27/200. Action: 1. Reward/Value: 0.6/0.0728. Done: -10
#  Mean Policy loss: 4.4659. Mean Value loss: -1.8537
# Episode: 1/200, score/average: 3.6000/3.6000
#
# Reset
# Steps: 34/200. Action: 2. Reward/Value: 0.6/0.038. Done: -10
#  Mean Policy loss: 6.9002. Mean Value loss: -0.9757
# Episode: 2/200, score/average: 3.3000/3.4500
#
# Reset
# Steps: 41/200. Action: 2. Reward/Value: 0.6/0.0607. Done: 10
#  Mean Policy loss: 9.4273. Mean Value loss: -1.4013
# Episode: 3/200, score/average: 5.3000/4.0667
#
# Reset
# Steps: 24/200. Action: 3. Reward/Value: 0.6/0.0636. Done: 10
#  Mean Policy loss: 142.9015. Mean Value loss: -11.0003
# Episode: 4/200, score/average: 28.2000/10.1000
#
# Reset
# Steps: 55/200. Action: 1. Reward/Value: 0.3/-0.0203. Done: -1
#  Mean Policy loss: 16.2963. Mean Value loss: -2.2752
# Episode: 5/200, score/average: 7.5000/9.5800
#
# Reset
# Steps: 42/200. Action: 4. Reward/Value: 1.0/0.028. Done: 100
#  Mean Policy loss: 20.5288. Mean Value loss: -4.2266
# Episode: 6/200, score/average: 14.1000/10.3333 SAVING
#
# Reset
# Steps: 22/200. Action: 2. Reward/Value: -0.4/0.0242. Done: -1
#  Mean Policy loss: 19.0220. Mean Value loss: -4.0724
# Episode: 7/200, score/average: 9.6000/10.2286
#
# Reset
# Steps: 52/200. Action: 4. Reward/Value: -0.1/0.0703. Done: -1
#  Mean Policy loss: 19.5932. Mean Value loss: -2.7948
# Episode: 8/200, score/average: 6.7000/9.7875
#
# Reset
# Steps: 48/200. Action: 2. Reward/Value: -0.1/0.0563. Done: -1
#  Mean Policy loss: 5.4791. Mean Value loss: -0.0870
# Episode: 9/200, score/average: 3.2000/9.0556
#
# Reset
# Steps: 30/200. Action: 2. Reward/Value: -0.8/0.0452. Done: -1
#  Mean Policy loss: 10.0415. Mean Value loss: -1.7195
# Episode: 10/200, score/average: 10.4000/9.1900 SAVING
#
# Reset
# Steps: 14/200. Action: 3. Reward/Value: -0.1/-0.0101. Done: 1
#  Mean Policy loss: 10.6570. Mean Value loss: -2.5078
# Episode: 11/200, score/average: 7.8000/9.6100
#
# Reset
# Steps: 28/200. Action: 3. Reward/Value: 0.6/0.069. Done: 100
#  Mean Policy loss: 57.8893. Mean Value loss: -6.8057
# Episode: 12/200, score/average: 19.7000/11.2500 SAVING
#
# Reset
# Steps: 34/200. Action: 1. Reward/Value: -0.8/0.0012. Done: -1
#  Mean Policy loss: 94.8885. Mean Value loss: -8.9052
# Episode: 13/200, score/average: 22.3000/12.9500 SAVING
#
# Reset
# Steps: 47/200. Action: 5. Reward/Value: 0.6/0.0456. Done: 10
#  Mean Policy loss: 9.5019. Mean Value loss: -1.3683
# Episode: 14/200, score/average: 6.9000/10.8200
#
# Reset
# Steps: 27/200. Action: 3. Reward/Value: -0.1/0.1216. Done: 1
#  Mean Policy loss: 15.5947. Mean Value loss: -3.3639
# Episode: 15/200, score/average: 8.6000/10.9300
#
# Reset
# Steps: 43/200. Action: 3. Reward/Value: 0.3/0.019. Done: -10
#  Mean Policy loss: 26.9201. Mean Value loss: 3.4638
# Episode: 16/200, score/average: -6.6000/8.8600
#
# Reset
# Steps: 35/200. Action: 3. Reward/Value: 0.6/0.0374. Done: 10
#  Mean Policy loss: 16.6942. Mean Value loss: 0.5390
# Episode: 17/200, score/average: -3.6000/7.5400
#
# Reset
# Steps: 31/200. Action: 4. Reward/Value: -0.8/0.1188. Done: 1
#  Mean Policy loss: 46.8206. Mean Value loss: -5.9618
# Episode: 18/200, score/average: 18.2000/8.6900
#
# Reset
# Steps: 18/200. Action: 5. Reward/Value: -0.1/-0.0028. Done: 1
#  Mean Policy loss: 14.9322. Mean Value loss: -3.5447
# Episode: 19/200, score/average: 7.9000/9.1600
#
# Reset
# Steps: 14/200. Action: 4. Reward/Value: 0.6/-0.0114. Done: 1
#  Mean Policy loss: 36.5621. Mean Value loss: -5.0030
# Episode: 20/200, score/average: 15.5000/9.6700 SAVING
#
# Reset
# Steps: 32/200. Action: 1. Reward/Value: -0.1/-0.0452. Done: -1
#  Mean Policy loss: 1.5967. Mean Value loss: -0.2171
# Episode: 21/200, score/average: 1.0000/8.9900
#
# Reset
# Steps: 42/200. Action: 5. Reward/Value: -0.8/0.023. Done: -1
#  Mean Policy loss: 18.5438. Mean Value loss: -0.6004
# Episode: 22/200, score/average: 11.2000/8.1400
#
# Reset
# Steps: 49/200. Action: 3. Reward/Value: 0.3/0.0261. Done: -10
#  Mean Policy loss: 4.1086. Mean Value loss: -1.4318
# Episode: 23/200, score/average: 4.4000/6.3500
#
# Reset
# Steps: 36/200. Action: 4. Reward/Value: -0.8/0.0308. Done: -1
#  Mean Policy loss: 8.7580. Mean Value loss: 1.6734
# Episode: 24/200, score/average: -1.9000/5.4700
#
# Reset
# Steps: 26/200. Action: 1. Reward/Value: -0.1/-0.0026. Done: 1
#  Mean Policy loss: 23.3240. Mean Value loss: -4.4885
# Episode: 25/200, score/average: 10.0000/5.6100
#
# Reset
# Steps: 36/200. Action: 1. Reward/Value: -0.1/0.0177. Done: -1
#  Mean Policy loss: 2.5494. Mean Value loss: -1.3624
# Episode: 26/200, score/average: 4.2000/6.6900
#
# Reset
# Steps: 35/200. Action: 4. Reward/Value: 0.3/0.0173. Done: -1
#  Mean Policy loss: 8.4551. Mean Value loss: -0.5613
# Episode: 27/200, score/average: 2.5000/7.3000
#
# Reset
# Steps: 29/200. Action: 2. Reward/Value: 0.6/0.102. Done: 1000
#  Mean Policy loss: 39.0499. Mean Value loss: -5.8740
# Episode: 28/200, score/average: 17.5000/7.2300
#
# Reset
# Steps: 34/200. Action: 3. Reward/Value: -0.8/0.0691. Done: 1
#  Mean Policy loss: 27.2106. Mean Value loss: -4.2129
# Episode: 29/200, score/average: 12.7000/7.7100
#
# Reset
# Steps: 26/200. Action: 5. Reward/Value: 0.6/-0.0051. Done: 1
#  Mean Policy loss: 8.7631. Mean Value loss: -2.6513
# Episode: 30/200, score/average: 6.9000/6.8500 SAVING
#
# Reset
# Steps: 29/200. Action: 1. Reward/Value: 0.6/-0.0146. Done: -1
#  Mean Policy loss: 6.3783. Mean Value loss: 2.1435
# Episode: 31/200, score/average: -6.0000/6.1500
#
# Reset
# Steps: 24/200. Action: 5. Reward/Value: -0.1/-0.0628. Done: -1
#  Mean Policy loss: 2.6222. Mean Value loss: -1.3526
# Episode: 32/200, score/average: 2.7000/5.3000
#
# Reset
# Steps: 21/200. Action: 1. Reward/Value: -0.8/0.0842. Done: 10
#  Mean Policy loss: 16.8897. Mean Value loss: -3.1191
# Episode: 33/200, score/average: 12.0000/6.0600
#
# Reset
# Steps: 36/200. Action: 4. Reward/Value: -0.1/-0.007. Done: -1
#  Mean Policy loss: 8.8059. Mean Value loss: -1.5520
# Episode: 34/200, score/average: 4.7000/6.7200
#
# Reset
# Steps: 30/200. Action: 2. Reward/Value: 0.6/0.0778. Done: 10
#  Mean Policy loss: 17.3800. Mean Value loss: -4.0547
# Episode: 35/200, score/average: 11.2000/6.8400
#
# Reset
# Steps: 34/200. Action: 1. Reward/Value: 0.6/-0.0078. Done: 10
#  Mean Policy loss: 33.5254. Mean Value loss: -5.1012
# Episode: 36/200, score/average: 20.3000/8.4500
#
# Reset
# Steps: 43/200. Action: 3. Reward/Value: 0.3/0.0285. Done: -1
#  Mean Policy loss: 4.2849. Mean Value loss: -0.6048
# Episode: 37/200, score/average: 4.1000/8.6100
#
# Reset
# Steps: 33/200. Action: 5. Reward/Value: 1.3/0.0335. Done: 10
#  Mean Policy loss: 38.9929. Mean Value loss: -4.3949
# Episode: 38/200, score/average: 20.6000/8.9200
#
# Reset
# Steps: 27/200. Action: 1. Reward/Value: -0.1/0.1073. Done: -1
#  Mean Policy loss: 7.6508. Mean Value loss: -2.5279
# Episode: 39/200, score/average: 5.3000/8.1800
#
# Reset
# Steps: 37/200. Action: 0. Reward/Value: -0.1/0.1009. Done: -1
#  Mean Policy loss: 16.8929. Mean Value loss: -3.5476
# Episode: 40/200, score/average: 12.5000/8.7400 SAVING
#
# Reset
# Steps: 46/200. Action: 4. Reward/Value: 0.6/0.0566. Done: -1
#  Mean Policy loss: 30.3223. Mean Value loss: -2.4621
# Episode: 41/200, score/average: 13.9000/10.7300
#
# Reset
# Steps: 28/200. Action: 4. Reward/Value: 0.6/0.0496. Done: -10
#  Mean Policy loss: 9.6917. Mean Value loss: -2.6194
# Episode: 42/200, score/average: 5.5000/11.0100
#
# Reset
# Steps: 33/200. Action: 5. Reward/Value: 0.3/0.0581. Done: -1
#  Mean Policy loss: 3.6583. Mean Value loss: 0.0732
# Episode: 43/200, score/average: -2.1000/9.6000
#
# Reset
# Steps: 36/200. Action: 2. Reward/Value: -0.4/-0.0008. Done: -1
#  Mean Policy loss: 7.4811. Mean Value loss: 2.2414
# Episode: 44/200, score/average: -8.9000/8.2400
#
# Reset
# Steps: 39/200. Action: 4. Reward/Value: 0.6/0.1061. Done: 10
#  Mean Policy loss: 78.3927. Mean Value loss: -8.5124
# Episode: 45/200, score/average: 26.0000/9.7200
#
# Reset
# Steps: 53/200. Action: 5. Reward/Value: -0.1/0.0151. Done: -1
#  Mean Policy loss: 19.6395. Mean Value loss: -3.5313
# Episode: 46/200, score/average: 5.0000/8.1900
#
# Reset
# Steps: 49/200. Action: 5. Reward/Value: 0.6/0.0355. Done: 100
#  Mean Policy loss: 13.7329. Mean Value loss: -2.4799
# Episode: 47/200, score/average: 13.9000/9.1700
#
# Reset
# Steps: 16/200. Action: 4. Reward/Value: 0.6/0.1029. Done: 10
#  Mean Policy loss: 30.0338. Mean Value loss: -4.8959
# Episode: 48/200, score/average: 11.9000/8.3000
#
# Reset
# Steps: 39/200. Action: 4. Reward/Value: -0.8/0.093. Done: -1
#  Mean Policy loss: 2.5954. Mean Value loss: 0.2575
# Episode: 49/200, score/average: 2.1000/7.9800
#
# Reset
# Steps: 20/200. Action: 5. Reward/Value: -0.1/0.0357. Done: 1
#  Mean Policy loss: 30.6557. Mean Value loss: -4.8945
# Episode: 50/200, score/average: 12.0000/7.9300 SAVING
#
# Reset
# Steps: 39/200. Action: 2. Reward/Value: 1.3/0.0667. Done: -10
#  Mean Policy loss: 32.0134. Mean Value loss: -5.3733
# Episode: 51/200, score/average: 17.0000/8.2400
#
# Reset
# Steps: 37/200. Action: 1. Reward/Value: 0.6/0.0749. Done: -1
#  Mean Policy loss: 5.7041. Mean Value loss: -0.2207
# Episode: 52/200, score/average: 2.7000/7.9600
#
# Reset
# Steps: 28/200. Action: 0. Reward/Value: 1.3/0.0696. Done: -1
#  Mean Policy loss: 9.2031. Mean Value loss: -0.4673
# Episode: 53/200, score/average: -2.1000/7.9600
#
# Reset
# Steps: 23/200. Action: 5. Reward/Value: 0.6/0.0252. Done: 10
#  Mean Policy loss: 11.2728. Mean Value loss: -3.1513
# Episode: 54/200, score/average: 7.4000/9.5900
#
# Reset
# Steps: 52/200. Action: 1. Reward/Value: -0.1/0.0758. Done: -1
#  Mean Policy loss: 51.5554. Mean Value loss: -3.9207
# Episode: 55/200, score/average: 12.4000/8.2300
#
# Reset
# Steps: 36/200. Action: 1. Reward/Value: -0.4/-0.0503. Done: -1
#  Mean Policy loss: 25.1965. Mean Value loss: -0.5011
# Episode: 56/200, score/average: 7.1000/8.4400
#
# Reset
# Steps: 23/200. Action: 5. Reward/Value: -0.1/-0.005. Done: 1
#  Mean Policy loss: 54.9870. Mean Value loss: -6.3144
# Episode: 57/200, score/average: 16.5000/8.7000
#
# Reset
# Steps: 26/200. Action: 1. Reward/Value: -0.1/-0.1051. Done: -1
#  Mean Policy loss: 8.8374. Mean Value loss: -2.3603
# Episode: 58/200, score/average: 7.7000/8.2800
#
# Reset
# Steps: 40/200. Action: 5. Reward/Value: -0.8/0.1223. Done: 1
#  Mean Policy loss: 321.6805. Mean Value loss: -16.4754
# Episode: 59/200, score/average: 56.1000/13.6800 SAVING
#
# Reset
# Steps: 23/200. Action: 1. Reward/Value: 0.6/0.0472. Done: -1
#  Mean Policy loss: 3.7298. Mean Value loss: -0.3278
# Episode: 60/200, score/average: -2.0000/12.2800 SAVING
#
# Reset
# Steps: 34/200. Action: 1. Reward/Value: -0.1/-0.064. Done: -1
#  Mean Policy loss: 11.4555. Mean Value loss: -2.4395
# Episode: 61/200, score/average: 10.3000/11.6100
#
# Reset
# Steps: 21/200. Action: 4. Reward/Value: 1.3/0.0336. Done: -1
#  Mean Policy loss: 36.0419. Mean Value loss: -5.7581
# Episode: 62/200, score/average: 16.0000/12.9400
#
# Reset
# Steps: 20/200. Action: 1. Reward/Value: 0.3/0.0478. Done: -1
#  Mean Policy loss: 1.6889. Mean Value loss: -1.1887
# Episode: 63/200, score/average: 1.9000/13.3400
#
# Reset
# Steps: 37/200. Action: 4. Reward/Value: 1.3/0.0319. Done: -1
#  Mean Policy loss: 2.6703. Mean Value loss: -1.0150
# Episode: 64/200, score/average: 4.8000/13.0800
#
# Reset
# Steps: 42/200. Action: 1. Reward/Value: -0.1/0.0672. Done: 1
#  Mean Policy loss: 38.9786. Mean Value loss: -5.3020
# Episode: 65/200, score/average: 16.1000/13.4500
#
# Reset
# Steps: 40/200. Action: 4. Reward/Value: 0.3/0.0445. Done: -1
#  Mean Policy loss: 2.1310. Mean Value loss: 0.2144
# Episode: 66/200, score/average: 3.1000/13.0500
#
# Reset
# Steps: 35/200. Action: 4. Reward/Value: 0.6/0.0696. Done: 10
#  Mean Policy loss: 79.6920. Mean Value loss: -8.6267
# Episode: 67/200, score/average: 24.8000/13.8800 SAVING
#
# Reset
# Steps: 27/200. Action: 1. Reward/Value: -0.1/-0.0906. Done: -1
#  Mean Policy loss: 10.3758. Mean Value loss: -2.6662
# Episode: 68/200, score/average: 6.9000/13.8000
#
# Reset
# Steps: 31/200. Action: 4. Reward/Value: -0.1/-0.0171. Done: -1
#  Mean Policy loss: 4.5046. Mean Value loss: 0.3388
# Episode: 69/200, score/average: 2.1000/8.4000
#
# Reset
# Steps: 35/200. Action: 1. Reward/Value: 0.3/-0.0502. Done: -1
#  Mean Policy loss: 1.7278. Mean Value loss: -0.8325
# Episode: 70/200, score/average: 3.8000/8.9800 SAVING
#
# Reset
# Steps: 24/200. Action: 1. Reward/Value: -0.8/0.084. Done: -1
#  Mean Policy loss: 40.8084. Mean Value loss: 5.6218
# Episode: 71/200, score/average: -11.8000/6.7700
#
# Reset
# Steps: 34/200. Action: 3. Reward/Value: -0.1/-0.0971. Done: -1
#  Mean Policy loss: 22.9801. Mean Value loss: -4.4039
# Episode: 72/200, score/average: 14.9000/6.6600
#
# Reset
# Steps: 27/200. Action: 4. Reward/Value: -0.8/0.1235. Done: 1
#  Mean Policy loss: 41.2841. Mean Value loss: -6.1174
# Episode: 73/200, score/average: 16.5000/8.1200
#
# Reset
# Steps: 25/200. Action: 5. Reward/Value: 0.6/-0.0039. Done: 10
#  Mean Policy loss: 32.0307. Mean Value loss: -5.4310
# Episode: 74/200, score/average: 12.9000/8.9300
#
# Reset
# Steps: 45/200. Action: 5. Reward/Value: -0.1/0.0489. Done: -1
#  Mean Policy loss: 2.9200. Mean Value loss: 0.0210
# Episode: 75/200, score/average: 1.7000/7.4900
#
# Reset
# Steps: 54/200. Action: 4. Reward/Value: -0.1/-0.0067. Done: -1
#  Mean Policy loss: 8.2465. Mean Value loss: 0.0527
# Episode: 76/200, score/average: 0.9000/7.2700
#
# Reset
# Steps: 53/200. Action: 3. Reward/Value: 0.6/0.0365. Done: -10
#  Mean Policy loss: 18.0599. Mean Value loss: -5.0735
# Episode: 77/200, score/average: 6.7000/5.4600
#
# Reset
# Steps: 30/200. Action: 5. Reward/Value: -0.1/-0.0366. Done: -1
#  Mean Policy loss: 7.5548. Mean Value loss: -2.3693
# Episode: 78/200, score/average: 5.6000/5.3300
#
# Reset
# Steps: 21/200. Action: 1. Reward/Value: -0.1/0.1134. Done: 1
#  Mean Policy loss: 27.6490. Mean Value loss: -4.6601
# Episode: 79/200, score/average: 11.3000/6.2500
#
# Reset
# Steps: 34/200. Action: 5. Reward/Value: -0.1/-0.0292. Done: -1
#  Mean Policy loss: 1.8640. Mean Value loss: -0.8389
# Episode: 80/200, score/average: 0.8000/5.9500 SAVING
#
# Reset
# Steps: 48/200. Action: 1. Reward/Value: -0.1/-0.0551. Done: -1
#  Mean Policy loss: 4.3743. Mean Value loss: -1.3534
# Episode: 81/200, score/average: 6.4000/7.7700
#
# Reset
# Steps: 24/200. Action: 1. Reward/Value: -0.1/-0.0232. Done: -1
#  Mean Policy loss: 1.3227. Mean Value loss: -0.9546
# Episode: 82/200, score/average: 2.1000/6.4900
#
# Reset
# Steps: 47/200. Action: 1. Reward/Value: 0.6/0.038. Done: 1 0
#  Mean Policy loss: 3.5352. Mean Value loss: -1.3015
# Episode: 83/200, score/average: 4.1000/5.2500
#
# Reset
# Steps: 38/200. Action: 2. Reward/Value: -0.1/0.1276. Done: -1
#  Mean Policy loss: 3.0715. Mean Value loss: 0.7643
# Episode: 84/200, score/average: -1.0000/3.8600
#
# Reset
# Steps: 35/200. Action: 1. Reward/Value: -0.1/0.0685. Done: -1
#  Mean Policy loss: 12.6799. Mean Value loss: 1.1108
# Episode: 85/200, score/average: 4.7000/4.1600
#
# Reset
# Steps: 27/200. Action: 5. Reward/Value: -0.1/-0.0799. Done: -1
#  Mean Policy loss: 2.0813. Mean Value loss: 0.2007
# Episode: 86/200, score/average: 1.0000/4.1700
#
# Reset
# Steps: 27/200. Action: 5. Reward/Value: 0.3/0.0442. Done: 10
#  Mean Policy loss: 7.7850. Mean Value loss: -2.2270
# Episode: 87/200, score/average: 7.5000/4.2500
#
# Reset
# Steps: 50/200. Action: 1. Reward/Value: 0.3/0.0373. Done: -1
#  Mean Policy loss: 27.3793. Mean Value loss: -2.4030
# Episode: 88/200, score/average: 14.7000/5.1600
#
# Reset
# Steps: 47/200. Action: 4. Reward/Value: 1.3/0.0363. Done: -10
#  Mean Policy loss: 6.7428. Mean Value loss: -1.9946
# Episode: 89/200, score/average: 6.1000/4.6400
#
# Reset
# Steps: 31/200. Action: 5. Reward/Value: 0.6/0.0441. Done: 10
#  Mean Policy loss: 47.0399. Mean Value loss: -6.5305
# Episode: 90/200, score/average: 18.4000/6.4000 SAVING
#
# Reset
# Steps: 55/200. Action: 4. Reward/Value: 0.6/0.0231. Done: -10
#  Mean Policy loss: 47.0017. Mean Value loss: -6.7687
# Episode: 91/200, score/average: 15.5000/7.3100
#
# Reset
# Steps: 34/200. Action: 1. Reward/Value: 1.3/0.0494. Done: 10
#  Mean Policy loss: 15.0334. Mean Value loss: -3.5670
# Episode: 92/200, score/average: 11.7000/8.2700
#
# Reset
# Steps: 47/200. Action: 5. Reward/Value: -0.1/-0.097. Done: -1
#  Mean Policy loss: 19.8965. Mean Value loss: -4.1059
# Episode: 93/200, score/average: 12.4000/9.1000
#
# Reset
# Steps: 48/200. Action: 1. Reward/Value: -0.8/0.0982. Done: -1
#  Mean Policy loss: 28.5662. Mean Value loss: -2.4357
# Episode: 94/200, score/average: 12.6000/10.4600
#
# Reset
# Steps: 43/200. Action: 1. Reward/Value: -0.4/0.0026. Done: -1
#  Mean Policy loss: 6.8026. Mean Value loss: -1.4027
# Episode: 95/200, score/average: 7.1000/10.7000
#
# Reset
# Steps: 22/200. Action: 4. Reward/Value: 0.3/0.0457. Done: 10
#  Mean Policy loss: 35.5582. Mean Value loss: -4.7109
# Episode: 96/200, score/average: 17.3000/12.3300
#
# Reset
# Steps: 37/200. Action: 4. Reward/Value: 0.3/0.0494. Done: 10
#  Mean Policy loss: 8.0172. Mean Value loss: -2.5886
# Episode: 97/200, score/average: 7.7000/12.3500
#
# Reset
# Steps: 29/200. Action: 4. Reward/Value: -0.1/0.0087. Done: -1
#  Mean Policy loss: 3.4778. Mean Value loss: -1.3422
# Episode: 98/200, score/average: 5.4000/11.4200
#
# Reset
# Steps: 37/200. Action: 5. Reward/Value: -0.8/0.044. Done: -1
#  Mean Policy loss: 10.1111. Mean Value loss: 2.1478
# Episode: 99/200, score/average: -3.0000/10.5100
#
# Reset
# Steps: 44/200. Action: 4. Reward/Value: -0.1/0.0675. Done: -1
#  Mean Policy loss: 3.1092. Mean Value loss: 1.3596
# Episode: 100/200, score/average: -6.3000/8.0400 SAVING
#
# Reset
# Steps: 29/200. Action: 2. Reward/Value: 0.6/0.0966. Done: 10
#  Mean Policy loss: 56.8530. Mean Value loss: -7.3392
# Episode: 101/200, score/average: 18.8000/8.3700
#
# Reset
# Steps: 43/200. Action: 5. Reward/Value: -0.1/-0.0112. Done: 1
#  Mean Policy loss: 49.6482. Mean Value loss: -6.8775
# Episode: 102/200, score/average: 26.5000/9.8500
#
# Reset
# Steps: 26/200. Action: 5. Reward/Value: -0.1/-0.0143. Done: 1
#  Mean Policy loss: 24.3403. Mean Value loss: -4.3884
# Episode: 103/200, score/average: 10.9000/9.7000
#
# Reset
# Steps: 30/200. Action: 1. Reward/Value: 0.6/-0.0468. Done: 1
#  Mean Policy loss: 15.4707. Mean Value loss: -3.6296
# Episode: 104/200, score/average: 8.7000/9.3100
#
# Reset
# Steps: 19/200. Action: 5. Reward/Value: -0.1/-0.0122. Done: 1
#  Mean Policy loss: 27.8967. Mean Value loss: -4.3328
# Episode: 105/200, score/average: 13.6000/9.9600
#
# Reset
# Steps: 54/200. Action: 4. Reward/Value: -0.8/0.0706. Done: -1
#  Mean Policy loss: 111.2056. Mean Value loss: -9.2375
# Episode: 106/200, score/average: 28.5000/11.0800
#
# Reset
# Steps: 30/200. Action: 1. Reward/Value: 0.6/-0.0126. Done: 1
#  Mean Policy loss: 134.7451. Mean Value loss: -11.1033
# Episode: 107/200, score/average: 34.3000/13.7400
#
# Reset
# Steps: 50/200. Action: 5. Reward/Value: 0.6/0.0811. Done: 10
#  Mean Policy loss: 55.5157. Mean Value loss: -6.1680
# Episode: 108/200, score/average: 32.4000/16.4400 SAVING
#
# Reset
# Steps: 28/200. Action: 4. Reward/Value: 0.6/0.0372. Done: 100
#  Mean Policy loss: 26.1692. Mean Value loss: -4.4682
# Episode: 109/200, score/average: 13.9000/18.1300 SAVING
#
# Reset
# Steps: 31/200. Action: 4. Reward/Value: -0.1/0.0502. Done: -1
#  Mean Policy loss: 20.6182. Mean Value loss: 1.3658
# Episode: 110/200, score/average: 1.6000/18.9200 SAVING
#
# Reset
# Steps: 30/200. Action: 5. Reward/Value: -0.4/-0.0072. Done: -1
#  Mean Policy loss: 20.8775. Mean Value loss: -3.4255
# Episode: 111/200, score/average: 10.6000/18.1000
#
# Reset
# Steps: 47/200. Action: 1. Reward/Value: 0.3/0.0313. Done: -1
#  Mean Policy loss: 3.4297. Mean Value loss: 0.6391
# Episode: 112/200, score/average: 2.5000/15.7000
#
# Reset
# Steps: 16/200. Action: 5. Reward/Value: -0.8/0.0888. Done: 1
#  Mean Policy loss: 2.7145. Mean Value loss: -0.8206
# Episode: 113/200, score/average: 2.4000/14.8500
#
# Reset
# Steps: 41/200. Action: 4. Reward/Value: 0.6/0.0312. Done: -10
#  Mean Policy loss: 8.4953. Mean Value loss: -2.0847
# Episode: 114/200, score/average: 8.0000/14.7800
#
# Reset
# Steps: 48/200. Action: 4. Reward/Value: 0.6/0.1067. Done: 10
#  Mean Policy loss: 14.6379. Mean Value loss: -3.3434
# Episode: 115/200, score/average: 12.8000/14.7000
#
# Reset
# Steps: 41/200. Action: 5. Reward/Value: -0.4/0.0723. Done: 1
#  Mean Policy loss: 55.4882. Mean Value loss: -6.4870
# Episode: 116/200, score/average: 22.9000/14.1400
#
# Reset
# Steps: 48/200. Action: 4. Reward/Value: -0.4/0.011. Done: -1
#  Mean Policy loss: 19.0263. Mean Value loss: -1.0109
# Episode: 117/200, score/average: 8.9000/11.6000
#
# Reset
# Steps: 47/200. Action: 1. Reward/Value: -0.8/0.0635. Done: 1
#  Mean Policy loss: 42.5681. Mean Value loss: -5.4359
# Episode: 118/200, score/average: 18.6000/10.2200
#
# Reset
# Steps: 25/200. Action: 4. Reward/Value: 0.6/0.0201. Done: 1 0
#  Mean Policy loss: 1.9101. Mean Value loss: -0.9728
# Episode: 119/200, score/average: 2.4000/9.0700
#
# Reset
# Steps: 54/200. Action: 1. Reward/Value: -0.1/0.0608. Done: -1
#  Mean Policy loss: 59.7686. Mean Value loss: 1.1091
# Episode: 120/200, score/average: 3.2000/9.2300 SAVING
#
# Reset
# Steps: 22/200. Action: 3. Reward/Value: -0.8/0.02. Done: -10
#  Mean Policy loss: 1.3347. Mean Value loss: 0.5023
# Episode: 121/200, score/average: -0.1000/8.1600
#
# Reset
# Steps: 19/200. Action: 5. Reward/Value: 1.3/0.0388. Done: 1
#  Mean Policy loss: 32.6046. Mean Value loss: -5.6316
# Episode: 122/200, score/average: 11.3000/9.0400
#
# Reset
# Steps: 36/200. Action: 4. Reward/Value: 1.3/0.049. Done: 10 0
#  Mean Policy loss: 17.8289. Mean Value loss: -4.0204
# Episode: 123/200, score/average: 13.3000/10.1300
#
# Reset
# Steps: 45/200. Action: 1. Reward/Value: 0.3/0.0462. Done: 10
#  Mean Policy loss: 12.1222. Mean Value loss: -2.3545
# Episode: 124/200, score/average: 10.8000/10.4100
#
# Reset
# Steps: 24/200. Action: 5. Reward/Value: 1.3/0.0818. Done: 10
#  Mean Policy loss: 20.0430. Mean Value loss: -4.2782
# Episode: 125/200, score/average: 13.1000/10.4400
#
# Reset
# Steps: 43/200. Action: 5. Reward/Value: 1.0/0.0164. Done: -1
#  Mean Policy loss: 13.9658. Mean Value loss: -2.7547
# Episode: 126/200, score/average: 11.1000/9.2600
#
# Reset
# Steps: 41/200. Action: 1. Reward/Value: 0.3/0.0223. Done: -1
#  Mean Policy loss: 3.4833. Mean Value loss: -1.3161
# Episode: 127/200, score/average: 5.8000/8.9500
#
# Reset
# Steps: 24/200. Action: 1. Reward/Value: -0.8/-0.0344. Done: -1
#  Mean Policy loss: 1.0937. Mean Value loss: 0.8466
# Episode: 128/200, score/average: -2.6000/6.8300
#
# Reset
# Steps: 42/200. Action: 3. Reward/Value: -0.1/0.0904. Done: -1
#  Mean Policy loss: 10.4120. Mean Value loss: -1.8393
# Episode: 129/200, score/average: 10.1000/7.6000
#
# Reset
# Steps: 47/200. Action: 1. Reward/Value: 0.6/0.04. Done: -1 0
#  Mean Policy loss: 12.6296. Mean Value loss: -2.7107
# Episode: 130/200, score/average: 12.9000/8.5700 SAVING
#
# Reset
# Steps: 18/200. Action: 5. Reward/Value: 1.3/0.0171. Done: 1
#  Mean Policy loss: 19.1231. Mean Value loss: -4.2393
# Episode: 131/200, score/average: 7.2000/9.3000
#
# Reset
# Steps: 23/200. Action: 1. Reward/Value: -0.1/-0.056. Done: -1
#  Mean Policy loss: 0.5382. Mean Value loss: 0.3681
# Episode: 132/200, score/average: -1.5000/8.0200
#
# Reset
# Steps: 35/200. Action: 5. Reward/Value: 0.6/0.0707. Done: 10
#  Mean Policy loss: 34.6395. Mean Value loss: -5.4960
# Episode: 133/200, score/average: 17.7000/8.4600
#
# Reset
# Steps: 52/200. Action: 3. Reward/Value: -0.1/0.1064. Done: -1
#  Mean Policy loss: 332.3252. Mean Value loss: -17.9350
# Episode: 134/200, score/average: 47.1000/12.0900
#
# Reset
# Steps: 40/200. Action: 4. Reward/Value: -0.8/0.086. Done: 10
#  Mean Policy loss: 63.7281. Mean Value loss: -7.0429
# Episode: 135/200, score/average: 18.6000/12.6400
#
# Reset
# Steps: 32/200. Action: 4. Reward/Value: -0.1/0.0672. Done: -1
#  Mean Policy loss: 33.3674. Mean Value loss: -1.4938
# Episode: 136/200, score/average: 14.0000/12.9300
#
# Reset
# Steps: 58/200. Action: 4. Reward/Value: -0.8/0.0019. Done: -1
#  Mean Policy loss: 30.4311. Mean Value loss: 0.7986
# Episode: 137/200, score/average: -2.6000/12.0900
#
# Reset
# Steps: 39/200. Action: 1. Reward/Value: -0.1/0.0904. Done: 10
#  Mean Policy loss: 26.7262. Mean Value loss: -4.3678
# Episode: 138/200, score/average: 16.1000/13.9600
#
# Reset
# Steps: 52/200. Action: 4. Reward/Value: 1.0/0.0411. Done: 10
#  Mean Policy loss: 12.4388. Mean Value loss: -4.0340
# Episode: 139/200, score/average: 6.6000/13.6100
#
# Reset
# Steps: 89/200. Action: 5. Reward/Value: -0.1/-0.0582. Done: -1
#  Mean Policy loss: 42.8016. Mean Value loss: -3.5060
# Episode: 140/200, score/average: 8.0000/13.1200 SAVING
#
# Reset
# Steps: 33/200. Action: 5. Reward/Value: -0.1/-0.0222. Done: -1
#  Mean Policy loss: 3.3462. Mean Value loss: -1.3226
# Episode: 141/200, score/average: 5.0000/12.9000
#
# Reset
# Steps: 40/200. Action: 4. Reward/Value: 0.6/0.0526. Done: 10
#  Mean Policy loss: 45.2966. Mean Value loss: -5.6947
# Episode: 142/200, score/average: 21.5000/15.2000
#
# Reset
# Steps: 55/200. Action: 5. Reward/Value: -0.4/0.0498. Done: 1
#  Mean Policy loss: 40.6901. Mean Value loss: -7.6639
# Episode: 143/200, score/average: 15.2000/14.9500
#
# Reset
# Steps: 26/200. Action: 5. Reward/Value: -0.1/-0.0311. Done: 1
#  Mean Policy loss: 48.9137. Mean Value loss: -6.5563
# Episode: 144/200, score/average: 16.4000/11.8800
#
# Reset
# Steps: 49/200. Action: 5. Reward/Value: -0.1/-0.0048. Done: 1
#  Mean Policy loss: 37.2836. Mean Value loss: -5.4122
# Episode: 145/200, score/average: 22.5000/12.2700
#
# Reset
# Steps: 37/200. Action: 3. Reward/Value: 1.3/-0.0432. Done: -1
#  Mean Policy loss: 31.8193. Mean Value loss: -5.1039
# Episode: 146/200, score/average: 18.3000/12.7000
#
# Reset
# Steps: 64/200. Action: 5. Reward/Value: -0.8/-0.0528. Done: -1
#  Mean Policy loss: 126.0766. Mean Value loss: -15.0393
# Episode: 147/200, score/average: 34.3000/16.3900
#
# Reset
# Steps: 77/200. Action: 4. Reward/Value: -0.8/0.0123. Done: -1
#  Mean Policy loss: 60.6579. Mean Value loss: -3.2345
# Episode: 148/200, score/average: 11.6000/15.9400
#
# Reset
# Steps: 84/200. Action: 5. Reward/Value: -0.8/0.0707. Done: -1
#  Mean Policy loss: 218.4669. Mean Value loss: -17.4647
# Episode: 149/200, score/average: 52.3000/20.5100 SAVING
#
# Reset
# Steps: 44/200. Action: 4. Reward/Value: 1.0/0.0464. Done: 100
#  Mean Policy loss: 35.0777. Mean Value loss: -4.6948
# Episode: 150/200, score/average: 24.9000/22.2000 SAVING
#
# Reset
# Steps: 54/200. Action: 4. Reward/Value: -0.8/-0.0032. Done: -1
#  Mean Policy loss: 27.5815. Mean Value loss: 4.9042
# Episode: 151/200, score/average: -6.6000/21.0400
#
# Reset
# Steps: 85/200. Action: 5. Reward/Value: -0.4/-0.0039. Done: -1
#  Mean Policy loss: 30.6826. Mean Value loss: -5.2750
# Episode: 152/200, score/average: 14.9000/20.3800
#
# Reset
# Steps: 57/200. Action: 4. Reward/Value: 0.3/0.0771. Done: -1
#  Mean Policy loss: 49.2075. Mean Value loss: -4.4393
# Episode: 153/200, score/average: 11.9000/20.0500
#
# Reset
# Steps: 39/200. Action: 4. Reward/Value: 1.0/0.0435. Done: -1
#  Mean Policy loss: 11.6487. Mean Value loss: -3.0337
# Episode: 154/200, score/average: 11.4000/19.5500
#
# Reset
# Steps: 69/200. Action: 5. Reward/Value: -0.4/0.0079. Done: -1
#  Mean Policy loss: 13.1407. Mean Value loss: -1.3988
# Episode: 155/200, score/average: 4.9000/17.7900
#
# Reset
# Steps: 46/200. Action: 3. Reward/Value: -0.4/0.0288. Done: 10
#  Mean Policy loss: 44.7673. Mean Value loss: -5.4849
# Episode: 156/200, score/average: 21.6000/18.1200
#
# Reset
# Steps: 108/200. Action: 5. Reward/Value: -0.1/-0.0398. Done: -1
#  Mean Policy loss: 61.7124. Mean Value loss: -9.8831
# Episode: 157/200, score/average: 24.4000/17.1300
#
# Reset
# Steps: 48/200. Action: 1. Reward/Value: 1.3/0.0654. Done: 100
#  Mean Policy loss: 38.0888. Mean Value loss: -5.8756
# Episode: 158/200, score/average: 22.6000/18.2300
#
# Reset
# Steps: 27/200. Action: 4. Reward/Value: 0.6/0.0176. Done: 1 0
#  Mean Policy loss: 10.2481. Mean Value loss: -2.7045
# Episode: 159/200, score/average: 8.3000/13.8300
#
# Reset
# Steps: 62/200. Action: 4. Reward/Value: 1.3/0.0266. Done: 10
#  Mean Policy loss: 150.3090. Mean Value loss: -15.9696
# Episode: 160/200, score/average: 36.0000/14.9400 SAVING
#
# Reset
# Steps: 73/200. Action: 5. Reward/Value: 0.6/0.0326. Done: -10
#  Mean Policy loss: 90.3644. Mean Value loss: -11.2472
# Episode: 161/200, score/average: 27.8000/18.3800
#
# Reset
# Steps: 61/200. Action: 5. Reward/Value: -0.8/0.0109. Done: -1
#  Mean Policy loss: 16.7732. Mean Value loss: 0.0367
# Episode: 162/200, score/average: 3.2000/17.2100
#
# Reset
# Steps: 64/200. Action: 2. Reward/Value: 0.6/0.0793. Done: 100
#  Mean Policy loss: 96.0215. Mean Value loss: -12.7451
# Episode: 163/200, score/average: 25.1000/18.5300
#
# Reset
# Steps: 65/200. Action: 3. Reward/Value: 1.3/0.0928. Done: 1
#  Mean Policy loss: 413.6169. Mean Value loss: -27.1769
# Episode: 164/200, score/average: 70.9000/24.4800 SAVING
#
# Reset
# Steps: 111/200. Action: 5. Reward/Value: -0.1/-0.0076. Done: 1
#  Mean Policy loss: 22.6106. Mean Value loss: -5.4444
# Episode: 165/200, score/average: 14.5000/25.4400 SAVING
#
# Reset
# Steps: 33/200. Action: 4. Reward/Value: -0.4/-0.0654. Done: -1
#  Mean Policy loss: 22.1599. Mean Value loss: -3.8505
# Episode: 166/200, score/average: 11.7000/24.4500
#
# Reset
# Steps: 88/200. Action: 5. Reward/Value: -0.4/0.0304. Done: 10
#  Mean Policy loss: 54.9223. Mean Value loss: -8.7687
# Episode: 167/200, score/average: 28.6000/24.8700
#
# Reset
# Steps: 88/200. Action: 4. Reward/Value: 0.6/0.0621. Done: -10
#  Mean Policy loss: 27.6352. Mean Value loss: -2.8042
# Episode: 168/200, score/average: 13.1000/23.9200
#
# Reset
# Steps: 40/200. Action: 4. Reward/Value: 0.6/0.0362. Done: 1 0
#  Mean Policy loss: 19.9714. Mean Value loss: -3.9962
# Episode: 169/200, score/average: 14.3000/24.5200
#
# Reset
# Steps: 135/200. Action: 4. Reward/Value: 0.6/0.0424. Done: 1 0
#  Mean Policy loss: 59.0874. Mean Value loss: -8.1633
# Episode: 170/200, score/average: 28.9000/23.8100 SAVING
#
# Reset
# Steps: 101/200. Action: 4. Reward/Value: 0.6/0.0595. Done: -1
#  Mean Policy loss: 33.9709. Mean Value loss: -5.7340
# Episode: 171/200, score/average: 17.4000/22.7700
#
# Reset
# Steps: 41/200. Action: 4. Reward/Value: 0.6/-0.0282. Done: -1
#  Mean Policy loss: 11.3645. Mean Value loss: -2.8147
# Episode: 172/200, score/average: 11.0000/23.5500
#
# Reset
# Steps: 91/200. Action: 5. Reward/Value: 2.0/0.0261. Done: 1 0
#  Mean Policy loss: 34.7302. Mean Value loss: -6.3005
# Episode: 173/200, score/average: 21.1000/23.1500
#
# Reset
# Steps: 83/200. Action: 5. Reward/Value: -0.8/0.0686. Done: 10
#  Mean Policy loss: 172.9798. Mean Value loss: -16.9277
# Episode: 174/200, score/average: 49.2000/20.9800
#
# Reset
# Steps: 101/200. Action: 4. Reward/Value: 1.3/0.0777. Done: -1
#  Mean Policy loss: 91.3381. Mean Value loss: -9.6820
# Episode: 175/200, score/average: 19.8000/21.5100
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: 1.0/0.055. Done: 0000
#  Mean Policy loss: 254.3648. Mean Value loss: -24.8571
# Episode: 176/200, score/average: 83.4000/28.6800 SAVING
#
# Reset
# Steps: 71/200. Action: 4. Reward/Value: 0.6/-0.0274. Done: -1
#  Mean Policy loss: 484.1522. Mean Value loss: -29.9311
# Episode: 177/200, score/average: 81.5000/33.9700 SAVING
#
# Reset
# Steps: 143/200. Action: 3. Reward/Value: 0.6/0.074. Done: 1000
#  Mean Policy loss: 106.9313. Mean Value loss: -15.0486
# Episode: 178/200, score/average: 47.8000/37.4400 SAVING
#
# Reset
# Steps: 134/200. Action: 5. Reward/Value: -0.1/-0.0554. Done: -1
#  Mean Policy loss: 57.6250. Mean Value loss: -7.8335
# Episode: 179/200, score/average: 25.3000/38.5400 SAVING
#
# Reset
# Steps: 150/200. Action: 5. Reward/Value: -0.4/-0.0375. Done: -1
#  Mean Policy loss: 216.2739. Mean Value loss: -19.3509
# Episode: 180/200, score/average: 64.1000/42.0600 SAVING
#
# Reset
# Steps: 110/200. Action: 5. Reward/Value: -0.8/0.093. Done: 10
#  Mean Policy loss: 251.4211. Mean Value loss: -16.9982
# Episode: 181/200, score/average: 54.6000/45.7800 SAVING
#
# Reset
# Steps: 144/200. Action: 4. Reward/Value: -0.8/0.0578. Done: 10
#  Mean Policy loss: 62.4340. Mean Value loss: -10.3163
# Episode: 182/200, score/average: 33.9000/48.0700 SAVING
#
# Reset
# Steps: 174/200. Action: 4. Reward/Value: -0.1/0.0639. Done: 1
#  Mean Policy loss: 731.5277. Mean Value loss: -47.3884
# Episode: 183/200, score/average: 131.0000/59.0600 SAVING
#
# Reset
# Steps: 142/200. Action: 4. Reward/Value: 1.3/0.0452. Done: 10
#  Mean Policy loss: 75.0872. Mean Value loss: -7.6730
# Episode: 184/200, score/average: 32.8000/57.4200
#
# Reset
# Steps: 116/200. Action: 4. Reward/Value: 1.0/0.0371. Done: 10
#  Mean Policy loss: 57.3088. Mean Value loss: -9.8953
# Episode: 185/200, score/average: 24.1000/57.8500
#
# Reset
# Steps: 76/200. Action: 4. Reward/Value: 0.3/0.049. Done: -100
#  Mean Policy loss: 50.8333. Mean Value loss: -6.1308
# Episode: 186/200, score/average: 23.4000/51.8500
#
# Reset
# Steps: 189/200. Action: 4. Reward/Value: 0.3/0.0623. Done: 100
#  Mean Policy loss: 81.7017. Mean Value loss: -13.4856
# Episode: 187/200, score/average: 37.7000/47.4700
#
# Reset
# Steps: 84/200. Action: 4. Reward/Value: -0.1/0.0586. Done: -1
#  Mean Policy loss: 18.2930. Mean Value loss: 1.9171
# Episode: 188/200, score/average: -2.2000/42.4700
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: 1.0/0.0304. Done: 000
#  Mean Policy loss: 351.3056. Mean Value loss: -26.5116
# Episode: 189/200, score/average: 90.2000/48.9600
#
# Reset
# Steps: 154/200. Action: 4. Reward/Value: 1.0/0.0262. Done: 100
#  Mean Policy loss: 196.3593. Mean Value loss: -24.6340
# Episode: 190/200, score/average: 64.2000/48.9700 SAVING
#
# Reset
# Steps: 46/200. Action: 5. Reward/Value: -0.8/0.1163. Done: 10
#  Mean Policy loss: 53.7899. Mean Value loss: -7.0726
# Episode: 191/200, score/average: 25.0000/46.0100
#
# Reset
# Steps: 66/200. Action: 4. Reward/Value: 1.3/0.0908. Done: 100
#  Mean Policy loss: 156.6638. Mean Value loss: -17.0147
# Episode: 192/200, score/average: 39.1000/46.5300
#
# Reset
# Steps: 69/200. Action: 4. Reward/Value: -0.1/-0.004. Done: 10
#  Mean Policy loss: 127.3452. Mean Value loss: -13.9835
# Episode: 193/200, score/average: 35.8000/37.0100
#
# Reset
# Steps: 129/200. Action: 4. Reward/Value: 1.0/0.0283. Done: 10
#  Mean Policy loss: 159.5234. Mean Value loss: -18.4528
# Episode: 194/200, score/average: 50.5000/38.7800
#
# Reset
# Steps: 166/200. Action: 5. Reward/Value: 0.6/-0.0189. Done: -1
#  Mean Policy loss: 613.4341. Mean Value loss: -48.3819
# Episode: 195/200, score/average: 131.6000/49.5300
#
# Reset
# Steps: 63/200. Action: 5. Reward/Value: -0.1/0.0675. Done: 1
#  Mean Policy loss: 238.6262. Mean Value loss: -19.9612
# Episode: 196/200, score/average: 43.9000/51.5800
#
# Reset
# Steps: 61/200. Action: 4. Reward/Value: 1.3/0.0714. Done: 1 0
#  Mean Policy loss: 116.8047. Mean Value loss: -13.8162
# Episode: 197/200, score/average: 32.1000/51.0200
#
# Reset
# Steps: 52/200. Action: 5. Reward/Value: 0.6/0.0432. Done: 100
#  Mean Policy loss: 103.2526. Mean Value loss: -13.1686
# Episode: 198/200, score/average: 27.4000/53.9800
#
# Reset
# Steps: 109/200. Action: 4. Reward/Value: 1.3/0.0362. Done: -10
#  Mean Policy loss: 180.7999. Mean Value loss: -15.8258
# Episode: 199/200, score/average: 33.3000/48.2900
#
# Reset
# Steps: 126/200. Action: 5. Reward/Value: -0.8/0.0094. Done: -1
#  Mean Policy loss: 62.9305. Mean Value loss: -8.6500
# Episode: 200/200, score/average: 27.0000/44.5700 SAVING

# %%
agent.load("Models6/auto-docking-iss_PPO__100_8.04.pt")
# Out:
# ./Models6/auto-docking-iss_PPO__100_8.04.pt

# %%
agent.test(500)
# Out:
# Reset
# Steps: 38/500. Action: 5. Score/Value: 0.6/0.0401. Done: 0
# Next state: [-0.10140000001828753, -0.6925, 0.8913000000000015, -0.1205522352288236, 0.0, -0.06509820702325397]

# %%
import os
import pyautogui

# Simular pulsación de Ctrl+S
pyautogui.hotkey('ctrl', 's')

os.system('sudo shutdown')
# os.system('sudo shutdown -c')
# Out:
# Shutdown scheduled for Thu 2024-08-08 08:26:34 CEST, use 'shutdown -c' to cancel.
# 0

# %%
import time
from math import sqrt
import matplotlib.pyplot as plt
import random
from env3 import Env
import os
import numpy as np
import torch
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader
from copy import deepcopy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class ExperienceDataset(Dataset):
    def __init__(self, data):
        super().__init__()
        self.data = data

    def __len__(self):
        return len(self.data[0])

    def __getitem__(self, ind):
        return tuple(map(lambda t: t[ind], self.data))

def create_shuffled_dataloader(data, batch_size):
    ds = ExperienceDataset(data)
    return DataLoader(ds, batch_size = batch_size, shuffle = True)

# %%
class PolicyNetwork(torch.nn.Module):
    def __init__(self,state_dims, n_actions):
        super(PolicyNetwork, self).__init__()
        self.actor = torch.nn.Sequential(
            torch.nn.Linear(6, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, n_actions),
            torch.nn.Softmax(dim=-1)
        )

    def forward(self, x):
        policy = self.actor(x)
        return policy
    

class ValueNetwork(torch.nn.Module):
    def __init__(self,state_dims):
        super(ValueNetwork, self).__init__()
        self.critic = torch.nn.Sequential(
            torch.nn.Linear(6, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        value = self.critic(x)
        return value
        
def weights_init(m):
    if isinstance(m,torch.nn.Linear):
        m.bias.data.fill_(0)
        torch.nn.init.kaiming_uniform_(m.weight)


def np_to_tensor(x):
    return torch.tensor(x).to(torch.float32)

    
policy_model = PolicyNetwork(state_dims=6, n_actions = 6)
value_model = ValueNetwork(state_dims=6)

# %%
print(policy_model,value_model)
summary(policy_model, input_size=(1, 6))
summary(value_model, input_size=(1, 6))
# Out:
# PolicyNetwork(
#   (actor): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=6, bias=True)
#     (5): Softmax(dim=-1)
#   )
# ) ValueNetwork(
#   (critic): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             448
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 32]           2,080
#               ReLU-4                [-1, 1, 32]               0
#             Linear-5                 [-1, 1, 6]             198
#            Softmax-6                 [-1, 1, 6]               0
# ================================================================
# Total params: 2,726
# Trainable params: 2,726
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             448
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 32]           2,080
#               ReLU-4                [-1, 1, 32]               0
#             Linear-5                 [-1, 1, 1]              33
# ================================================================
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------

# %%
class PPO:
    def __init__(self, state_dim=6, action_dim=6, policy_lr=0.0005, value_lr=0.001, 
                 gamma=0.99, lam=0.95, beta_s=0.01,epsilon_clip=0.2, value_clip=0.4, 
                 epochs=10,batch_size=50,save_path='Models'):
        
        self.policy_net = PolicyNetwork(state_dim, action_dim).to(device)
        self.value_net = ValueNetwork(state_dim).to(device)
        self.policy_net.apply(weights_init)
        self.value_net.apply(weights_init)

        self.policy_optimizer = torch.optim.Adam(self.policy_net.parameters(), lr=policy_lr)
        self.value_optimizer = torch.optim.Adam(self.value_net.parameters(), lr=value_lr)

        self.gamma = gamma
        self.lamda = lam
        self.epsilon_clip = epsilon_clip
        self.value_clip = value_clip
        self.beta_s = beta_s
        self.epochs = epochs
        self.action_dim = action_dim
        self.batch_size = batch_size

        self.env = Env()
        self.env.run()

        self.save_path = save_path
        self.env_name = "auto-docking-iss"

        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
        self.path = str(self.env_name)+'_PPO_'
        self.model_name = os.path.join(self.save_path, self.path)

        self.trajectory = {'states':[],'actions':[], 'rewards':[], 'action_logs':[],
                           'values':[],'done':[]}
        
        self.scores, self.episodes, self.average = [],[],[]
        self.value_loss_mean, self.policy_loss_mean = [], []

    def save(self,episode,score):
        torch.save({
            'actor': self.policy_net.state_dict(),
            'critic': self.value_net.state_dict()
        }, f'./'+ self.model_name + '_' + str(episode) + '_' + str(round(score,4)) + '.pt')

    def load(self,name):
        print(f'./{self.save_path}/{name}')
        try:
            data = torch.load(f'./{self.save_path}/{name}')
            self.policy_net.load_state_dict(data['actor'])
            self.value_net.load_state_dict(data['critic'])
        except Exception as e:
            print(e)

    # Función para visualizar la evolución del entrenamiento
    def plot_model(self, score, episode,num_episodes):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-10:]) / len(self.scores[-10:]))
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(1,figsize=(18, 9))
            plt.plot(self.episodes, self.scores, 'b')
            plt.plot(self.episodes, self.average, 'r')
            plt.ylabel('Score', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"scores.png")
            except OSError:
                pass

        return self.average[-1]
    
    def plot_loss(self,episode,num_episodes):        
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(2,figsize=(18, 9))
            plt.plot(self.episodes, self.policy_loss_mean, 'b')
            plt.plot(self.episodes, self.value_loss_mean, 'r')
            plt.ylabel('Loss', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"loss.png")
            except OSError:
                pass
    

    #Almacenamiento de todas las variables que definen una transición para PPO
    def collect_trayectory(self,state,action,action_logs,reward,done,value):
        # action_onehot = np.zeros([self.action_dim])
        # action_onehot[action] = 1
        self.trajectory['states'].append(state)
        self.trajectory['actions'].append(action)
        self.trajectory['rewards'].append(reward)
        self.trajectory['values'].append(value)
        self.trajectory['action_logs'].append(action_logs)
        self.trajectory['done'].append(done)
    
    def clear_trayectory(self):
        for key in self.trajectory.keys():
            self.trajectory[key].clear()
    
    def select_action(self,state):
        action_probs = self.policy_net(state).squeeze().detach()
        dist = torch.distributions.Categorical(action_probs)
        action = dist.sample()
        action_log_probs = dist.log_prob(action)
        
        return action.item(),action_log_probs,dist.entropy().item()

    
    def generalized_advantage_estimation(self,next_state):
        advantages = np.zeros_like(self.trajectory['rewards'])
        last_gae_lambda = 0
        self.trajectory['values'].append(self.value_net(next_state).squeeze().detach())

        for t in reversed(range(len(self.trajectory['rewards']))):
            delta = self.trajectory['rewards'][t]+ self.gamma * self.trajectory['values'][t + 1].item() - self.trajectory['values'][t].item()
            advantages[t] = last_gae_lambda = delta + self.gamma * self.lamda * last_gae_lambda
        
        return np_to_tensor(advantages)


    def learn_from_episode_trajectory(self,next_state):
        self.policy_net.train()
        self.value_net.train()

        # to_torch_tensor = lambda t: torch.stack(t).to(device).detach()

        states = deepcopy(self.trajectory['states'])
        actions = deepcopy(self.trajectory['actions'])
        # rewards = deepcopy(self.trajectory['rewards'])
        values = deepcopy(self.trajectory['values'])
        action_logs = deepcopy(self.trajectory['action_logs'])
        # done = deepcopy(self.trajectory['done'])

        advantages = self.generalized_advantage_estimation(next_state).to(device)

        # prepare dataloader for policy phase training
        dl = create_shuffled_dataloader([states, actions, action_logs, advantages, values], self.batch_size)

        policy_loss_array = []
        value_loss_array = []

        for i in range(self.epochs):
            for states, actions, action_log, advantages, values in dl:
                #Update policy_net
                new_action_probs = self.policy_net(states).squeeze()
                dist = torch.distributions.Categorical(new_action_probs)

                # print("")
                # print(actions)
                # print(new_action_probs)
                new_action_logs = dist.log_prob(actions)
                entropy = dist.entropy()

                # compute PPO-Clip
                ratios = torch.exp(new_action_logs - action_log)
                surr1 = ratios * advantages
                surr2 = ratios.clamp(1 - self.epsilon_clip, 1 + self.epsilon_clip) * advantages
                policy_loss = -torch.mean(torch.min(surr1, surr2) - self.beta_s * entropy)
                policy_loss_array.append(policy_loss.detach().numpy())

                self.policy_optimizer.zero_grad() # Clean gradients
                policy_loss.mean().backward() # Compute gradients
                self.policy_optimizer.step() #Update weights

                #Update value_net
                new_values = self.value_net(states).squeeze()
                value_clipped = values + (new_values - values).clamp(-self.value_clip, self.value_clip)
                value_loss_1 = (value_clipped.flatten() - advantages) ** 2
                value_loss_2 = (values.flatten() - advantages) ** 2
                value_loss = torch.mean(torch.max(value_loss_1, value_loss_2))
                value_loss_array.append(value_loss.detach().numpy())

                self.value_optimizer.zero_grad() # Clean gradients
                value_loss.backward() # Compute gradients 

        self.value_loss_mean.append(sum(value_loss_array)/self.epochs)
        self.policy_loss_mean.append(sum(policy_loss_array)/self.epochs)

        print(f"\n Mean Policy loss: {self.value_loss_mean[-1]:.4f}. Mean Value loss: {self.policy_loss_mean[-1]:.4f}")
        
        self.policy_net.eval()
        self.value_net.eval()


    # Función para resetear el entorno tras acabar trayectoria
    def reset(self):
        state = self.env.reset()
        return np_to_tensor(self.process_state(state))
    
     # Función para interacción agente-entorno
    def step(self, action):
        next_state, reward, done = self.env.step(action)
        next_state = self.process_state(next_state)
        return np_to_tensor(next_state), reward, done

    def process_state(self,state):
        state_processed = np.array(state)
        state_processed[:3] = state_processed[:3] / 40 # Position array
        return state_processed
    
    def train(self,num_episodes=200,max_steps=200):
        average = 0
        self.policy_net.eval()
        self.value_net.eval()

        max_score_average = -5000

        for episode in range(1,num_episodes+1):
            self.clear_trayectory()

            state = self.reset()
            score = 0

            SAVING = ""

            for step in range(1,max_steps+1):
                
                action_probs = self.policy_net(state).squeeze().detach()
                dist = torch.distributions.Categorical(action_probs)
                action = dist.sample()
                action_log = dist.log_prob(action)

                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action.item())    
                self.collect_trayectory(state,action,action_log,reward,done,value)

                state = next_state

                score += reward

                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Reward/Value: {round(reward,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)

                if done:
                    break
                
                time.sleep(1)

            self.learn_from_episode_trajectory(next_state)
            self.clear_trayectory()

            average = self.plot_model(score, episode,num_episodes)
            self.plot_loss(episode,num_episodes)
            
            if average >= max_score_average and episode > 5:
                max_score_average = average
                self.save(episode,score)
                SAVING = "SAVING"
            elif episode % 10 == 0:
                self.save(episode,score)
                SAVING = "SAVING"
            else:
                SAVING = ""
            
            print(f"Episode: {episode}/{num_episodes}, score/average: {score:.4f}/{average:.4f} {SAVING}\n")


        # close environemnt when finish training
        self.save(episode,score)

    def test(self,max_steps):
        self.policy_net.eval()
        self.value_net.eval()

        self.clear_trayectory()
        state = self.reset()
        score = 0

        start = time.time()
        end = time.time()
        step = 0

        while True:
            end = time.time()
            if end - start >= 1.0:
                step += 1
                action_probabilities = self.policy_net(state)
                action = torch.argmax(action_probabilities, dim=-1).item()#np.argmax(self.policy_net(state).squeeze().detach().numpy())
                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action)    

                state = next_state

                score += reward

                # print(action_probabilities)
                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Score/Value: {round(score,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)
                start = time.time()

            if self.env.done:
                break

        state_end = self.env.get_state()
        
        print(f'\nNext state: {state_end}')

# %%
agent = PPO(save_path='Models5')
# Out:
# (5462) wsgi starting up on http://127.0.0.1:5000
# (5462) accepted ('127.0.0.1', 50452)
# (5462) accepted ('127.0.0.1', 50464)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET / HTTP/1.1" 304 242 0.005368
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /css/normalize.css HTTP/1.1" 304 201 0.001272
# (5462) accepted ('127.0.0.1', 50474)
# (5462) accepted ('127.0.0.1', 50478)
# (5462) accepted ('127.0.0.1', 50482)
# (5462) accepted ('127.0.0.1', 50498)
# (5462) accepted ('127.0.0.1', 50508)
# (5462) accepted ('127.0.0.1', 50520)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /css/layout.css HTTP/1.1" 304 198 0.000773
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /js/three/three.js HTTP/1.1" 304 196 0.000565
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /js/three/WebGL.js HTTP/1.1" 304 196 0.000356
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /js/three/GLTFLoader.js HTTP/1.1" 304 201 0.000352
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /js/three/CSS2DRenderer.js HTTP/1.1" 304 204 0.001184
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /js/gsap3/gsap.js HTTP/1.1" 304 195 0.000522
# (5462) accepted ('127.0.0.1', 50532)
# (5462) accepted ('127.0.0.1', 50546)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /js/gsap3/DrawSVGPlugin.js HTTP/1.1" 304 204 0.000620
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /js/gsap3/ScrambleTextPlugin.js HTTP/1.1" 304 209 0.000606
# (5462) accepted ('127.0.0.1', 50562)
# (5462) accepted ('127.0.0.1', 50568)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/hud-darken.png HTTP/1.1" 304 202 0.000607
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/hud-ring.png HTTP/1.1" 304 200 0.000393
# (5462) accepted ('127.0.0.1', 50580)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/hud-ring-inner.png HTTP/1.1" 304 206 0.000507
# (5462) accepted ('127.0.0.1', 50588)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/shadow.png HTTP/1.1" 304 198 0.000433
# (5462) accepted ('127.0.0.1', 50590)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /js/threed.js HTTP/1.1" 304 197 0.000508
# (5462) accepted ('127.0.0.1', 50604)
# (5462) accepted ('127.0.0.1', 50610)
# (5462) accepted ('127.0.0.1', 50620)
# (5462) accepted ('127.0.0.1', 50622)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/instructions/step1_6.jpg HTTP/1.1" 304 199 0.000593
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/instructions/step2.jpg HTTP/1.1" 304 197 0.000398
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/instructions/step3.jpg HTTP/1.1" 304 197 0.000529
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/instructions/step4.jpg HTTP/1.1" 304 197 0.000436
# (5462) accepted ('127.0.0.1', 50628)
# (5462) accepted ('127.0.0.1', 50640)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/instructions/step5.jpg HTTP/1.1" 304 197 0.000359
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/instructions/step7.jpg HTTP/1.1" 304 197 0.000380
# (5462) accepted ('127.0.0.1', 50654)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /socket.io/?EIO=4&transport=polling&t=P4kOHTU HTTP/1.1" 200 278 0.000413
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/hud/ForwardViewSprites.json HTTP/1.1" 304 211 0.000825
# (5462) accepted ('127.0.0.1', 50670)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /3d/iss.glb HTTP/1.1" 304 195 0.000777
# (5462) accepted ('127.0.0.1', 50674)
# (5462) accepted ('127.0.0.1', 50690)
# (5462) accepted ('127.0.0.1', 50698)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/earth.jpg HTTP/1.1" 304 197 0.000551
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/navball.png HTTP/1.1" 304 199 0.000422
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/texture_fire.jpg HTTP/1.1" 304 204 0.000382
# (5462) accepted ('127.0.0.1', 50714)
# (5462) accepted ('127.0.0.1', 50726)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/texture_wormhole.jpg HTTP/1.1" 304 208 0.000363
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/texture_star.jpg HTTP/1.1" 304 204 0.000485
# (5462) accepted ('127.0.0.1', 50728)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /img/hud/ForwardViewSprites2.png HTTP/1.1" 304 211 0.000693
# (5462) accepted ('127.0.0.1', 50736)
# (5462) accepted ('127.0.0.1', 50740)
# (5462) accepted ('127.0.0.1', 50744)
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "POST /socket.io/?EIO=4&transport=polling&t=P4kOHXT&sid=BygjM8lNpAGHPVtxAAAA HTTP/1.1" 200 219 0.000452
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /socket.io/?EIO=4&transport=polling&t=P4kOHXU&sid=BygjM8lNpAGHPVtxAAAA HTTP/1.1" 200 213 0.000094
# 127.0.0.1 - - [07/Aug/2024 21:46:40] "GET /socket.io/?EIO=4&transport=polling&t=P4kOHZK&sid=BygjM8lNpAGHPVtxAAAA HTTP/1.1" 200 181 0.000178
# 127.0.0.1 - - [07/Aug/2024 21:46:41] "GET /img/favicon.ico HTTP/1.1" 304 199 0.000664

# %%
agent.train(num_episodes=200,max_steps=200)
# Out:
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.25/0.2407. Done: 0
#  Mean Policy loss: 186.3427. Mean Value loss: 24.3197
# Episode: 1/200, score/average: -80.6500/-80.6500
#
# Reset
# Steps: 185/200. Action: 2. Reward/Value: -0.55/0.018. Done: -1
#  Mean Policy loss: 132.6760. Mean Value loss: 4.7814
# Episode: 2/200, score/average: -15.6000/-48.1250
#
# Reset
# Steps: 32/200. Action: 3. Reward/Value: -0.55/0.0799. Done: -1
#  Mean Policy loss: 6.8615. Mean Value loss: 1.4865
# Episode: 3/200, score/average: -3.9000/-33.3833
#
# Reset
# Steps: 42/200. Action: 4. Reward/Value: -1.0/0.0416. Done: -1
#  Mean Policy loss: 31.7409. Mean Value loss: 4.4898
# Episode: 4/200, score/average: -10.1000/-27.5625
#
# Reset
# Steps: 62/200. Action: 3. Reward/Value: -1.0/0.078. Done: -10
#  Mean Policy loss: 52.9901. Mean Value loss: 2.6835
# Episode: 5/200, score/average: 0.7500/-21.9000
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -0.0/0.1317. Done: 00
#  Mean Policy loss: 74.3708. Mean Value loss: 8.3230
# Episode: 6/200, score/average: -22.2500/-21.9583 SAVING
#
# Reset
# Steps: 48/200. Action: 3. Reward/Value: 0.4/0.0704. Done: -10
#  Mean Policy loss: 11.8825. Mean Value loss: 2.8988
# Episode: 7/200, score/average: -9.4500/-20.1714 SAVING
#
# Reset
# Steps: 98/200. Action: 4. Reward/Value: -0.55/-0.099. Done: -1
#  Mean Policy loss: 46.1324. Mean Value loss: 8.4396
# Episode: 8/200, score/average: -30.6500/-21.4812
#
# Reset
# Steps: 71/200. Action: 3. Reward/Value: -1.0/0.1198. Done: -10
#  Mean Policy loss: 69.8810. Mean Value loss: 11.1028
# Episode: 9/200, score/average: -30.7500/-22.5111
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -0.25/0.0588. Done: 0
#  Mean Policy loss: 39.4324. Mean Value loss: 7.9288
# Episode: 10/200, score/average: -29.0000/-23.1600 SAVING
#
# Reset
# Steps: 181/200. Action: 5. Reward/Value: -0.3/0.0476. Done: -10
#  Mean Policy loss: 79.1157. Mean Value loss: 3.5454
# Episode: 11/200, score/average: -16.0000/-16.6950 SAVING
#
# Reset
# Steps: 33/200. Action: 2. Reward/Value: -1.0/0.0953. Done: -1
#  Mean Policy loss: 36.6219. Mean Value loss: 5.4612
# Episode: 12/200, score/average: -17.6500/-16.9000
#
# Reset
# Steps: 89/200. Action: 5. Reward/Value: -0.3/-0.0382. Done: -1
#  Mean Policy loss: 46.7206. Mean Value loss: 4.4860
# Episode: 13/200, score/average: -19.0500/-18.4150
#
# Reset
# Steps: 184/200. Action: 4. Reward/Value: -1.0/-0.0053. Done: -1
#  Mean Policy loss: 101.4734. Mean Value loss: 4.5840
# Episode: 14/200, score/average: -14.2000/-18.8250
#
# Reset
# Steps: 97/200. Action: 1. Reward/Value: -0.55/-0.0558. Done: -1
#  Mean Policy loss: 86.2745. Mean Value loss: 12.0301
# Episode: 15/200, score/average: -37.7000/-22.6700
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.0/-0.0844. Done: 00
#  Mean Policy loss: 129.7731. Mean Value loss: 13.8194
# Episode: 16/200, score/average: -48.6000/-25.3050
#
# Reset
# Steps: 81/200. Action: 5. Reward/Value: -1.0/0.0938. Done: -1
#  Mean Policy loss: 61.0999. Mean Value loss: 9.9213
# Episode: 17/200, score/average: -31.6500/-27.5250
#
# Reset
# Steps: 41/200. Action: 2. Reward/Value: -1.0/0.0161. Done: -1
#  Mean Policy loss: 3.6790. Mean Value loss: 0.9478
# Episode: 18/200, score/average: -1.2500/-24.5850
#
# Reset
# Steps: 46/200. Action: 4. Reward/Value: -0.55/0.0891. Done: -1
#  Mean Policy loss: 41.8432. Mean Value loss: 5.9407
# Episode: 19/200, score/average: -22.1000/-23.7200
#
# Reset
# Steps: 23/200. Action: 5. Reward/Value: -1.0/0.1424. Done: -1
#  Mean Policy loss: 8.4691. Mean Value loss: 2.5057
# Episode: 20/200, score/average: -5.8500/-21.4050 SAVING
#
# Reset
# Steps: 80/200. Action: 5. Reward/Value: -1.0/0.0635. Done: -1
#  Mean Policy loss: 115.1579. Mean Value loss: 12.6611
# Episode: 21/200, score/average: -32.4500/-23.0500
#
# Reset
# Steps: 62/200. Action: 3. Reward/Value: -1.0/0.0615. Done: -1
#  Mean Policy loss: 55.5030. Mean Value loss: 9.9352
# Episode: 22/200, score/average: -21.7000/-23.4550
#
# Reset
# Steps: 47/200. Action: 4. Reward/Value: -1.0/0.0071. Done: -1
#  Mean Policy loss: 16.3726. Mean Value loss: 1.8943
# Episode: 23/200, score/average: -0.9000/-21.6400
#
# Reset
# Steps: 148/200. Action: 5. Reward/Value: -1.0/-0.0101. Done: -1
#  Mean Policy loss: 27.0306. Mean Value loss: 2.4863
# Episode: 24/200, score/average: -5.1500/-20.7350
#
# Reset
# Steps: 79/200. Action: 0. Reward/Value: -0.55/-0.0085. Done: -1
#  Mean Policy loss: 21.9012. Mean Value loss: 2.1915
# Episode: 25/200, score/average: -4.2500/-17.3900
#
# Reset
# Steps: 102/200. Action: 4. Reward/Value: -1.0/-0.0965. Done: -1
#  Mean Policy loss: 108.4049. Mean Value loss: 15.5189
# Episode: 26/200, score/average: -32.7500/-15.8050 SAVING
#
# Reset
# Steps: 46/200. Action: 2. Reward/Value: -1.0/0.0204. Done: -1
#  Mean Policy loss: 27.7414. Mean Value loss: 5.0140
# Episode: 27/200, score/average: -17.6500/-14.4050 SAVING
#
# Reset
# Steps: 125/200. Action: 2. Reward/Value: -1.0/0.0996. Done: -1
#  Mean Policy loss: 41.0893. Mean Value loss: 6.8437
# Episode: 28/200, score/average: -22.2000/-16.5000
#
# Reset
# Steps: 138/200. Action: 4. Reward/Value: -0.55/-0.0492. Done: -1
#  Mean Policy loss: 69.1674. Mean Value loss: 4.5949
# Episode: 29/200, score/average: -19.4500/-16.2350
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: 0.0/0.1135. Done: 0 0
#  Mean Policy loss: 139.0475. Mean Value loss: 17.6217
# Episode: 30/200, score/average: -60.4000/-21.6900 SAVING
#
# Reset
# Steps: 74/200. Action: 5. Reward/Value: 0.15/0.0269. Done: -10
#  Mean Policy loss: 9.8011. Mean Value loss: 2.2775
# Episode: 31/200, score/average: -4.1000/-18.8550
#
# Reset
# Steps: 91/200. Action: 1. Reward/Value: -0.3/0.0068. Done: -1
#  Mean Policy loss: 46.1890. Mean Value loss: 5.6925
# Episode: 32/200, score/average: -14.4000/-18.1250
#
# Reset
# Steps: 51/200. Action: 1. Reward/Value: -0.3/0.0914. Done: -1
#  Mean Policy loss: 16.3076. Mean Value loss: 4.1167
# Episode: 33/200, score/average: -8.0500/-18.8400
#
# Reset
# Steps: 83/200. Action: 1. Reward/Value: 0.7/0.0531. Done: 100
#  Mean Policy loss: 135.0508. Mean Value loss: -1.5533
# Episode: 34/200, score/average: -7.1000/-19.0350
#
# Reset
# Steps: 53/200. Action: 3. Reward/Value: 0.4/0.0451. Done: -10
#  Mean Policy loss: 17.4735. Mean Value loss: 3.6924
# Episode: 35/200, score/average: -5.7000/-19.1800
#
# Reset
# Steps: 51/200. Action: 5. Reward/Value: -1.0/0.024. Done: -10
#  Mean Policy loss: 28.5656. Mean Value loss: 6.2854
# Episode: 36/200, score/average: -9.4000/-16.8450
#
# Reset
# Steps: 21/200. Action: 2. Reward/Value: -0.7/0.1146. Done: 1
#  Mean Policy loss: 2.6305. Mean Value loss: -1.0941
# Episode: 37/200, score/average: 2.9000/-14.7900
#
# Reset
# Steps: 37/200. Action: 4. Reward/Value: 0.15/0.0243. Done: -1
#  Mean Policy loss: 14.0013. Mean Value loss: 2.5126
# Episode: 38/200, score/average: -4.4500/-13.0150 SAVING
#
# Reset
# Steps: 43/200. Action: 2. Reward/Value: -0.3/0.1115. Done: -1
#  Mean Policy loss: 6.3672. Mean Value loss: 1.8304
# Episode: 39/200, score/average: -4.0500/-11.4750 SAVING
#
# Reset
# Steps: 52/200. Action: 2. Reward/Value: -0.3/0.0922. Done: -1
#  Mean Policy loss: 3.2570. Mean Value loss: 1.5463
# Episode: 40/200, score/average: -3.9500/-5.8300 SAVING
#
# Reset
# Steps: 57/200. Action: 3. Reward/Value: 0.4/0.0252. Done: -10
#  Mean Policy loss: 69.1463. Mean Value loss: 8.4862
# Episode: 41/200, score/average: -19.5000/-7.3700
#
# Reset
# Steps: 56/200. Action: 2. Reward/Value: 0.7/0.0168. Done: 100
#  Mean Policy loss: 24.2164. Mean Value loss: -3.3380
# Episode: 42/200, score/average: 10.0500/-4.9250 SAVING
#
# Reset
# Steps: 52/200. Action: 0. Reward/Value: -1.0/0.1269. Done: -1
#  Mean Policy loss: 48.5905. Mean Value loss: 9.1709
# Episode: 43/200, score/average: -18.7000/-5.9900
#
# Reset
# Steps: 44/200. Action: 5. Reward/Value: -1.0/0.0091. Done: -1
#  Mean Policy loss: 10.4785. Mean Value loss: 2.8945
# Episode: 44/200, score/average: -10.0000/-6.2800
#
# Reset
# Steps: 43/200. Action: 1. Reward/Value: -0.3/-0.0275. Done: -1
#  Mean Policy loss: 9.9186. Mean Value loss: 2.2672
# Episode: 45/200, score/average: -6.1500/-6.3250
#
# Reset
# Steps: 70/200. Action: 1. Reward/Value: -0.3/-0.0069. Done: -1
#  Mean Policy loss: 24.5919. Mean Value loss: 0.3293
# Episode: 46/200, score/average: -3.1000/-5.6950
#
# Reset
# Steps: 161/200. Action: 4. Reward/Value: -1.0/-0.0029. Done: -1
#  Mean Policy loss: 159.1589. Mean Value loss: 15.9136
# Episode: 47/200, score/average: -40.3500/-10.0200
#
# Reset
# Steps: 52/200. Action: 4. Reward/Value: -0.3/-0.0496. Done: -1
#  Mean Policy loss: 8.4992. Mean Value loss: 2.9722
# Episode: 48/200, score/average: -4.0000/-9.9750
#
# Reset
# Steps: 24/200. Action: 4. Reward/Value: -0.3/-0.0156. Done: 1
#  Mean Policy loss: 2.9428. Mean Value loss: -1.3765
# Episode: 49/200, score/average: 4.3000/-9.1400
#
# Reset
# Steps: 67/200. Action: 3. Reward/Value: -0.3/-0.0205. Done: -1
#  Mean Policy loss: 19.5560. Mean Value loss: 0.4788
# Episode: 50/200, score/average: -4.2500/-9.1700 SAVING
#
# Reset
# Steps: 57/200. Action: 1. Reward/Value: -0.3/0.1277. Done: -1
#  Mean Policy loss: 20.3697. Mean Value loss: 4.3261
# Episode: 51/200, score/average: -6.5500/-7.8750
#
# Reset
# Steps: 50/200. Action: 5. Reward/Value: -1.0/0.0691. Done: -1
#  Mean Policy loss: 13.6304. Mean Value loss: 1.5004
# Episode: 52/200, score/average: -1.9000/-9.0700
#
# Reset
# Steps: 60/200. Action: 1. Reward/Value: -0.3/-0.0024. Done: -1
#  Mean Policy loss: 15.2467. Mean Value loss: 1.6608
# Episode: 53/200, score/average: -4.0500/-7.6050
#
# Reset
# Steps: 38/200. Action: 2. Reward/Value: -1.0/0.0782. Done: -1
#  Mean Policy loss: 17.8380. Mean Value loss: 3.9319
# Episode: 54/200, score/average: -11.8500/-7.7900
#
# Reset
# Steps: 41/200. Action: 5. Reward/Value: 0.0/0.0011. Done: 100
#  Mean Policy loss: 7.5416. Mean Value loss: -2.1730
# Episode: 55/200, score/average: 5.6500/-6.6100
#
# Reset
# Steps: 35/200. Action: 1. Reward/Value: -1.0/0.0664. Done: -1
#  Mean Policy loss: 14.8156. Mean Value loss: 2.2312
# Episode: 56/200, score/average: -1.7500/-6.4750
#
# Reset
# Steps: 43/200. Action: 4. Reward/Value: -1.0/0.1318. Done: -1
#  Mean Policy loss: 7.4279. Mean Value loss: -0.7191
# Episode: 57/200, score/average: 1.7000/-2.2700 SAVING
#
# Reset
# Steps: 32/200. Action: 1. Reward/Value: -0.55/0.0348. Done: -1
#  Mean Policy loss: 5.4539. Mean Value loss: 2.1767
# Episode: 58/200, score/average: -5.9500/-2.4650
#
# Reset
# Steps: 28/200. Action: 1. Reward/Value: -1.0/0.0423. Done: -1
#  Mean Policy loss: 11.7011. Mean Value loss: 3.2198
# Episode: 59/200, score/average: -8.1500/-3.7100
#
# Reset
# Steps: 52/200. Action: 5. Reward/Value: -0.3/0.0121. Done: -1
#  Mean Policy loss: 96.2733. Mean Value loss: 12.5393
# Episode: 60/200, score/average: -23.6000/-5.6450 SAVING
#
# Reset
# Steps: 53/200. Action: 5. Reward/Value: -1.0/0.0732. Done: -1
#  Mean Policy loss: 20.8629. Mean Value loss: 2.0243
# Episode: 61/200, score/average: -4.4000/-5.4300
#
# Reset
# Steps: 28/200. Action: 2. Reward/Value: -1.0/0.055. Done: -1
#  Mean Policy loss: 2.9677. Mean Value loss: 1.0163
# Episode: 62/200, score/average: 0.0000/-5.2400
#
# Reset
# Steps: 43/200. Action: 2. Reward/Value: 0.15/0.0335. Done: -1
#  Mean Policy loss: 2.3773. Mean Value loss: -0.2498
# Episode: 63/200, score/average: 3.1500/-4.5200
#
# Reset
# Steps: 55/200. Action: 4. Reward/Value: -1.0/-0.0218. Done: -1
#  Mean Policy loss: 31.3825. Mean Value loss: 7.3421
# Episode: 64/200, score/average: -12.9000/-4.6250
#
# Reset
# Steps: 61/200. Action: 5. Reward/Value: -0.3/-0.0411. Done: -1
#  Mean Policy loss: 7.5565. Mean Value loss: -2.0512
# Episode: 65/200, score/average: 5.1500/-4.6750
#
# Reset
# Steps: 41/200. Action: 2. Reward/Value: -0.55/-0.0155. Done: -1
#  Mean Policy loss: 7.3818. Mean Value loss: 2.0323
# Episode: 66/200, score/average: -4.0500/-4.9050
#
# Reset
# Steps: 52/200. Action: 2. Reward/Value: 0.45/0.0176. Done: 10
#  Mean Policy loss: 22.9057. Mean Value loss: -5.9157
# Episode: 67/200, score/average: 10.7500/-4.0000
#
# Reset
# Steps: 70/200. Action: 3. Reward/Value: 0.0/-0.0059. Done: 100
#  Mean Policy loss: 8.6350. Mean Value loss: -1.3891
# Episode: 68/200, score/average: 4.8000/-2.9250
#
# Reset
# Steps: 57/200. Action: 0. Reward/Value: 0.0/-0.0109. Done: 10
#  Mean Policy loss: 6.6727. Mean Value loss: -0.8484
# Episode: 69/200, score/average: 1.3000/-1.9800 SAVING
#
# Reset
# Steps: 36/200. Action: 0. Reward/Value: -1.0/0.0407. Done: -1
#  Mean Policy loss: 12.9712. Mean Value loss: 1.5502
# Episode: 70/200, score/average: 0.9000/0.4700 SAVING
#
# Reset
# Steps: 59/200. Action: 5. Reward/Value: 0.15/0.0292. Done: -1
#  Mean Policy loss: 5.1975. Mean Value loss: -1.4200
# Episode: 71/200, score/average: -0.8500/0.8250 SAVING
#
# Reset
# Steps: 87/200. Action: 0. Reward/Value: -0.7/0.1166. Done: 10
#  Mean Policy loss: 25.6104. Mean Value loss: -4.3375
# Episode: 72/200, score/average: 13.9000/2.2150 SAVING
#
# Reset
# Steps: 27/200. Action: 2. Reward/Value: -0.7/0.0702. Done: 1
#  Mean Policy loss: 3.5239. Mean Value loss: -0.8975
# Episode: 73/200, score/average: 4.0000/2.3000 SAVING
#
# Reset
# Steps: 69/200. Action: 0. Reward/Value: -0.3/0.1694. Done: -1
#  Mean Policy loss: 60.6066. Mean Value loss: 7.2613
# Episode: 74/200, score/average: -19.6000/1.6300
#
# Reset
# Steps: 68/200. Action: 2. Reward/Value: 0.15/0.0109. Done: -1
#  Mean Policy loss: 18.9053. Mean Value loss: 2.5758
# Episode: 75/200, score/average: -3.5000/0.7650
#
# Reset
# Steps: 21/200. Action: 2. Reward/Value: -0.7/0.1053. Done: 1
#  Mean Policy loss: 3.5715. Mean Value loss: -1.3002
# Episode: 76/200, score/average: 4.2000/1.5900
#
# Reset
# Steps: 47/200. Action: 3. Reward/Value: -0.3/-0.1108. Done: -1
#  Mean Policy loss: 1.8847. Mean Value loss: 0.5958
# Episode: 77/200, score/average: -0.9000/0.4250
#
# Reset
# Steps: 75/200. Action: 3. Reward/Value: -0.3/0.0459. Done: -10
#  Mean Policy loss: 43.6318. Mean Value loss: 1.3774
# Episode: 78/200, score/average: -8.5000/-0.9050
#
# Reset
# Steps: 86/200. Action: 4. Reward/Value: 0.15/0.0135. Done: -1
#  Mean Policy loss: 9.6092. Mean Value loss: -0.9118
# Episode: 79/200, score/average: 4.0000/-0.6350
#
# Reset
# Steps: 46/200. Action: 4. Reward/Value: 0.15/0.0382. Done: -1
#  Mean Policy loss: 7.0928. Mean Value loss: -0.7359
# Episode: 80/200, score/average: 6.6000/-0.0650 SAVING
#
# Reset
# Steps: 33/200. Action: 0. Reward/Value: -0.7/0.114. Done: 100
#  Mean Policy loss: 15.9431. Mean Value loss: -2.4299
# Episode: 81/200, score/average: 9.3000/0.9500
#
# Reset
# Steps: 49/200. Action: 1. Reward/Value: 0.4/0.0348. Done: -10
#  Mean Policy loss: 19.0720. Mean Value loss: -0.4657
# Episode: 82/200, score/average: -2.5500/-0.6950
#
# Reset
# Steps: 28/200. Action: 1. Reward/Value: 0.4/0.0633. Done: -1
#  Mean Policy loss: 18.3940. Mean Value loss: 2.6138
# Episode: 83/200, score/average: -10.4500/-2.1400
#
# Reset
# Steps: 96/200. Action: 1. Reward/Value: -0.25/0.0388. Done: 1
#  Mean Policy loss: 8.2544. Mean Value loss: -1.6362
# Episode: 84/200, score/average: 3.9500/0.2150
#
# Reset
# Steps: 75/200. Action: 3. Reward/Value: 0.4/0.0384. Done: -100
#  Mean Policy loss: 11.2927. Mean Value loss: 0.8952
# Episode: 85/200, score/average: -3.9500/0.1700
#
# Reset
# Steps: 58/200. Action: 5. Reward/Value: -1.0/0.0355. Done: -1
#  Mean Policy loss: 25.3553. Mean Value loss: 5.4067
# Episode: 86/200, score/average: -9.0500/-1.1550
#
# Reset
# Steps: 41/200. Action: 1. Reward/Value: -0.0/0.0641. Done: 10
#  Mean Policy loss: 9.0909. Mean Value loss: -2.1385
# Episode: 87/200, score/average: 7.5500/-0.3100
#
# Reset
# Steps: 83/200. Action: 3. Reward/Value: -0.3/0.0128. Done: -1
#  Mean Policy loss: 53.5008. Mean Value loss: 6.6725
# Episode: 88/200, score/average: -16.5000/-1.1100
#
# Reset
# Steps: 40/200. Action: 1. Reward/Value: 0.15/-0.0041. Done: -1
#  Mean Policy loss: 12.2989. Mean Value loss: 2.3095
# Episode: 89/200, score/average: -4.5000/-1.9600
#
# Reset
# Steps: 56/200. Action: 3. Reward/Value: -0.3/0.0323. Done: -1
#  Mean Policy loss: 11.7645. Mean Value loss: 2.3157
# Episode: 90/200, score/average: -6.2500/-3.2450 SAVING
#
# Reset
# Steps: 79/200. Action: 2. Reward/Value: 0.15/0.01. Done: 1 00
#  Mean Policy loss: 21.7316. Mean Value loss: 0.3009
# Episode: 91/200, score/average: 1.3000/-4.0450
#
# Reset
# Steps: 13/200. Action: 5. Reward/Value: 0.0/0.0261. Done: 10
#  Mean Policy loss: 6.4449. Mean Value loss: -2.2765
# Episode: 92/200, score/average: 5.0500/-3.2850
#
# Reset
# Steps: 74/200. Action: 2. Reward/Value: 0.7/0.0553. Done: 100
#  Mean Policy loss: 24.0341. Mean Value loss: -0.3100
# Episode: 93/200, score/average: 2.2500/-2.0150
#
# Reset
# Steps: 60/200. Action: 4. Reward/Value: -0.3/0.0215. Done: -1
#  Mean Policy loss: 45.3538. Mean Value loss: 6.2109
# Episode: 94/200, score/average: -18.8000/-4.2900
#
# Reset
# Steps: 50/200. Action: 2. Reward/Value: -0.3/-0.0733. Done: -1
#  Mean Policy loss: 5.8049. Mean Value loss: 1.2563
# Episode: 95/200, score/average: -3.4000/-4.2350
#
# Reset
# Steps: 61/200. Action: 2. Reward/Value: -0.3/-0.0413. Done: -1
#  Mean Policy loss: 32.0290. Mean Value loss: 6.5757
# Episode: 96/200, score/average: -10.7500/-4.4050
#
# Reset
# Steps: 59/200. Action: 2. Reward/Value: -0.3/-0.0015. Done: -1
#  Mean Policy loss: 83.2335. Mean Value loss: 7.4042
# Episode: 97/200, score/average: -18.9000/-7.0500
#
# Reset
# Steps: 73/200. Action: 2. Reward/Value: 0.15/0.0031. Done: -1
#  Mean Policy loss: 4.4436. Mean Value loss: 0.0367
# Episode: 98/200, score/average: 2.3000/-5.1700
#
# Reset
# Steps: 130/200. Action: 2. Reward/Value: 0.4/0.099. Done: -100
#  Mean Policy loss: 71.6870. Mean Value loss: 7.7410
# Episode: 99/200, score/average: -20.0500/-6.7250
#
# Reset
# Steps: 27/200. Action: 3. Reward/Value: -1.0/0.0299. Done: -1
#  Mean Policy loss: 2.6011. Mean Value loss: 1.1310
# Episode: 100/200, score/average: -4.4000/-6.5400 SAVING
#
# Reset
# Steps: 29/200. Action: 2. Reward/Value: 0.15/0.0103. Done: -1
#  Mean Policy loss: 5.3893. Mean Value loss: -1.3505
# Episode: 101/200, score/average: 3.5500/-6.3150
#
# Reset
# Steps: 48/200. Action: 1. Reward/Value: -0.3/0.036. Done: -10
#  Mean Policy loss: 18.3083. Mean Value loss: 3.0163
# Episode: 102/200, score/average: -6.2500/-7.4450
#
# Reset
# Steps: 33/200. Action: 3. Reward/Value: 0.4/0.0636. Done: -10
#  Mean Policy loss: 3.1837. Mean Value loss: 0.5702
# Episode: 103/200, score/average: -3.4500/-8.0150
#
# Reset
# Steps: 55/200. Action: 5. Reward/Value: -1.0/0.007. Done: -10
#  Mean Policy loss: 52.1108. Mean Value loss: 7.9852
# Episode: 104/200, score/average: -13.9000/-7.5250
#
# Reset
# Steps: 53/200. Action: 2. Reward/Value: -0.1/-0.05. Done: -1 0
#  Mean Policy loss: 3.7538. Mean Value loss: 0.6780
# Episode: 105/200, score/average: -2.0500/-7.3900
#
# Reset
# Steps: 63/200. Action: 0. Reward/Value: -0.3/-0.0067. Done: -1
#  Mean Policy loss: 34.6717. Mean Value loss: 4.6429
# Episode: 106/200, score/average: -7.8500/-7.1000
#
# Reset
# Steps: 76/200. Action: 3. Reward/Value: 0.7/0.0214. Done: 1000
#  Mean Policy loss: 21.9464. Mean Value loss: 0.1946
# Episode: 107/200, score/average: -2.2500/-5.4350
#
# Reset
# Steps: 51/200. Action: 3. Reward/Value: -0.3/-0.0474. Done: -1
#  Mean Policy loss: 8.2061. Mean Value loss: 1.4182
# Episode: 108/200, score/average: 1.2500/-5.5400
#
# Reset
# Steps: 58/200. Action: 4. Reward/Value: -0.3/-0.049. Done: -1
#  Mean Policy loss: 11.2113. Mean Value loss: -1.2801
# Episode: 109/200, score/average: 5.4000/-2.9950
#
# Reset
# Steps: 52/200. Action: 1. Reward/Value: -0.25/0.0277. Done: 1
#  Mean Policy loss: 22.1608. Mean Value loss: -5.2026
# Episode: 110/200, score/average: 10.9000/-1.4650 SAVING
#
# Reset
# Steps: 47/200. Action: 3. Reward/Value: -0.3/-0.0041. Done: -1
#  Mean Policy loss: 7.2267. Mean Value loss: -0.9574
# Episode: 111/200, score/average: 8.1000/-1.0100
#
# Reset
# Steps: 46/200. Action: 1. Reward/Value: -0.7/-0.0054. Done: 1
#  Mean Policy loss: 2.4136. Mean Value loss: 0.0145
# Episode: 112/200, score/average: 2.2500/-0.1600
#
# Reset
# Steps: 48/200. Action: 1. Reward/Value: -0.55/-0.0165. Done: -1
#  Mean Policy loss: 52.5161. Mean Value loss: 6.7199
# Episode: 113/200, score/average: -22.5500/-2.0700
#
# Reset
# Steps: 25/200. Action: 5. Reward/Value: -0.7/0.0405. Done: 10
#  Mean Policy loss: 10.8990. Mean Value loss: -1.8768
# Episode: 114/200, score/average: 7.9500/0.1150
#
# Reset
# Steps: 42/200. Action: 3. Reward/Value: 0.7/0.04. Done: 1: 00
#  Mean Policy loss: 6.8047. Mean Value loss: -0.1215
# Episode: 115/200, score/average: 5.0500/0.8250
#
# Reset
# Steps: 49/200. Action: 1. Reward/Value: -0.55/0.0253. Done: -1
#  Mean Policy loss: 8.0719. Mean Value loss: -0.6503
# Episode: 116/200, score/average: -1.4500/1.4650
#
# Reset
# Steps: 40/200. Action: 3. Reward/Value: -0.0/0.0808. Done: 10
#  Mean Policy loss: 8.4706. Mean Value loss: -1.7994
# Episode: 117/200, score/average: 5.3000/2.2200
#
# Reset
# Steps: 47/200. Action: 1. Reward/Value: -1.0/0.0715. Done: -1
#  Mean Policy loss: 22.1452. Mean Value loss: 4.1810
# Episode: 118/200, score/average: -12.6500/0.8300
#
# Reset
# Steps: 40/200. Action: 4. Reward/Value: -0.3/-0.014. Done: -1
#  Mean Policy loss: 32.3526. Mean Value loss: 4.9415
# Episode: 119/200, score/average: -15.0500/-1.2150
#
# Reset
# Steps: 43/200. Action: 2. Reward/Value: -0.3/-0.076. Done: -1
#  Mean Policy loss: 5.7499. Mean Value loss: 1.3576
# Episode: 120/200, score/average: -1.0500/-2.4100 SAVING
#
# Reset
# Steps: 41/200. Action: 5. Reward/Value: -0.3/0.0431. Done: -1
#  Mean Policy loss: 4.4752. Mean Value loss: -0.1053
# Episode: 121/200, score/average: 1.5000/-3.0700
#
# Reset
# Steps: 43/200. Action: 3. Reward/Value: -1.0/-0.0163. Done: -1
#  Mean Policy loss: 22.2186. Mean Value loss: 4.2126
# Episode: 122/200, score/average: -13.4500/-4.6400
#
# Reset
# Steps: 62/200. Action: 3. Reward/Value: -0.55/0.0257. Done: -1
#  Mean Policy loss: 2.3922. Mean Value loss: 0.2020
# Episode: 123/200, score/average: -0.6000/-2.4450
#
# Reset
# Steps: 24/200. Action: 0. Reward/Value: -0.25/0.0391. Done: 1
#  Mean Policy loss: 11.7622. Mean Value loss: -2.1755
# Episode: 124/200, score/average: 8.3500/-2.4050
#
# Reset
# Steps: 49/200. Action: 5. Reward/Value: -0.3/-0.006. Done: -10
#  Mean Policy loss: 8.0590. Mean Value loss: 2.1110
# Episode: 125/200, score/average: -4.5000/-3.3600
#
# Reset
# Steps: 36/200. Action: 3. Reward/Value: -0.1/0.0271. Done: -1
#  Mean Policy loss: 1.7104. Mean Value loss: 0.4398
# Episode: 126/200, score/average: -0.7500/-3.2900
#
# Reset
# Steps: 32/200. Action: 3. Reward/Value: 0.45/0.0365. Done: 10
#  Mean Policy loss: 5.7961. Mean Value loss: -1.2192
# Episode: 127/200, score/average: 7.1000/-3.1100
#
# Reset
# Steps: 39/200. Action: 1. Reward/Value: -0.3/0.0634. Done: -1
#  Mean Policy loss: 15.4119. Mean Value loss: 3.2916
# Episode: 128/200, score/average: -8.9000/-2.7350
#
# Reset
# Steps: 21/200. Action: 4. Reward/Value: -0.0/0.0725. Done: 10
#  Mean Policy loss: 4.3903. Mean Value loss: -1.6403
# Episode: 129/200, score/average: 5.7000/-0.6600
#
# Reset
# Steps: 34/200. Action: 2. Reward/Value: -0.3/0.0017. Done: -1
#  Mean Policy loss: 6.5784. Mean Value loss: 1.3240
# Episode: 130/200, score/average: -6.0000/-1.1550 SAVING
#
# Reset
# Steps: 52/200. Action: 4. Reward/Value: 0.0/-0.0274. Done: 10
#  Mean Policy loss: 8.1437. Mean Value loss: -1.9882
# Episode: 131/200, score/average: 5.2000/-0.7850
#
# Reset
# Steps: 19/200. Action: 1. Reward/Value: 0.0/0.015. Done: 100
#  Mean Policy loss: 22.6254. Mean Value loss: -4.2821
# Episode: 132/200, score/average: 10.7500/1.6350
#
# Reset
# Steps: 49/200. Action: 3. Reward/Value: 0.4/0.0484. Done: -10
#  Mean Policy loss: 5.5635. Mean Value loss: -0.4136
# Episode: 133/200, score/average: 1.5000/1.8450
#
# Reset
# Steps: 52/200. Action: 2. Reward/Value: -0.7/0.0486. Done: 10
#  Mean Policy loss: 4.9344. Mean Value loss: -0.7718
# Episode: 134/200, score/average: 5.1500/1.5250
#
# Reset
# Steps: 33/200. Action: 3. Reward/Value: 0.45/0.0511. Done: 10
#  Mean Policy loss: 2.1700. Mean Value loss: -1.2546
# Episode: 135/200, score/average: 4.8000/2.4550 SAVING
#
# Reset
# Steps: 42/200. Action: 1. Reward/Value: -0.55/-0.0145. Done: -1
#  Mean Policy loss: 3.8897. Mean Value loss: 0.0473
# Episode: 136/200, score/average: 2.5000/2.7800 SAVING
#
# Reset
# Steps: 93/200. Action: 1. Reward/Value: -0.3/-0.0931. Done: -1
#  Mean Policy loss: 6.3957. Mean Value loss: 1.5727
# Episode: 137/200, score/average: -4.8000/1.5900
#
# Reset
# Steps: 30/200. Action: 1. Reward/Value: -0.55/-0.0021. Done: -1
#  Mean Policy loss: 1.8348. Mean Value loss: -0.0595
# Episode: 138/200, score/average: -0.7500/2.4050
#
# Reset
# Steps: 22/200. Action: 2. Reward/Value: -0.55/0.0777. Done: -1
#  Mean Policy loss: 2.6137. Mean Value loss: 0.7427
# Episode: 139/200, score/average: 0.7500/1.9100
#
# Reset
# Steps: 43/200. Action: 3. Reward/Value: 0.7/0.0385. Done: 100
#  Mean Policy loss: 9.5773. Mean Value loss: -2.3522
# Episode: 140/200, score/average: 7.7000/3.2800 SAVING
#
# Reset
# Steps: 38/200. Action: 5. Reward/Value: -0.7/0.093. Done: 10
#  Mean Policy loss: 14.4153. Mean Value loss: -2.4057
# Episode: 141/200, score/average: 11.5500/3.9150 SAVING
#
# Reset
# Steps: 22/200. Action: 2. Reward/Value: 0.0/0.0161. Done: 100
#  Mean Policy loss: 3.6580. Mean Value loss: -1.7410
# Episode: 142/200, score/average: 4.5500/3.2950
#
# Reset
# Steps: 37/200. Action: 1. Reward/Value: -0.3/-0.0821. Done: -1
#  Mean Policy loss: 4.5174. Mean Value loss: -1.4210
# Episode: 143/200, score/average: 7.4000/3.8850
#
# Reset
# Steps: 55/200. Action: 1. Reward/Value: -0.3/-0.0561. Done: -1
#  Mean Policy loss: 11.1933. Mean Value loss: 3.0492
# Episode: 144/200, score/average: -6.4500/2.7250
#
# Reset
# Steps: 33/200. Action: 3. Reward/Value: -0.55/0.1223. Done: -1
#  Mean Policy loss: 3.3377. Mean Value loss: 0.2319
# Episode: 145/200, score/average: 1.6500/2.4100
#
# Reset
# Steps: 56/200. Action: 2. Reward/Value: -0.3/0.1135. Done: -1
#  Mean Policy loss: 26.0055. Mean Value loss: 4.5148
# Episode: 146/200, score/average: -11.1000/1.0500
#
# Reset
# Steps: 33/200. Action: 3. Reward/Value: 0.45/0.0314. Done: 10
#  Mean Policy loss: 4.4758. Mean Value loss: -1.8139
# Episode: 147/200, score/average: 5.9500/2.1250
#
# Reset
# Steps: 62/200. Action: 3. Reward/Value: 0.15/0.0609. Done: -1
#  Mean Policy loss: 51.3267. Mean Value loss: 7.3801
# Episode: 148/200, score/average: -12.5500/0.9450
#
# Reset
# Steps: 59/200. Action: 3. Reward/Value: -0.55/0.0175. Done: -1
#  Mean Policy loss: 8.7749. Mean Value loss: 2.3638
# Episode: 149/200, score/average: -7.8000/0.0900
#
# Reset
# Steps: 50/200. Action: 1. Reward/Value: -0.55/0.0066. Done: -1
#  Mean Policy loss: 3.3314. Mean Value loss: 0.7959
# Episode: 150/200, score/average: -0.9000/-0.7700 SAVING
#
# Reset
# Steps: 22/200. Action: 3. Reward/Value: -0.25/0.0339. Done: 1
#  Mean Policy loss: 12.4221. Mean Value loss: -2.7637
# Episode: 151/200, score/average: 8.8500/-1.0400
#
# Reset
# Steps: 42/200. Action: 2. Reward/Value: -0.1/-0.0036. Done: -1
#  Mean Policy loss: 4.9442. Mean Value loss: 0.7634
# Episode: 152/200, score/average: 0.5500/-1.4400
#
# Reset
# Steps: 39/200. Action: 4. Reward/Value: -0.25/0.0221. Done: 1
#  Mean Policy loss: 2.1677. Mean Value loss: -0.4289
# Episode: 153/200, score/average: 3.7500/-1.8050
#
# Reset
# Steps: 39/200. Action: 5. Reward/Value: -0.25/0.0416. Done: 1
#  Mean Policy loss: 6.7771. Mean Value loss: -1.7168
# Episode: 154/200, score/average: 8.3000/-0.3300
#
# Reset
# Steps: 33/200. Action: 1. Reward/Value: -0.3/-0.0465. Done: -1
#  Mean Policy loss: 2.4269. Mean Value loss: 1.3160
# Episode: 155/200, score/average: -3.8000/-0.8750
#
# Reset
# Steps: 23/200. Action: 1. Reward/Value: -0.3/-0.0694. Done: -1
#  Mean Policy loss: 0.4773. Mean Value loss: 0.5327
# Episode: 156/200, score/average: -0.6500/0.1700
#
# Reset
# Steps: 59/200. Action: 2. Reward/Value: -0.3/-0.0206. Done: -1
#  Mean Policy loss: 33.7703. Mean Value loss: 5.6884
# Episode: 157/200, score/average: -7.6000/-1.1850
#
# Reset
# Steps: 38/200. Action: 1. Reward/Value: -1.0/0.0746. Done: -1
#  Mean Policy loss: 1.8461. Mean Value loss: 0.4449
# Episode: 158/200, score/average: -1.6500/-0.0950
#
# Reset
# Steps: 42/200. Action: 1. Reward/Value: 0.0/0.0403. Done: 100
#  Mean Policy loss: 1.6111. Mean Value loss: -0.6637
# Episode: 159/200, score/average: 2.9500/0.9800
#
# Reset
# Steps: 28/200. Action: 1. Reward/Value: -0.55/0.0604. Done: -1
#  Mean Policy loss: 1.9981. Mean Value loss: 1.1521
# Episode: 160/200, score/average: -1.6000/0.9100 SAVING
#
# Reset
# Steps: 42/200. Action: 3. Reward/Value: 0.7/0.0203. Done: 100
#  Mean Policy loss: 5.4650. Mean Value loss: -1.7111
# Episode: 161/200, score/average: 4.3500/0.4600
#
# Reset
# Steps: 45/200. Action: 3. Reward/Value: -0.3/0.0879. Done: -1
#  Mean Policy loss: 19.2905. Mean Value loss: 3.4859
# Episode: 162/200, score/average: -13.1500/-0.9100
#
# Reset
# Steps: 42/200. Action: 4. Reward/Value: -1.0/0.0744. Done: -1
#  Mean Policy loss: 11.7797. Mean Value loss: 2.2750
# Episode: 163/200, score/average: -6.1000/-1.8950
#
# Reset
# Steps: 56/200. Action: 3. Reward/Value: 0.4/0.0689. Done: -10
#  Mean Policy loss: 6.6275. Mean Value loss: 0.5743
# Episode: 164/200, score/average: -2.1500/-2.9400
#
# Reset
# Steps: 14/200. Action: 2. Reward/Value: -0.7/0.046. Done: 1 0
#  Mean Policy loss: 1.0142. Mean Value loss: 0.7634
# Episode: 165/200, score/average: -0.5500/-2.6150
#
# Reset
# Steps: 44/200. Action: 1. Reward/Value: 0.4/0.0496. Done: -10
#  Mean Policy loss: 0.1873. Mean Value loss: -0.1847
# Episode: 166/200, score/average: 0.9500/-2.4550
#
# Reset
# Steps: 37/200. Action: 4. Reward/Value: -0.3/0.1031. Done: -1
#  Mean Policy loss: 2.4722. Mean Value loss: 0.3589
# Episode: 167/200, score/average: 0.9500/-1.6000
#
# Reset
# Steps: 23/200. Action: 3. Reward/Value: 0.45/0.0283. Done: 10
#  Mean Policy loss: 5.6607. Mean Value loss: -2.0967
# Episode: 168/200, score/average: 4.9000/-0.9450
#
# Reset
# Steps: 33/200. Action: 4. Reward/Value: -0.7/-0.0425. Done: 1
#  Mean Policy loss: 26.8479. Mean Value loss: -4.5651
# Episode: 169/200, score/average: 15.1500/0.2750
#
# Reset
# Steps: 46/200. Action: 4. Reward/Value: -0.3/-0.0269. Done: -1
#  Mean Policy loss: 4.2033. Mean Value loss: -1.5474
# Episode: 170/200, score/average: 6.8000/1.1150 SAVING
#
# Reset
# Steps: 38/200. Action: 3. Reward/Value: -0.3/0.0528. Done: -1
#  Mean Policy loss: 9.3646. Mean Value loss: 2.3201
# Episode: 171/200, score/average: -4.9500/0.1850
#
# Reset
# Steps: 41/200. Action: 3. Reward/Value: -0.0/0.0715. Done: 10
#  Mean Policy loss: 5.5354. Mean Value loss: -2.0757
# Episode: 172/200, score/average: 7.1500/2.2150
#
# Reset
# Steps: 39/200. Action: 1. Reward/Value: 0.4/-0.0029. Done: -1
#  Mean Policy loss: 6.7634. Mean Value loss: -0.3078
# Episode: 173/200, score/average: 4.8500/3.3100
#
# Reset
# Steps: 43/200. Action: 5. Reward/Value: -0.7/0.1178. Done: 1
#  Mean Policy loss: 6.5771. Mean Value loss: -2.0486
# Episode: 174/200, score/average: 7.8500/4.3100 SAVING
#
# Reset
# Steps: 40/200. Action: 3. Reward/Value: 0.15/-0.0227. Done: -1
#  Mean Policy loss: 11.1174. Mean Value loss: 0.6518
# Episode: 175/200, score/average: -6.5000/3.7150
#
# Reset
# Steps: 23/200. Action: 1. Reward/Value: 0.0/0.0117. Done: 10
#  Mean Policy loss: 3.4227. Mean Value loss: -1.5995
# Episode: 176/200, score/average: 2.9500/3.9150
#
# Reset
# Steps: 26/200. Action: 5. Reward/Value: 0.45/0.0192. Done: 1
#  Mean Policy loss: 2.1638. Mean Value loss: -1.3038
# Episode: 177/200, score/average: 4.7500/4.2950
#
# Reset
# Steps: 16/200. Action: 5. Reward/Value: 0.45/0.0488. Done: 1
#  Mean Policy loss: 21.0019. Mean Value loss: -4.2328
# Episode: 178/200, score/average: 9.7500/4.7800 SAVING
#
# Reset
# Steps: 35/200. Action: 1. Reward/Value: 0.4/0.0343. Done: -10
#  Mean Policy loss: 5.4208. Mean Value loss: 1.2156
# Episode: 179/200, score/average: -2.8000/2.9850
#
# Reset
# Steps: 38/200. Action: 2. Reward/Value: -1.0/0.0686. Done: -1
#  Mean Policy loss: 7.2120. Mean Value loss: 1.9899
# Episode: 180/200, score/average: -3.6500/1.9400 SAVING
#
# Reset
# Steps: 25/200. Action: 1. Reward/Value: -0.7/0.0992. Done: 1
#  Mean Policy loss: 19.2969. Mean Value loss: -3.2912
# Episode: 181/200, score/average: 10.5000/3.4850
#
# Reset
# Steps: 20/200. Action: 3. Reward/Value: 0.7/0.0387. Done: 10
#  Mean Policy loss: 15.0424. Mean Value loss: -3.7474
# Episode: 182/200, score/average: 9.1500/3.6850
#
# Reset
# Steps: 29/200. Action: 1. Reward/Value: -0.3/-0.0761. Done: -1
#  Mean Policy loss: 5.8670. Mean Value loss: -1.6256
# Episode: 183/200, score/average: 6.3500/3.8350
#
# Reset
# Steps: 41/200. Action: 4. Reward/Value: 0.15/-0.0512. Done: -1
#  Mean Policy loss: 4.8660. Mean Value loss: 0.0287
# Episode: 184/200, score/average: 2.4500/3.2950
#
# Reset
# Steps: 27/200. Action: 1. Reward/Value: 0.4/0.0246. Done: -1
#  Mean Policy loss: 0.7004. Mean Value loss: -0.7695
# Episode: 185/200, score/average: 3.0500/4.2500
#
# Reset
# Steps: 21/200. Action: 3. Reward/Value: -0.3/0.0657. Done: -1
#  Mean Policy loss: 1.2384. Mean Value loss: -0.5576
# Episode: 186/200, score/average: 2.3500/4.1900
#
# Reset
# Steps: 42/200. Action: 1. Reward/Value: -0.25/-0.0201. Done: 1
#  Mean Policy loss: 8.5959. Mean Value loss: -1.6323
# Episode: 187/200, score/average: 5.0500/4.2200
#
# Reset
# Steps: 35/200. Action: 4. Reward/Value: -0.55/-0.0148. Done: -1
#  Mean Policy loss: 13.9442. Mean Value loss: 1.2263
# Episode: 188/200, score/average: 1.7000/3.4150
#
# Reset
# Steps: 28/200. Action: 0. Reward/Value: -0.55/0.0172. Done: -1
#  Mean Policy loss: 18.7355. Mean Value loss: 3.6616
# Episode: 189/200, score/average: -7.7500/2.9200
#
# Reset
# Steps: 43/200. Action: 5. Reward/Value: -1.0/0.071. Done: -10
#  Mean Policy loss: 9.0058. Mean Value loss: 0.7084
# Episode: 190/200, score/average: 2.3000/3.5150 SAVING
#
# Reset
# Steps: 38/200. Action: 1. Reward/Value: -0.7/0.113. Done: 10
#  Mean Policy loss: 4.7609. Mean Value loss: -1.6878
# Episode: 191/200, score/average: 5.5500/3.0200
#
# Reset
# Steps: 31/200. Action: 4. Reward/Value: -1.0/0.0636. Done: -1
#  Mean Policy loss: 17.2877. Mean Value loss: 2.5360
# Episode: 192/200, score/average: -2.8500/1.8200
#
# Reset
# Steps: 39/200. Action: 0. Reward/Value: -0.3/0.0652. Done: -1
#  Mean Policy loss: 6.8254. Mean Value loss: 0.7595
# Episode: 193/200, score/average: 0.0500/1.1900
#
# Reset
# Steps: 50/200. Action: 2. Reward/Value: 0.4/0.014. Done: -100
#  Mean Policy loss: 3.8208. Mean Value loss: 0.6151
# Episode: 194/200, score/average: -1.8500/0.7600
#
# Reset
# Steps: 45/200. Action: 2. Reward/Value: -0.55/0.0083. Done: -1
#  Mean Policy loss: 4.4237. Mean Value loss: 0.9069
# Episode: 195/200, score/average: -2.4000/0.2150
#
# Reset
# Steps: 36/200. Action: 5. Reward/Value: 0.45/0.0276. Done: 10
#  Mean Policy loss: 1.7356. Mean Value loss: 0.4642
# Episode: 196/200, score/average: 0.0500/-0.0150
#
# Reset
# Steps: 49/200. Action: 1. Reward/Value: -0.3/0.1288. Done: -1
#  Mean Policy loss: 11.2465. Mean Value loss: 2.3300
# Episode: 197/200, score/average: -7.9500/-1.3150
#
# Reset
# Steps: 38/200. Action: 3. Reward/Value: -0.3/0.0182. Done: -1
#  Mean Policy loss: 1.2209. Mean Value loss: -0.8224
# Episode: 198/200, score/average: 4.0500/-1.0800
#
# Reset
# Steps: 50/200. Action: 5. Reward/Value: 0.15/0.0016. Done: -1
#  Mean Policy loss: 6.7056. Mean Value loss: -0.2636
# Episode: 199/200, score/average: 0.4000/-0.2650
#
# Reset
# Steps: 35/200. Action: 2. Reward/Value: -0.25/0.0364. Done: 1
#  Mean Policy loss: 2.7585. Mean Value loss: -1.1735
# Episode: 200/200, score/average: 4.0000/-0.0950 SAVING
# 127.0.0.1 - - [07/Aug/2024 20:28:38] "GET /socket.io/?EIO=4&transport=websocket&sid=l5UICRNPztkGCyZNAAAC HTTP/1.1" 200 0 19738.392570

# %%
agent.load("auto-docking-iss_PPO__178_9.75.pt")
# Out:
# ./Models5/auto-docking-iss_PPO__178_9.75.pt

# %%
agent.test(500)
# Out:
# Reset
# tensor([0.0148, 0.5833, 0.0600, 0.1667, 0.0847, 0.0904],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0148, 0.5833, 0.0600, 0.1667, 0.0847, 0.0904],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0163, 0.5091, 0.0626, 0.1935, 0.1033, 0.1151],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0181, 0.4316, 0.0706, 0.2128, 0.1182, 0.1486],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0184, 0.4266, 0.0714, 0.2139, 0.1196, 0.1501],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0187, 0.4238, 0.0716, 0.2143, 0.1208, 0.1508],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0190, 0.4207, 0.0719, 0.2147, 0.1221, 0.1516],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0193, 0.4152, 0.0728, 0.2157, 0.1236, 0.1532],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0196, 0.4148, 0.0724, 0.2154, 0.1247, 0.1530],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0199, 0.4119, 0.0727, 0.2158, 0.1260, 0.1537],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0202, 0.4088, 0.0730, 0.2161, 0.1273, 0.1545],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0206, 0.4059, 0.0733, 0.2164, 0.1286, 0.1552],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0209, 0.4028, 0.0736, 0.2167, 0.1300, 0.1560],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0212, 0.4002, 0.0738, 0.2168, 0.1312, 0.1567],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0216, 0.3973, 0.0742, 0.2168, 0.1324, 0.1576],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0220, 0.3942, 0.0744, 0.2169, 0.1339, 0.1585],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0224, 0.3884, 0.0753, 0.2178, 0.1358, 0.1603],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0228, 0.3880, 0.0748, 0.2170, 0.1372, 0.1601],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0233, 0.3848, 0.0750, 0.2171, 0.1388, 0.1610],
#        grad_fn=<SoftmaxBackward0>)
# tensor([0.0237, 0.3816, 0.0753, 0.2172, 0.1404, 0.1617],
#        grad_fn=<SoftmaxBackward0>)
#
# Next state: [-0.10210000001075059, -1.2969, -0.1149, -0.12171139528910425, 0.0, 0.0]
# 127.0.0.1 - - [07/Aug/2024 21:47:31] "GET /socket.io/?EIO=4&transport=websocket&sid=BygjM8lNpAGHPVtxAAAA HTTP/1.1" 200 0 51.115984
# (5462) accepted ('127.0.0.1', 49988)
# 127.0.0.1 - - [07/Aug/2024 21:47:31] "GET / HTTP/1.1" 304 242 0.000564
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /css/normalize.css HTTP/1.1" 304 201 0.000750
# (5462) accepted ('127.0.0.1', 49992)
# (5462) accepted ('127.0.0.1', 50004)
# (5462) accepted ('127.0.0.1', 50010)
# (5462) accepted ('127.0.0.1', 50022)
# (5462) accepted ('127.0.0.1', 50026)
# (5462) accepted ('127.0.0.1', 50032)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /css/layout.css HTTP/1.1" 304 198 0.001103
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /js/three/three.js HTTP/1.1" 304 196 0.000684
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /js/three/WebGL.js HTTP/1.1" 304 196 0.000597
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /js/three/GLTFLoader.js HTTP/1.1" 304 201 0.000574
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /js/three/CSS2DRenderer.js HTTP/1.1" 304 204 0.000483
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /js/gsap3/gsap.js HTTP/1.1" 304 195 0.000471
# (5462) accepted ('127.0.0.1', 50036)
# (5462) accepted ('127.0.0.1', 50052)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /js/gsap3/DrawSVGPlugin.js HTTP/1.1" 304 204 0.000675
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /js/gsap3/ScrambleTextPlugin.js HTTP/1.1" 304 209 0.000704
# (5462) accepted ('127.0.0.1', 50062)
# (5462) accepted ('127.0.0.1', 50064)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/hud-darken.png HTTP/1.1" 304 202 0.001319
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/hud-ring.png HTTP/1.1" 304 200 0.000602
# (5462) accepted ('127.0.0.1', 50078)
# (5462) accepted ('127.0.0.1', 50090)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/hud-ring-inner.png HTTP/1.1" 304 206 0.000596
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/shadow.png HTTP/1.1" 304 198 0.000587
# (5462) accepted ('127.0.0.1', 50094)
# (5462) accepted ('127.0.0.1', 50098)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /js/threed.js HTTP/1.1" 304 197 0.000604
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/instructions/step1_6.jpg HTTP/1.1" 304 199 0.000415
# (5462) accepted ('127.0.0.1', 50112)
# (5462) accepted ('127.0.0.1', 50116)
# (5462) accepted ('127.0.0.1', 50120)
# (5462) accepted ('127.0.0.1', 50130)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/instructions/step2.jpg HTTP/1.1" 304 197 0.000421
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/instructions/step3.jpg HTTP/1.1" 304 197 0.000373
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/instructions/step4.jpg HTTP/1.1" 304 197 0.000412
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/instructions/step5.jpg HTTP/1.1" 304 197 0.000299
# (5462) accepted ('127.0.0.1', 50144)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/instructions/step7.jpg HTTP/1.1" 304 197 0.000337
# (5462) accepted ('127.0.0.1', 50156)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /socket.io/?EIO=4&transport=polling&t=P4kOU1U HTTP/1.1" 200 278 0.000261
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/earth.jpg HTTP/1.1" 304 197 0.000626
# (5462) accepted ('127.0.0.1', 50166)
# (5462) accepted ('127.0.0.1', 50178)
# (5462) accepted ('127.0.0.1', 50184)
# (5462) accepted ('127.0.0.1', 50190)
# (5462) accepted ('127.0.0.1', 50200)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/navball.png HTTP/1.1" 304 199 0.000417
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/texture_fire.jpg HTTP/1.1" 304 204 0.000399
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/texture_wormhole.jpg HTTP/1.1" 304 208 0.000464
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/texture_star.jpg HTTP/1.1" 304 204 0.000365
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/hud/ForwardViewSprites.json HTTP/1.1" 304 211 0.000396
# (5462) accepted ('127.0.0.1', 50208)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/hud/ForwardViewSprites2.png HTTP/1.1" 304 211 0.000381
# (5462) accepted ('127.0.0.1', 45674)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /3d/iss.glb HTTP/1.1" 304 195 0.000782
# (5462) accepted ('127.0.0.1', 45684)
# (5462) accepted ('127.0.0.1', 45692)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "POST /socket.io/?EIO=4&transport=polling&t=P4kOU4K&sid=UPRbgGQkRNySjq3cAAAC HTTP/1.1" 200 219 0.000392
# (5462) accepted ('127.0.0.1', 45694)
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /socket.io/?EIO=4&transport=polling&t=P4kOU4L&sid=UPRbgGQkRNySjq3cAAAC HTTP/1.1" 200 181 0.000115
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /socket.io/?EIO=4&transport=polling&t=P4kOU6F&sid=UPRbgGQkRNySjq3cAAAC HTTP/1.1" 200 181 0.000154
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /img/favicon.ico HTTP/1.1" 304 199 0.001113
# 127.0.0.1 - - [07/Aug/2024 21:47:32] "GET /socket.io/?EIO=4&transport=polling&t=P4kOU6N&sid=UPRbgGQkRNySjq3cAAAC HTTP/1.1" 200 181 0.000208

# %%
import time
from math import sqrt
import matplotlib.pyplot as plt
import random
from env5 import Env
import os
import numpy as np
import torch
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader
from copy import deepcopy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class ExperienceDataset(Dataset):
    def __init__(self, data):
        super().__init__()
        self.data = data

    def __len__(self):
        return len(self.data[0])

    def __getitem__(self, ind):
        return tuple(map(lambda t: t[ind], self.data))

def create_shuffled_dataloader(data, batch_size):
    ds = ExperienceDataset(data)
    return DataLoader(ds, batch_size = batch_size, shuffle = True)

# %%
class PolicyNetwork(torch.nn.Module):
    def __init__(self,state_dims, n_actions):
        super(PolicyNetwork, self).__init__()
        self.actor = torch.nn.Sequential(
            torch.nn.Linear(6, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, n_actions),
            torch.nn.Softmax(dim=-1)
        )

    def forward(self, x):
        policy = self.actor(x)
        return policy
    

class ValueNetwork(torch.nn.Module):
    def __init__(self,state_dims):
        super(ValueNetwork, self).__init__()
        self.critic = torch.nn.Sequential(
            torch.nn.Linear(6, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        value = self.critic(x)
        return value
        
def weights_init(m):
    if isinstance(m,torch.nn.Linear):
        m.bias.data.fill_(0)
        torch.nn.init.kaiming_uniform_(m.weight)


def np_to_tensor(x):
    return torch.tensor(x).to(torch.float32)

    
policy_model = PolicyNetwork(state_dims=6, n_actions = 7)
value_model = ValueNetwork(state_dims=6)

# %%
print(policy_model,value_model)
summary(policy_model, input_size=(1, 6))
summary(value_model, input_size=(1, 6))
# Out:
# PolicyNetwork(
#   (actor): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=7, bias=True)
#     (5): Softmax(dim=-1)
#   )
# ) ValueNetwork(
#   (critic): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             448
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 32]           2,080
#               ReLU-4                [-1, 1, 32]               0
#             Linear-5                 [-1, 1, 7]             231
#            Softmax-6                 [-1, 1, 7]               0
# ================================================================
# Total params: 2,759
# Trainable params: 2,759
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             448
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 32]           2,080
#               ReLU-4                [-1, 1, 32]               0
#             Linear-5                 [-1, 1, 1]              33
# ================================================================
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------

# %%
class PPO:
    def __init__(self, state_dim=6, action_dim=7, policy_lr=0.0005, value_lr=0.001, 
                 gamma=0.99, lam=0.95, beta_s=0.01,epsilon_clip=0.2, value_clip=0.4, 
                 epochs=5,batch_size=50,save_path='Models'):
        
        self.policy_net = PolicyNetwork(state_dim, action_dim).to(device)
        self.value_net = ValueNetwork(state_dim).to(device)
        self.policy_net.apply(weights_init)
        self.value_net.apply(weights_init)

        self.policy_optimizer = torch.optim.Adam(self.policy_net.parameters(), lr=policy_lr)
        self.value_optimizer = torch.optim.Adam(self.value_net.parameters(), lr=value_lr)

        self.gamma = gamma
        self.lamda = lam
        self.epsilon_clip = epsilon_clip
        self.value_clip = value_clip
        self.beta_s = beta_s
        self.epochs = epochs
        self.action_dim = action_dim
        self.batch_size = batch_size

        self.env = Env(port=5555)
        self.env.run()

        self.save_path = save_path
        self.env_name = "auto-docking-iss"

        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
        self.path = str(self.env_name)+'_PPO_'
        self.model_name = os.path.join(self.save_path, self.path)

        self.trajectory = {'states':[],'actions':[], 'rewards':[], 'action_logs':[],
                           'values':[],'done':[]}
        
        self.scores, self.episodes, self.average = [],[],[]
        self.value_loss_mean, self.policy_loss_mean = [], []

    def save(self,episode,score):
        torch.save({
            'actor': self.policy_net.state_dict(),
            'critic': self.value_net.state_dict()
        }, f'./'+ self.model_name + '_' + str(episode) + '_' + str(round(score,4)) + '.pt')

    def load(self,name):
        print(f'./{name}')
        try:
            data = torch.load(f'./{name}')
            self.policy_net.load_state_dict(data['actor'])
            self.value_net.load_state_dict(data['critic'])
        except Exception as e:
            print(e)

    # Función para visualizar la evolución del entrenamiento
    def plot_model(self, score, episode,num_episodes):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-10:]) / len(self.scores[-10:]))
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(1,figsize=(18, 9))
            plt.plot(self.episodes, self.scores, 'b')
            plt.plot(self.episodes, self.average, 'r')
            plt.ylabel('Score', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"scores.png")
            except OSError:
                pass

        return self.average[-1]
    
    def plot_loss(self,episode,num_episodes):        
        if (episode % 10 == 0 and episode > 0) or episode == num_episodes:#str(episode)[-2:] == "00":# much faster than episode % 100
            plt.figure(2,figsize=(18, 9))
            plt.plot(self.episodes, self.policy_loss_mean, 'b')
            plt.plot(self.episodes, self.value_loss_mean, 'r')
            plt.ylabel('Loss', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.savefig(self.model_name+"loss.png")
            except OSError:
                pass
    

    #Almacenamiento de todas las variables que definen una transición para PPO
    def collect_trayectory(self,state,action,action_logs,reward,done,value):
        self.trajectory['states'].append(state)
        self.trajectory['actions'].append(action)
        self.trajectory['rewards'].append(reward)
        self.trajectory['values'].append(value)
        self.trajectory['action_logs'].append(action_logs)
        self.trajectory['done'].append(done)
    
    def clear_trayectory(self):
        for key in self.trajectory.keys():
            self.trajectory[key].clear()
    
    def select_action(self,state):
        action_probs = self.policy_net(state).squeeze().detach()
        dist = torch.distributions.Categorical(action_probs)
        action = dist.sample()
        action_log_probs = dist.log_prob(action)
        
        return action.item(),action_log_probs,dist.entropy().item()

    
    def generalized_advantage_estimation(self,next_state):
        advantages = np.zeros_like(self.trajectory['rewards'])
        last_gae_lambda = 0
        self.trajectory['values'].append(self.value_net(next_state).squeeze().detach())

        for t in reversed(range(len(self.trajectory['rewards']))):
            delta = self.trajectory['rewards'][t]+ self.gamma * self.trajectory['values'][t + 1].item() - self.trajectory['values'][t].item()
            advantages[t] = last_gae_lambda = delta + self.gamma * self.lamda * last_gae_lambda
        
        return np_to_tensor(advantages)


    def learn_from_episode_trajectory(self,next_state):
        self.policy_net.train()
        self.value_net.train()

        states = deepcopy(self.trajectory['states'])
        actions = deepcopy(self.trajectory['actions'])
        # rewards = deepcopy(self.trajectory['rewards'])
        values = deepcopy(self.trajectory['values'])
        action_logs = deepcopy(self.trajectory['action_logs'])
        # done = deepcopy(self.trajectory['done'])

        advantages = self.generalized_advantage_estimation(next_state).to(device)

        # prepare dataloader for policy phase training
        dl = create_shuffled_dataloader([states, actions, action_logs, advantages, values], self.batch_size)

        policy_loss_array = []
        value_loss_array = []

        for i in range(self.epochs):
            for states, actions, action_log, advantages, values in dl:
                #Update policy_net
                new_action_probs = self.policy_net(states).squeeze()
                dist = torch.distributions.Categorical(new_action_probs)

                # print("")
                # print(actions)
                # print(new_action_probs)
                new_action_logs = dist.log_prob(actions)
                entropy = dist.entropy()

                # compute PPO-Clip
                ratios = torch.exp(new_action_logs - action_log)
                surr1 = ratios * advantages
                surr2 = ratios.clamp(1 - self.epsilon_clip, 1 + self.epsilon_clip) * advantages
                policy_loss = -torch.mean(torch.min(surr1, surr2) - self.beta_s * entropy)
                policy_loss_array.append(policy_loss.detach().numpy())

                self.policy_optimizer.zero_grad() # Clean gradients
                policy_loss.mean().backward() # Compute gradients
                self.policy_optimizer.step() #Update weights

                #Update value_net
                new_values = self.value_net(states).squeeze()
                value_clipped = values + (new_values - values).clamp(-self.value_clip, self.value_clip)
                value_loss_1 = (value_clipped.flatten() - advantages) ** 2
                value_loss_2 = (values.flatten() - advantages) ** 2
                value_loss = torch.mean(torch.max(value_loss_1, value_loss_2))
                value_loss_array.append(value_loss.detach().numpy())

                self.value_optimizer.zero_grad() # Clean gradients
                value_loss.backward() # Compute gradients 

        self.value_loss_mean.append(sum(value_loss_array)/self.epochs)
        self.policy_loss_mean.append(sum(policy_loss_array)/self.epochs)

        print(f"\n Mean Policy loss: {self.value_loss_mean[-1]:.4f}. Mean Value loss: {self.policy_loss_mean[-1]:.4f}")
        
        self.policy_net.eval()
        self.value_net.eval()


    # Función para resetear el entorno tras acabar trayectoria
    def reset(self):
        state = self.env.reset()
        return np_to_tensor(self.process_state(state))
    
     # Función para interacción agente-entorno
    def step(self, action):
        next_state, reward, done = self.env.step(action)
        next_state = self.process_state(next_state)
        return np_to_tensor(next_state), reward, done

    def process_state(self,state):
        state_processed = np.array(state)
        state_processed[:3] = state_processed[:3] / 40 # Position array
        return state_processed
    
    def train(self,num_episodes=200,max_steps=200):
        average = 0
        self.policy_net.eval()
        self.value_net.eval()

        max_score_average = -5000

        for episode in range(1,num_episodes+1):
            self.clear_trayectory()

            state = self.reset()
            score = 0

            SAVING = ""

            for step in range(1,max_steps+1):
                
                action_probs = self.policy_net(state).squeeze().detach()
                dist = torch.distributions.Categorical(action_probs)
                action = dist.sample()
                action_log = dist.log_prob(action)

                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action.item())    
                self.collect_trayectory(state,action,action_log,reward,done,value)

                state = next_state

                score += reward

                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Reward/Value: {round(reward,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)

                if done:
                    break
                
                time.sleep(1.0)

            self.learn_from_episode_trajectory(next_state)
            self.clear_trayectory()

            average = self.plot_model(score, episode,num_episodes)
            self.plot_loss(episode,num_episodes)
            
            if average >= max_score_average and episode > 5:
                max_score_average = average
                self.save(episode,average)
                SAVING = "SAVING"
            elif episode % 10 == 0:
                self.save(episode,average)
                SAVING = "SAVING"
            else:
                SAVING = ""
            
            print(f"Episode: {episode}/{num_episodes}, score/average: {score:.4f}/{average:.4f} {SAVING}\n")


        # close environemnt when finish training
        self.save(episode,average)

    def test(self,max_steps):
        self.policy_net.eval()
        self.value_net.eval()

        self.clear_trayectory()
        state = self.reset()
        score = 0

        start = time.time()
        end = time.time()
        step = 0

        while True:
            end = time.time()
            if end - start >= 1.0:
                step += 1
                action_probabilities = self.policy_net(state)
                action = torch.argmax(action_probabilities, dim=-1).item()#np.argmax(self.policy_net(state).squeeze().detach().numpy())
                value = self.value_net(state).squeeze().detach()
                
                next_state,reward,done = self.step(action)    

                state = next_state

                score += reward

                # print(action_probabilities)
                print(f'\rSteps: {step}/{max_steps}. Action: {action}. Score/Value: {round(score,2)}/{round(value.item(),4)}. Done: {done}', end='', flush=True)
                start = time.time()

            if self.env.done or step > max_steps:
                break

        state_end = self.env.get_state()
        
        print(f'\nNext state: {state_end}')

# %%
agent = PPO(save_path='Models8')
# Out:
# (8321) wsgi starting up on http://127.0.0.1:5555
# (8321) accepted ('127.0.0.1', 40560)
# (8321) accepted ('127.0.0.1', 40574)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET / HTTP/1.1" 304 242 0.003393
# (8321) accepted ('127.0.0.1', 40582)
# (8321) accepted ('127.0.0.1', 40592)
# (8321) accepted ('127.0.0.1', 40600)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /css/layout.css HTTP/1.1" 304 198 0.001284
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /js/three/three.js HTTP/1.1" 304 196 0.000751
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /js/three/WebGL.js HTTP/1.1" 304 196 0.000662
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /css/normalize.css HTTP/1.1" 304 201 0.000563
# (8321) accepted ('127.0.0.1', 40610)
# (8321) accepted ('127.0.0.1', 40612)
# (8321) accepted ('127.0.0.1', 40624)
# (8321) accepted ('127.0.0.1', 40638)
# (8321) accepted ('127.0.0.1', 40654)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /js/three/GLTFLoader.js HTTP/1.1" 304 201 0.000593
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /js/three/CSS2DRenderer.js HTTP/1.1" 304 204 0.000348
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /js/gsap3/gsap.js HTTP/1.1" 304 195 0.000304
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /js/gsap3/DrawSVGPlugin.js HTTP/1.1" 304 204 0.000334
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /js/gsap3/ScrambleTextPlugin.js HTTP/1.1" 304 209 0.000431
# (8321) accepted ('127.0.0.1', 40664)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/hud-darken.png HTTP/1.1" 304 202 0.000768
# (8321) accepted ('127.0.0.1', 40672)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/hud-ring.png HTTP/1.1" 304 200 0.000610
# (8321) accepted ('127.0.0.1', 40688)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/hud-ring-inner.png HTTP/1.1" 304 206 0.000500
# (8321) accepted ('127.0.0.1', 40698)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/shadow.png HTTP/1.1" 304 198 0.000369
# (8321) accepted ('127.0.0.1', 40706)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /js/threed.js HTTP/1.1" 304 197 0.000803
# (8321) accepted ('127.0.0.1', 40708)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/instructions/step1_6.jpg HTTP/1.1" 304 199 0.000609
# (8321) accepted ('127.0.0.1', 40712)
# (8321) accepted ('127.0.0.1', 40716)
# (8321) accepted ('127.0.0.1', 40720)
# (8321) accepted ('127.0.0.1', 40734)
# (8321) accepted ('127.0.0.1', 40736)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/instructions/step2.jpg HTTP/1.1" 304 197 0.000459
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/instructions/step3.jpg HTTP/1.1" 304 197 0.000420
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/instructions/step4.jpg HTTP/1.1" 304 197 0.000322
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/instructions/step5.jpg HTTP/1.1" 304 197 0.000392
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/instructions/step7.jpg HTTP/1.1" 304 197 0.000370
# (8321) accepted ('127.0.0.1', 40752)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /socket.io/?EIO=4&transport=polling&t=P4rhtjp HTTP/1.1" 200 278 0.000419
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/hud/ForwardViewSprites.json HTTP/1.1" 304 211 0.000924
# (8321) accepted ('127.0.0.1', 40766)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /3d/iss.glb HTTP/1.1" 304 195 0.000596
# (8321) accepted ('127.0.0.1', 40778)
# (8321) accepted ('127.0.0.1', 40790)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/earth.jpg HTTP/1.1" 304 197 0.000643
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/navball.png HTTP/1.1" 304 199 0.000670
# (8321) accepted ('127.0.0.1', 40806)
# (8321) accepted ('127.0.0.1', 40816)
# (8321) accepted ('127.0.0.1', 40828)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/texture_fire.jpg HTTP/1.1" 304 204 0.000838
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/texture_wormhole.jpg HTTP/1.1" 304 208 0.000771
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/texture_star.jpg HTTP/1.1" 304 204 0.000576
# (8321) accepted ('127.0.0.1', 40842)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /img/hud/ForwardViewSprites2.png HTTP/1.1" 304 211 0.000587
# (8321) accepted ('127.0.0.1', 40858)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "POST /socket.io/?EIO=4&transport=polling&t=P4rhtnT&sid=qY_mmXHZgP8Af9L0AAAA HTTP/1.1" 200 219 0.000710
# (8321) accepted ('127.0.0.1', 40860)
# (8321) accepted ('127.0.0.1', 40872)
# 127.0.0.1 - - [09/Aug/2024 07:49:38] "GET /socket.io/?EIO=4&transport=polling&t=P4rhtnU&sid=qY_mmXHZgP8Af9L0AAAA HTTP/1.1" 200 181 0.000162
# 127.0.0.1 - - [09/Aug/2024 07:49:39] "GET /socket.io/?EIO=4&transport=polling&t=P4rhtq_&sid=qY_mmXHZgP8Af9L0AAAA HTTP/1.1" 200 181 0.000195
# 127.0.0.1 - - [09/Aug/2024 07:49:39] "GET /socket.io/?EIO=4&transport=polling&t=P4rhtrV&sid=qY_mmXHZgP8Af9L0AAAA HTTP/1.1" 200 181 0.000241
# 127.0.0.1 - - [09/Aug/2024 07:49:39] "GET /img/favicon.ico HTTP/1.1" 304 199 0.000658
# 127.0.0.1 - - [09/Aug/2024 07:49:39] "GET /img/target-iss.png HTTP/1.1" 304 202 0.001054

# %%
agent.train(num_episodes=200,max_steps=200)
# Out:
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.93/-0.0953. Done: 0
#  Mean Policy loss: 1346.8501. Mean Value loss: 71.9002
# Episode: 1/200, score/average: -228.4277/-228.4277
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.68/-0.0145. Done: 0
#  Mean Policy loss: 1692.8066. Mean Value loss: 80.2529
# Episode: 2/200, score/average: -256.7874/-242.6075
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -4.45/-0.065. Done: 00
#  Mean Policy loss: 7290.8193. Mean Value loss: 159.1554
# Episode: 3/200, score/average: -495.4860/-326.9003
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -3.77/-0.1913. Done: 0
#  Mean Policy loss: 8430.2803. Mean Value loss: 179.4861
# Episode: 4/200, score/average: -565.7474/-386.6121
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -4.35/0.0623. Done: 00
#  Mean Policy loss: 7391.9170. Mean Value loss: 161.4709
# Episode: 5/200, score/average: -506.6283/-410.6154
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -2.6/-0.1002. Done: 00
#  Mean Policy loss: 3028.9995. Mean Value loss: 108.3722
# Episode: 6/200, score/average: -344.9060/-399.6638 SAVING
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.51/0.0069. Done: 00
#  Mean Policy loss: 1339.9329. Mean Value loss: 71.8286
# Episode: 7/200, score/average: -232.1362/-375.7313 SAVING
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.58/-0.0318. Done: 0
#  Mean Policy loss: 1055.3043. Mean Value loss: 62.5290
# Episode: 8/200, score/average: -206.7539/-354.6091 SAVING
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -1.74/-0.0479. Done: 0
#  Mean Policy loss: 1753.2053. Mean Value loss: 82.4810
# Episode: 9/200, score/average: -264.8888/-344.6402 SAVING
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.27/-0.0724. Done: 0
#  Mean Policy loss: 1867.7107. Mean Value loss: 83.4830
# Episode: 10/200, score/average: -269.8042/-337.1566 SAVING
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -4.05/-0.1891. Done: 0
#  Mean Policy loss: 7923.8296. Mean Value loss: 171.9727
# Episode: 11/200, score/average: -538.6163/-368.1755
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.61/-0.0405. Done: 0
#  Mean Policy loss: 3157.1343. Mean Value loss: 110.0874
# Episode: 12/200, score/average: -353.4942/-377.8461
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.92/-0.0346. Done: 0
#  Mean Policy loss: 2846.0281. Mean Value loss: 101.7201
# Episode: 13/200, score/average: -318.8197/-360.1795
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -2.34/0.0541. Done: 00
#  Mean Policy loss: 3995.9773. Mean Value loss: 122.1847
# Episode: 14/200, score/average: -386.9976/-342.3045
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -2.61/-0.1268. Done: 0
#  Mean Policy loss: 1759.0768. Mean Value loss: 81.0064
# Episode: 15/200, score/average: -257.5925/-317.4010 SAVING
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -0.78/-0.0087. Done: 0
#  Mean Policy loss: 2831.7983. Mean Value loss: 100.1323
# Episode: 16/200, score/average: -317.0008/-314.6104 SAVING
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -4.3/0.1119. Done: 000
#  Mean Policy loss: 10589.8525. Mean Value loss: 195.9811
# Episode: 17/200, score/average: -613.3472/-352.7315
#
# Reset
# Steps: 176/200. Action: 5. Reward/Value: -0.22/-0.039. Done: 10
#  Mean Policy loss: 290.5022. Mean Value loss: 31.6554
# Episode: 18/200, score/average: -95.0232/-341.5585
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.95/-0.085. Done: 00
#  Mean Policy loss: 4011.2195. Mean Value loss: 119.4201
# Episode: 19/200, score/average: -374.1116/-352.4807
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.69/-0.015. Done: 00
#  Mean Policy loss: 1529.4619. Mean Value loss: 74.3093
# Episode: 20/200, score/average: -243.8110/-349.8814 SAVING
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -3.44/-0.0946. Done: 0
#  Mean Policy loss: 4474.8135. Mean Value loss: 125.4427
# Episode: 21/200, score/average: -389.2784/-334.9476
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.57/-0.0283. Done: 0
#  Mean Policy loss: 1793.8718. Mean Value loss: 82.3129
# Episode: 22/200, score/average: -259.7673/-325.5749
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -1.9/-0.01. Done: 0: 0
#  Mean Policy loss: 2529.0784. Mean Value loss: 98.2943
# Episode: 23/200, score/average: -318.2500/-325.5179
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -2.8/-0.1898. Done: 00
#  Mean Policy loss: 3737.1321. Mean Value loss: 117.2226
# Episode: 24/200, score/average: -367.9784/-323.6160
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.2/-0.0524. Done: 00
#  Mean Policy loss: 3984.3218. Mean Value loss: 120.7846
# Episode: 25/200, score/average: -383.0894/-336.1657
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.48/-0.0372. Done: 0
#  Mean Policy loss: 3399.8821. Mean Value loss: 111.5202
# Episode: 26/200, score/average: -353.6739/-339.8330
#
# Reset
# Steps: 153/200. Action: 0. Reward/Value: -1.7/0.0215. Done: -10
#  Mean Policy loss: 2466.0640. Mean Value loss: 96.0078
# Episode: 27/200, score/average: -245.5314/-303.0514 SAVING
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -1.58/0.062. Done: 000
#  Mean Policy loss: 2815.5767. Mean Value loss: 103.7500
# Episode: 28/200, score/average: -329.0425/-326.4534
#
# Reset
# Steps: 185/200. Action: 0. Reward/Value: -0.62/0.0434. Done: -1
#  Mean Policy loss: 1096.7466. Mean Value loss: 61.7495
# Episode: 29/200, score/average: -190.4709/-308.0893
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.54/0.0309. Done: 00
#  Mean Policy loss: 4605.0493. Mean Value loss: 128.4466
# Episode: 30/200, score/average: -400.9428/-323.8025 SAVING
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -2.85/0.0724. Done: 00
#  Mean Policy loss: 5440.3838. Mean Value loss: 143.5220
# Episode: 31/200, score/average: -453.7584/-330.2505
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.83/0.0149. Done: 00
#  Mean Policy loss: 911.6525. Mean Value loss: 58.7558
# Episode: 32/200, score/average: -190.5630/-323.3301
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -3.21/-0.0532. Done: 0
#  Mean Policy loss: 3817.5874. Mean Value loss: 118.5897
# Episode: 33/200, score/average: -374.6001/-328.9651
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.14/-0.0262. Done: 0
#  Mean Policy loss: 4741.5557. Mean Value loss: 134.6834
# Episode: 34/200, score/average: -425.7816/-334.7454
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -0.82/0.0274. Done: 00
#  Mean Policy loss: 1398.1296. Mean Value loss: 71.1643
# Episode: 35/200, score/average: -234.3153/-319.8680
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -3.58/0.0247. Done: 00
#  Mean Policy loss: 7388.7368. Mean Value loss: 160.6797
# Episode: 36/200, score/average: -499.7201/-334.4726
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.64/-0.08. Done: 0 0
#  Mean Policy loss: 1611.8528. Mean Value loss: 78.6130
# Episode: 37/200, score/average: -255.7265/-335.4921
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -4.71/-0.0153. Done: 0
#  Mean Policy loss: 9130.2920. Mean Value loss: 178.6236
# Episode: 38/200, score/average: -556.4975/-358.2376
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -2.45/-0.0189. Done: 0
#  Mean Policy loss: 3267.4282. Mean Value loss: 111.6808
# Episode: 39/200, score/average: -354.0181/-374.5923
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -2.51/-0.0837. Done: 0
#  Mean Policy loss: 3723.2102. Mean Value loss: 113.6892
# Episode: 40/200, score/average: -354.0871/-369.9068 SAVING
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -2.86/-0.0181. Done: 0
#  Mean Policy loss: 2078.9792. Mean Value loss: 85.6941
# Episode: 41/200, score/average: -271.2808/-351.6590
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -4.53/-0.0836. Done: 0
#  Mean Policy loss: 8441.0908. Mean Value loss: 176.2157
# Episode: 42/200, score/average: -548.5796/-387.4607
#
# Reset
# Steps: 165/200. Action: 6. Reward/Value: -1.6/-0.0493. Done: -1
#  Mean Policy loss: 1185.5341. Mean Value loss: 67.9084
# Episode: 43/200, score/average: -179.2675/-367.9274
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -3.79/0.0046. Done: 00
#  Mean Policy loss: 4315.5107. Mean Value loss: 123.6691
# Episode: 44/200, score/average: -388.5799/-364.2072
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -1.48/0.0059. Done: 00
#  Mean Policy loss: 5230.2178. Mean Value loss: 138.4320
# Episode: 45/200, score/average: -434.8916/-384.2649
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -2.54/-0.0696. Done: 0
#  Mean Policy loss: 3240.2058. Mean Value loss: 109.6528
# Episode: 46/200, score/average: -344.7198/-368.7649
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -6.15/0.0186. Done: 00
#  Mean Policy loss: 15316.6328. Mean Value loss: 234.0421
# Episode: 47/200, score/average: -731.4740/-416.3396
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -4.87/-0.039. Done: 00
#  Mean Policy loss: 7001.3306. Mean Value loss: 152.5624
# Episode: 48/200, score/average: -474.0247/-408.0923
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -2.26/-0.073. Done: 00
#  Mean Policy loss: 1850.9808. Mean Value loss: 84.2620
# Episode: 49/200, score/average: -272.3532/-399.9258
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.52/-0.12. Done: 000
#  Mean Policy loss: 4500.6904. Mean Value loss: 130.2711
# Episode: 50/200, score/average: -406.1460/-405.1317 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -4.05/-0.1616. Done: 0
#  Mean Policy loss: 5652.4102. Mean Value loss: 143.5119
# Episode: 51/200, score/average: -456.5216/-423.6558
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -3.27/-0.0268. Done: 0
#  Mean Policy loss: 4323.4487. Mean Value loss: 128.3570
# Episode: 52/200, score/average: -402.9716/-409.0950
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -2.96/0.0487. Done: 00
#  Mean Policy loss: 4823.3433. Mean Value loss: 128.5501
# Episode: 53/200, score/average: -400.9001/-431.2582
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -4.34/-0.1476. Done: 0
#  Mean Policy loss: 11068.7344. Mean Value loss: 203.2255
# Episode: 54/200, score/average: -631.7804/-455.5783
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -4.7/-0.1758. Done: 00
#  Mean Policy loss: 5665.9150. Mean Value loss: 136.3333
# Episode: 55/200, score/average: -423.3635/-454.4255
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -3.36/-0.0534. Done: 0
#  Mean Policy loss: 6359.2393. Mean Value loss: 154.0778
# Episode: 56/200, score/average: -483.9629/-468.3498
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.99/-0.123. Done: 00
#  Mean Policy loss: 3043.4148. Mean Value loss: 107.9464
# Episode: 57/200, score/average: -342.9411/-429.4965
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -5.21/-0.1661. Done: 0
#  Mean Policy loss: 10426.9209. Mean Value loss: 189.5196
# Episode: 58/200, score/average: -590.2444/-441.1185
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -3.92/-0.0383. Done: 0
#  Mean Policy loss: 4459.9385. Mean Value loss: 125.8055
# Episode: 59/200, score/average: -400.6286/-453.9460
#
# Reset
# Steps: 152/200. Action: 5. Reward/Value: -1.4/-0.0336. Done: -1
#  Mean Policy loss: 1480.8160. Mean Value loss: 75.1904
# Episode: 60/200, score/average: -189.6100/-432.2924 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -4.38/-0.0122. Done: 0
#  Mean Policy loss: 6540.7319. Mean Value loss: 151.0454
# Episode: 61/200, score/average: -465.4280/-433.1831
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -2.44/-0.0026. Done: 0
#  Mean Policy loss: 4112.6753. Mean Value loss: 125.7922
# Episode: 62/200, score/average: -398.0852/-432.6944
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -2.31/-0.0039. Done: 0
#  Mean Policy loss: 2990.9009. Mean Value loss: 106.6702
# Episode: 63/200, score/average: -334.8220/-426.0866
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -3.01/-0.0965. Done: 0
#  Mean Policy loss: 4445.7646. Mean Value loss: 129.8403
# Episode: 64/200, score/average: -408.9804/-403.8066
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -1.31/0.0367. Done: 00
#  Mean Policy loss: 1618.1267. Mean Value loss: 78.1790
# Episode: 65/200, score/average: -249.0189/-386.3721
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -2.15/0.0004. Done: 00
#  Mean Policy loss: 4256.1128. Mean Value loss: 126.2815
# Episode: 66/200, score/average: -401.0972/-378.0856
#
# Reset
# Steps: 158/200. Action: 0. Reward/Value: -3.69/-0.0845. Done: -1
#  Mean Policy loss: 6669.3804. Mean Value loss: 157.0764
# Episode: 67/200, score/average: -398.6940/-383.6609
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -2.57/0.0244. Done: 00
#  Mean Policy loss: 3819.1204. Mean Value loss: 117.0828
# Episode: 68/200, score/average: -365.9782/-361.2342
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -5.07/0.0267. Done: 0
#  Mean Policy loss: 10118.6885. Mean Value loss: 187.5598
# Episode: 69/200, score/average: -584.2267/-379.5941
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -2.02/-0.0169. Done: 0
#  Mean Policy loss: 3912.7019. Mean Value loss: 121.3382
# Episode: 70/200, score/average: -383.9598/-399.0290 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -1.36/-0.1013. Done: 0
#  Mean Policy loss: 1039.0876. Mean Value loss: 63.4712
# Episode: 71/200, score/average: -204.2597/-372.9122
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.63/-0.1566. Done: 0
#  Mean Policy loss: 3913.0239. Mean Value loss: 122.0722
# Episode: 72/200, score/average: -387.6088/-371.8646
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -1.19/-0.0412. Done: 0
#  Mean Policy loss: 1698.9030. Mean Value loss: 80.5037
# Episode: 73/200, score/average: -259.6716/-364.3495
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -2.34/0.0918. Done: 00
#  Mean Policy loss: 2427.7075. Mean Value loss: 95.4979
# Episode: 74/200, score/average: -301.7083/-353.6223
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -1.04/0.0172. Done: 00
#  Mean Policy loss: 2693.2380. Mean Value loss: 97.8506
# Episode: 75/200, score/average: -308.9598/-359.6164
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.68/0.0452. Done: 00
#  Mean Policy loss: 1501.5170. Mean Value loss: 75.9215
# Episode: 76/200, score/average: -246.2678/-344.1335
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -1.19/-0.0258. Done: 0
#  Mean Policy loss: 2326.0249. Mean Value loss: 93.2474
# Episode: 77/200, score/average: -300.8424/-334.3483
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -1.53/-0.0253. Done: 0
#  Mean Policy loss: 1829.8135. Mean Value loss: 83.7336
# Episode: 78/200, score/average: -272.8317/-325.0337
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -1.25/-0.114. Done: 00
#  Mean Policy loss: 884.2686. Mean Value loss: 54.6229
# Episode: 79/200, score/average: -187.7175/-285.3828 SAVING
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -4.86/0.02. Done: 0: 0
#  Mean Policy loss: 9814.8262. Mean Value loss: 186.5826
# Episode: 80/200, score/average: -577.4722/-304.7340 SAVING
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.59/-0.0976. Done: 0
#  Mean Policy loss: 1587.6945. Mean Value loss: 78.3009
# Episode: 81/200, score/average: -254.0285/-309.7109
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -2.04/0.0214. Done: 00
#  Mean Policy loss: 3483.8796. Mean Value loss: 115.4986
# Episode: 82/200, score/average: -369.6771/-307.9177
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.85/-0.0461. Done: 0
#  Mean Policy loss: 3221.0696. Mean Value loss: 108.4563
# Episode: 83/200, score/average: -348.4255/-316.7931
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -3.87/-0.0345. Done: 0
#  Mean Policy loss: 9034.9014. Mean Value loss: 181.6165
# Episode: 84/200, score/average: -572.8269/-343.9049
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.8/0.0344. Done: 000
#  Mean Policy loss: 4384.5469. Mean Value loss: 122.1787
# Episode: 85/200, score/average: -380.6693/-351.0759
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -1.71/0.0571. Done: 00
#  Mean Policy loss: 2850.5330. Mean Value loss: 101.8790
# Episode: 86/200, score/average: -322.5515/-358.7043
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -1.58/0.0282. Done: 00
#  Mean Policy loss: 2450.8145. Mean Value loss: 97.0619
# Episode: 87/200, score/average: -311.5888/-359.7789
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -2.89/-0.0012. Done: 0
#  Mean Policy loss: 2498.7400. Mean Value loss: 93.9227
# Episode: 88/200, score/average: -296.4863/-362.1443
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.83/0.0316. Done: 00
#  Mean Policy loss: 4602.7373. Mean Value loss: 131.5310
# Episode: 89/200, score/average: -412.6601/-384.6386
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -4.47/0.0041. Done: 00
#  Mean Policy loss: 9669.6113. Mean Value loss: 187.7336
# Episode: 90/200, score/average: -583.9783/-385.2892 SAVING
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -2.65/0.0458. Done: 00
#  Mean Policy loss: 1883.3295. Mean Value loss: 83.3796
# Episode: 91/200, score/average: -267.4792/-386.6343
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -2.22/0.0602. Done: 00
#  Mean Policy loss: 2111.8977. Mean Value loss: 88.2076
# Episode: 92/200, score/average: -281.4886/-377.8154
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -2.56/0.0476. Done: 00
#  Mean Policy loss: 2286.1023. Mean Value loss: 93.3006
# Episode: 93/200, score/average: -299.1238/-372.8853
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -1.85/0.0571. Done: 00
#  Mean Policy loss: 4363.0645. Mean Value loss: 126.8900
# Episode: 94/200, score/average: -399.1489/-355.5175
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.8/-0.0221. Done: 00
#  Mean Policy loss: 545.7878. Mean Value loss: 45.2770
# Episode: 95/200, score/average: -150.3624/-332.4868
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -1.54/0.0759. Done: 00
#  Mean Policy loss: 4416.2842. Mean Value loss: 127.1900
# Episode: 96/200, score/average: -404.6279/-340.6944
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -2.36/-0.0556. Done: 0
#  Mean Policy loss: 1717.0514. Mean Value loss: 81.0197
# Episode: 97/200, score/average: -260.4101/-335.5766
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -3.43/0.0999. Done: 0
#  Mean Policy loss: 6479.7847. Mean Value loss: 151.8813
# Episode: 98/200, score/average: -468.7672/-352.8047
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -4.71/0.0503. Done: 00
#  Mean Policy loss: 8012.5679. Mean Value loss: 165.6486
# Episode: 99/200, score/average: -512.1667/-362.7553
#
# Reset
# Steps: 189/200. Action: 2. Reward/Value: -3.36/-0.0029. Done: -1
#  Mean Policy loss: 4966.9272. Mean Value loss: 133.3467
# Episode: 100/200, score/average: -396.4358/-344.0011 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -5.45/0.0567. Done: 0
#  Mean Policy loss: 10884.9873. Mean Value loss: 190.9860
# Episode: 101/200, score/average: -590.8218/-376.3353
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -2.44/0.0113. Done: 00
#  Mean Policy loss: 4299.8330. Mean Value loss: 124.6492
# Episode: 102/200, score/average: -395.4335/-387.7298
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -5.02/0.0117. Done: 00
#  Mean Policy loss: 10486.2754. Mean Value loss: 191.4338
# Episode: 103/200, score/average: -595.8268/-417.4001
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -0.96/0.0053. Done: 00
#  Mean Policy loss: 782.0694. Mean Value loss: 53.5132
# Episode: 104/200, score/average: -182.0906/-395.6943
#
# Reset
# Steps: 180/200. Action: 3. Reward/Value: -3.16/-0.0309. Done: -1
#  Mean Policy loss: 3208.2224. Mean Value loss: 106.7070
# Episode: 105/200, score/average: -302.6760/-410.9256
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -4.26/-0.0332. Done: 0
#  Mean Policy loss: 9009.9102. Mean Value loss: 178.8010
# Episode: 106/200, score/average: -558.7902/-426.3419
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.92/0.0076. Done: 00
#  Mean Policy loss: 5306.6250. Mean Value loss: 142.8804
# Episode: 107/200, score/average: -444.9643/-444.7973
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -2.07/0.0555. Done: 00
#  Mean Policy loss: 3521.1313. Mean Value loss: 115.6663
# Episode: 108/200, score/average: -365.0861/-434.4292
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -2.74/-0.0918. Done: 0
#  Mean Policy loss: 3608.2175. Mean Value loss: 113.0941
# Episode: 109/200, score/average: -354.4686/-418.6594
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -3.34/-0.073. Done: 00
#  Mean Policy loss: 5978.4316. Mean Value loss: 148.1419
# Episode: 110/200, score/average: -461.6113/-425.1769 SAVING
#
# Reset
# Steps: 191/200. Action: 2. Reward/Value: -6.68/0.1495. Done: -1
#  Mean Policy loss: 14711.1855. Mean Value loss: 226.9308
# Episode: 111/200, score/average: -669.0877/-433.0035
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -3.52/0.057. Done: 000
#  Mean Policy loss: 6990.9229. Mean Value loss: 162.4950
# Episode: 112/200, score/average: -510.5796/-444.5181
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -4.4/-0.0447. Done: 00
#  Mean Policy loss: 6324.3804. Mean Value loss: 150.7320
# Episode: 113/200, score/average: -469.4492/-431.8804
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -4.39/0.0524. Done: 00
#  Mean Policy loss: 8574.8125. Mean Value loss: 174.6225
# Episode: 114/200, score/average: -548.5934/-468.5306
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.89/0.0151. Done: 00
#  Mean Policy loss: 3651.9614. Mean Value loss: 114.5008
# Episode: 115/200, score/average: -364.6167/-474.7247
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -4.2/0.0215. Done: 000
#  Mean Policy loss: 5838.9854. Mean Value loss: 140.4336
# Episode: 116/200, score/average: -437.0743/-462.5531
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.57/0.0086. Done: 00
#  Mean Policy loss: 1121.7543. Mean Value loss: 64.3223
# Episode: 117/200, score/average: -207.2550/-438.7822
#
# Reset
# Steps: 166/200. Action: 5. Reward/Value: -3.64/-0.0058. Done: -1
#  Mean Policy loss: 6535.3916. Mean Value loss: 155.2511
# Episode: 118/200, score/average: -408.9135/-443.1649
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -2.09/0.0536. Done: 00
#  Mean Policy loss: 2410.3286. Mean Value loss: 90.8224
# Episode: 119/200, score/average: -286.3501/-436.3531
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.27/-0.0286. Done: 0
#  Mean Policy loss: 7004.9736. Mean Value loss: 156.8733
# Episode: 120/200, score/average: -487.5620/-438.9481 SAVING
#
# Reset
# Steps: 187/200. Action: 5. Reward/Value: -2.71/-0.0354. Done: -1
#  Mean Policy loss: 3519.0046. Mean Value loss: 112.2520
# Episode: 121/200, score/average: -326.7428/-404.7137
#
# Reset
# Steps: 155/200. Action: 0. Reward/Value: -2.61/0.0881. Done: -1
#  Mean Policy loss: 4959.7080. Mean Value loss: 137.6253
# Episode: 122/200, score/average: -338.0090/-387.4566
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -3.04/0.0123. Done: 00
#  Mean Policy loss: 4136.7588. Mean Value loss: 125.5849
# Episode: 123/200, score/average: -395.2934/-380.0410
#
# Reset
# Steps: 200/200. Action: 6. Reward/Value: -1.8/-0.0907. Done: 00
#  Mean Policy loss: 3100.5544. Mean Value loss: 106.9600
# Episode: 124/200, score/average: -335.8841/-358.7701
#
# Reset
# Steps: 196/200. Action: 4. Reward/Value: -2.37/0.0285. Done: -1
#  Mean Policy loss: 4054.0110. Mean Value loss: 121.8932
# Episode: 125/200, score/average: -370.8883/-359.3972
#
# Reset
# Steps: 199/200. Action: 1. Reward/Value: -2.38/-0.0145. Done: -1
#  Mean Policy loss: 3235.5024. Mean Value loss: 108.3780
# Episode: 126/200, score/average: -341.7767/-349.8675
#
# Reset
# Steps: 181/200. Action: 0. Reward/Value: -2.17/-0.0109. Done: -1
#  Mean Policy loss: 3473.5005. Mean Value loss: 113.3306
# Episode: 127/200, score/average: -324.6489/-361.6069
#
# Reset
# Steps: 190/200. Action: 4. Reward/Value: -4.32/-0.0221. Done: -1
#  Mean Policy loss: 10550.9473. Mean Value loss: 197.4763
# Episode: 128/200, score/average: -590.0521/-379.7207
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -1.46/-0.0314. Done: 0
#  Mean Policy loss: 2319.5276. Mean Value loss: 93.5979
# Episode: 129/200, score/average: -300.9274/-381.1785
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -3.99/0.0146. Done: 00
#  Mean Policy loss: 6640.3955. Mean Value loss: 150.5431
# Episode: 130/200, score/average: -468.1803/-379.2403 SAVING
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -3.18/-0.0387. Done: 0
#  Mean Policy loss: 4469.7446. Mean Value loss: 128.0912
# Episode: 131/200, score/average: -399.5973/-386.5257
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -2.69/-0.074. Done: 00
#  Mean Policy loss: 2434.4036. Mean Value loss: 95.2564
# Episode: 132/200, score/average: -302.3754/-382.9624
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -0.29/-0.0104. Done: 0
#  Mean Policy loss: 769.2129. Mean Value loss: 51.7011
# Episode: 133/200, score/average: -174.6940/-360.9024
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -3.24/0.1069. Done: 00
#  Mean Policy loss: 4203.0576. Mean Value loss: 121.6643
# Episode: 134/200, score/average: -381.0469/-365.4187
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -1.65/0.019. Done: 000
#  Mean Policy loss: 2540.4958. Mean Value loss: 96.3208
# Episode: 135/200, score/average: -307.7483/-359.1047
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -1.97/-0.0295. Done: 0
#  Mean Policy loss: 2574.0994. Mean Value loss: 98.7150
# Episode: 136/200, score/average: -318.7600/-356.8031
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -2.32/-0.0129. Done: 0
#  Mean Policy loss: 3042.7661. Mean Value loss: 106.4492
# Episode: 137/200, score/average: -340.1895/-358.3571
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -0.62/0.0609. Done: 00
#  Mean Policy loss: 2526.4839. Mean Value loss: 93.8643
# Episode: 138/200, score/average: -304.0695/-329.7589
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -0.82/0.0435. Done: 00
#  Mean Policy loss: 620.9124. Mean Value loss: 48.0339
# Episode: 139/200, score/average: -157.1391/-315.3800
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.62/-0.0279. Done: 0
#  Mean Policy loss: 1268.9424. Mean Value loss: 70.2109
# Episode: 140/200, score/average: -229.2650/-291.4885 SAVING
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -0.96/0.0087. Done: 00
#  Mean Policy loss: 1482.8616. Mean Value loss: 72.2149
# Episode: 141/200, score/average: -233.8370/-274.9125 SAVING
#
# Reset
# Steps: 191/200. Action: 5. Reward/Value: -2.46/0.017. Done: -10
#  Mean Policy loss: 3549.7212. Mean Value loss: 113.8240
# Episode: 142/200, score/average: -339.5715/-278.6321
#
# Reset
# Steps: 186/200. Action: 2. Reward/Value: -1.92/-0.0263. Done: -1
#  Mean Policy loss: 1122.5707. Mean Value loss: 63.2664
# Episode: 143/200, score/average: -192.6983/-280.4325
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -1.15/0.0242. Done: 00
#  Mean Policy loss: 1140.5735. Mean Value loss: 65.8515
# Episode: 144/200, score/average: -213.4844/-263.6763 SAVING
#
# Reset
# Steps: 186/200. Action: 0. Reward/Value: -2.43/0.0324. Done: -1
#  Mean Policy loss: 3433.5110. Mean Value loss: 111.9013
# Episode: 145/200, score/average: -326.7475/-265.5762
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -1.63/-0.0306. Done: 0
#  Mean Policy loss: 724.4479. Mean Value loss: 52.8522
# Episode: 146/200, score/average: -172.9660/-250.9968 SAVING
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -0.35/-0.0104. Done: 0
#  Mean Policy loss: 1134.9529. Mean Value loss: 62.4614
# Episode: 147/200, score/average: -199.6379/-236.9416 SAVING
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.95/0.0169. Done: 00
#  Mean Policy loss: 1068.1643. Mean Value loss: 62.8298
# Episode: 148/200, score/average: -201.0993/-226.6446 SAVING
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -0.33/0.0075. Done: 00
#  Mean Policy loss: 759.4222. Mean Value loss: 51.5761
# Episode: 149/200, score/average: -172.3085/-228.1615
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.18/0.0273. Done: 00
#  Mean Policy loss: 1097.1727. Mean Value loss: 65.2656
# Episode: 150/200, score/average: -210.7052/-226.3056 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -2.53/-0.1621. Done: 0
#  Mean Policy loss: 3979.8999. Mean Value loss: 122.7801
# Episode: 151/200, score/average: -385.9753/-241.5194
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -1.04/-0.0412. Done: 0
#  Mean Policy loss: 1540.7604. Mean Value loss: 74.8573
# Episode: 152/200, score/average: -240.8424/-231.6465
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.57/-0.1309. Done: 0
#  Mean Policy loss: 7873.9390. Mean Value loss: 171.1779
# Episode: 153/200, score/average: -536.5075/-266.0274
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -2.92/-0.0494. Done: 0
#  Mean Policy loss: 4109.0396. Mean Value loss: 122.7037
# Episode: 154/200, score/average: -381.1559/-282.7945
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.15/0.0401. Done: 00
#  Mean Policy loss: 2599.0317. Mean Value loss: 99.6873
# Episode: 155/200, score/average: -316.2040/-281.7402
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -0.52/-0.0495. Done: 0
#  Mean Policy loss: 1809.9202. Mean Value loss: 80.3111
# Episode: 156/200, score/average: -253.5035/-289.7939
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -1.89/0.0802. Done: 00
#  Mean Policy loss: 1737.1136. Mean Value loss: 81.8633
# Episode: 157/200, score/average: -262.0995/-296.0401
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -1.36/-0.0718. Done: 0
#  Mean Policy loss: 2285.2798. Mean Value loss: 92.3918
# Episode: 158/200, score/average: -298.0252/-305.7327
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -4.47/-0.0386. Done: 0
#  Mean Policy loss: 11870.1924. Mean Value loss: 206.9879
# Episode: 159/200, score/average: -644.4661/-352.9485
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -3.97/0.0291. Done: 00
#  Mean Policy loss: 6441.7764. Mean Value loss: 153.6976
# Episode: 160/200, score/average: -481.2181/-379.9998 SAVING
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -3.19/-0.0308. Done: 0
#  Mean Policy loss: 2917.5886. Mean Value loss: 99.1888
# Episode: 161/200, score/average: -316.8172/-373.0839
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.2/-0.0304. Done: 00
#  Mean Policy loss: 3342.8765. Mean Value loss: 111.0376
# Episode: 162/200, score/average: -352.4753/-384.2472
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -2.97/-0.0447. Done: 0
#  Mean Policy loss: 4494.4653. Mean Value loss: 126.8066
# Episode: 163/200, score/average: -397.4086/-370.3373
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -4.57/-0.2348. Done: 0
#  Mean Policy loss: 9071.8340. Mean Value loss: 179.8888
# Episode: 164/200, score/average: -567.0988/-388.9316
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -2.44/-0.1193. Done: 0
#  Mean Policy loss: 3616.0430. Mean Value loss: 116.1612
# Episode: 165/200, score/average: -363.0096/-393.6122
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.93/-0.0371. Done: 0
#  Mean Policy loss: 3131.3669. Mean Value loss: 108.0082
# Episode: 166/200, score/average: -343.6569/-402.6275
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -3.23/-0.079. Done: 00
#  Mean Policy loss: 5757.5601. Mean Value loss: 140.8751
# Episode: 167/200, score/average: -437.3341/-420.1510
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -3.41/-0.0545. Done: 0
#  Mean Policy loss: 7323.6025. Mean Value loss: 164.7055
# Episode: 168/200, score/average: -516.8070/-442.0292
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -5.68/-0.0521. Done: 0
#  Mean Policy loss: 12851.5908. Mean Value loss: 207.5364
# Episode: 169/200, score/average: -639.6656/-441.5491
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.85/-0.0915. Done: 0
#  Mean Policy loss: 4575.1201. Mean Value loss: 126.8771
# Episode: 170/200, score/average: -395.4776/-432.9751 SAVING
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -6.12/-0.0414. Done: 0
#  Mean Policy loss: 13443.9746. Mean Value loss: 219.1317
# Episode: 171/200, score/average: -686.5186/-469.9452
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -4.96/-0.0331. Done: 0
#  Mean Policy loss: 9638.5254. Mean Value loss: 186.4646
# Episode: 172/200, score/average: -578.0828/-492.5060
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -5.44/-0.0078. Done: 0
#  Mean Policy loss: 12952.7178. Mean Value loss: 210.8528
# Episode: 173/200, score/average: -656.7453/-518.4396
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -5.1/-0.1218. Done: 00
#  Mean Policy loss: 10266.0762. Mean Value loss: 194.6009
# Episode: 174/200, score/average: -603.9357/-522.1233
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -4.24/-0.0048. Done: 0
#  Mean Policy loss: 8366.4502. Mean Value loss: 175.0952
# Episode: 175/200, score/average: -550.0152/-540.8239
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -5.08/-0.0695. Done: 0
#  Mean Policy loss: 8521.7061. Mean Value loss: 171.9298
# Episode: 176/200, score/average: -534.3791/-559.8961
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -4.2/-0.0238. Done: 00
#  Mean Policy loss: 5425.7505. Mean Value loss: 136.9229
# Episode: 177/200, score/average: -422.1385/-558.3765
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -4.62/0.0232. Done: 00
#  Mean Policy loss: 7683.6523. Mean Value loss: 166.4667
# Episode: 178/200, score/average: -518.0337/-558.4992
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -6.3/0.1295. Done: 00
#  Mean Policy loss: 15698.5547. Mean Value loss: 235.1457
# Episode: 179/200, score/average: -735.1280/-568.0454
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.33/-0.0469. Done: 0
#  Mean Policy loss: 3116.3315. Mean Value loss: 105.3351
# Episode: 180/200, score/average: -332.9346/-561.7911 SAVING
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -3.23/-0.0106. Done: 0
#  Mean Policy loss: 3449.0249. Mean Value loss: 110.7946
# Episode: 181/200, score/average: -353.9552/-528.5348
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -3.06/-0.0584. Done: 0
#  Mean Policy loss: 3760.2603. Mean Value loss: 113.9606
# Episode: 182/200, score/average: -361.8397/-506.9105
#
# Reset
# Steps: 200/200. Action: 3. Reward/Value: -4.88/-0.264. Done: 00
#  Mean Policy loss: 7504.2202. Mean Value loss: 160.7419
# Episode: 183/200, score/average: -504.1563/-491.6516
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.38/-0.1275. Done: 0
#  Mean Policy loss: 4514.3804. Mean Value loss: 125.0270
# Episode: 184/200, score/average: -392.3017/-470.4882
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -2.3/-0.139. Done: 0 0
#  Mean Policy loss: 2408.1934. Mean Value loss: 95.3247
# Episode: 185/200, score/average: -304.8482/-445.9715
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -3.88/-0.1565. Done: 0
#  Mean Policy loss: 6794.3086. Mean Value loss: 155.2982
# Episode: 186/200, score/average: -490.0363/-441.5372
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -5.21/-0.2434. Done: 0
#  Mean Policy loss: 12226.6943. Mean Value loss: 209.9119
# Episode: 187/200, score/average: -660.9073/-465.4141
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -4.27/-0.1717. Done: 0
#  Mean Policy loss: 9928.7998. Mean Value loss: 188.5719
# Episode: 188/200, score/average: -592.1629/-472.8270
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.27/-0.0945. Done: 0
#  Mean Policy loss: 4094.0488. Mean Value loss: 123.1766
# Episode: 189/200, score/average: -394.2320/-438.7374
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -5.22/-0.1976. Done: 0
#  Mean Policy loss: 10141.2666. Mean Value loss: 193.0503
# Episode: 190/200, score/average: -602.1006/-465.6540 SAVING
#
# Reset
# Steps: 200/200. Action: 4. Reward/Value: -3.46/-0.0657. Done: 0
#  Mean Policy loss: 5224.7007. Mean Value loss: 137.4533
# Episode: 191/200, score/average: -432.2722/-473.4857
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -2.75/-0.0269. Done: 0
#  Mean Policy loss: 5254.8525. Mean Value loss: 141.3548
# Episode: 192/200, score/average: -444.1025/-481.7120
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -0.79/-0.0234. Done: 0
#  Mean Policy loss: 785.9600. Mean Value loss: 54.2481
# Episode: 193/200, score/average: -175.5457/-448.8509
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -0.83/-0.0565. Done: 0
#  Mean Policy loss: 1432.7400. Mean Value loss: 72.8118
# Episode: 194/200, score/average: -240.5180/-433.6726
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -1.68/-0.1806. Done: 0
#  Mean Policy loss: 1805.0247. Mean Value loss: 82.7416
# Episode: 195/200, score/average: -263.7612/-429.5639
#
# Reset
# Steps: 200/200. Action: 0. Reward/Value: -0.66/-0.1045. Done: 0
#  Mean Policy loss: 1220.2605. Mean Value loss: 64.0502
# Episode: 196/200, score/average: -212.3924/-401.7995
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -1.5/0.0803. Done: 000
#  Mean Policy loss: 2214.0164. Mean Value loss: 90.6899
# Episode: 197/200, score/average: -285.9181/-364.3006
#
# Reset
# Steps: 200/200. Action: 5. Reward/Value: -3.1/-0.1119. Done: 00
#  Mean Policy loss: 4127.9380. Mean Value loss: 122.0564
# Episode: 198/200, score/average: -386.3792/-343.7222
#
# Reset
# Steps: 200/200. Action: 2. Reward/Value: -1.37/0.0312. Done: 00
#  Mean Policy loss: 1946.4430. Mean Value loss: 86.2991
# Episode: 199/200, score/average: -277.4474/-332.0437
#
# Reset
# Steps: 200/200. Action: 1. Reward/Value: -2.41/-0.0239. Done: 0
#  Mean Policy loss: 4138.9497. Mean Value loss: 125.7970
# Episode: 200/200, score/average: -394.9194/-311.3256 SAVING
# 127.0.0.1 - - [08/Aug/2024 22:44:56] "GET /socket.io/?EIO=4&transport=websocket&sid=JkVRiXRiwTylxPhBAAAA HTTP/1.1" 200 0 42171.707100

# %%
agent.load("Models8/auto-docking-iss_PPO__148_-226.6446.pt")
# Out:
# ./Models8/auto-docking-iss_PPO__148_-226.6446.pt

# %%
agent.test(500)
# Out:
# Reset
# Steps: 69/500. Action: 4. Score/Value: -93.29/-0.0185. Done: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 agent.test(500)
#
# Cell In[5], line 270, in PPO.test(self, max_steps)
#     267 step = 0
#     269 while True:
# --> 270     end = time.time()
#     271     if end - start >= 1.0:
#     272         step += 1
#
# KeyboardInterrupt:

# %%
import os
import pyautogui

# Simular pulsación de Ctrl+S
pyautogui.hotkey('ctrl', 's')

os.system('sudo shutdown')
# os.system('sudo shutdown -c')
